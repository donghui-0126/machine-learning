# %% [markdown]
# 여기는 "파이썬 머신러닝 완벽 가이드" 책을 보면서 몰랐던 부분을 적는 장소 입니다.
#
# 1. 왜 결정트리의 파라미터에 random_state가 들어가야 하는 지는 잘 모르겠다.
# 2. 왜?? GBM, XGB, LGBM 머신러닝 식들이 블랙박스 형태일까?? 결국 식으로 이루어져 있을 것 같은데, 잘 이해가 안간다.

# %% [markdown]
# # 1. 분류
#
# ## 1.1 결정트리
# 결정트리는 정보균일도가 높은 데이터 세트를 먼저 선택할 수 있도록 규칙 조건을 만든다. <br>
# 정보균일도는 지니계수와 엔트로피를 이용한 정보 이득 지수가 있는데, DecisionTreeClassifier에서는 지니계수를 이용해서 분류를 한다.

# %% [markdown]
# #### DecisionTreeClassifier(min_samples_split, min_samples_leaf, max_features, max_depth, max_leaf_nodes)
# min_samples_split : 노드를 분할하기 위한 최소한의 데이터 수 (default = 2) <br>
# 과적합을 제어하기 위함. 이 파라미터가 작아지면 과적합이 될 가능성이 커짐
#
# min_samples_leaf : 말단 노드가 되기 위한 최소한의 샘플 데이터 수 <br>
# 과적합을 제어하기 위함이지만, 비대칭적 데이터의 경우에 작게 설정을 해야한다.
#
# max_features : 최적의 분할을 위해 고려할 최대 피처 개수.
# 1. int/float : 피처의 개수/ 선택할 피처의 %
# 2. sqrt, auto : sqrt(전체 피처)의 개수만큼 선택
# 3. log : log2(전체 피처)의 개수만큼 선택
# 4. None : default
#
# max_lepth : 트리의 최대 깊이를 규정. (default = None). 깊이가 깊어지면 과적합할 가능성이 높아짐
#
# max_leaf_nodes : 말단 노드의 최대 개수

# %% [markdown]
# ## 결정 트리 모델의 시각화 (Grphviz를 이용함)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# DecisionTree Classifier 생성
dt_clf = DecisionTreeClassifier(random_state=156)

# 붓꽃 데이터를 로딩하고, 학습과 테스트 데이터 세트로 분리
iris_data = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris_data.data, iris_data.target, test_size=0.2, random_state=11)

#모델 학습
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=156)

# %%
from sklearn.tree import export_graphviz

# export_graphviz() 의 호출 결과로 out_file로 지정된 tree.dot 파일을 생성함
export_graphviz(dt_clf, out_file="tree.dot", class_names=iris_data.target_names, \
               feature_names = iris_data.feature_names, impurity=True, filled=True)

import graphviz
with open("tree.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %% [markdown]
# ## feature_importance 구해보기

# %%
import seaborn as sns
import numpy as np
# %matplotlib inline

# feature importance 추출
print("Feature importances: \n{}".format(np.round(dt_clf.feature_importances_, 3)))

# feature별 importance 매핑
for name, value in zip(iris_data.feature_names, dt_clf.feature_importances_):
    print('{0} : {1:.3f}'.format(name, value))
    
sns.barplot(x=dt_clf.feature_importances_, y=iris_data.feature_names)
# Out:
# Feature importances:
# [0.025 0.    0.555 0.42 ]
# sepal length (cm) : 0.025
# sepal width (cm) : 0.000
# petal length (cm) : 0.555
# petal width (cm) : 0.420
# <AxesSubplot:>

# %% [markdown]
# ## 결정트리 과적합 make_classification()

# %%
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
# %matplotlib inline

def visualize_boundary(model, X, y):
    fig,ax = plt.subplots()
    
    # 학습 데이타 scatter plot으로 나타내기
    ax.scatter(X[:, 0], X[:, 1], c=y, s=25, cmap='rainbow', edgecolor='k',
               clim=(y.min(), y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim_start , xlim_end = ax.get_xlim()
    ylim_start , ylim_end = ax.get_ylim()
    
    # 호출 파라미터로 들어온 training 데이타로 model 학습 . 
    model.fit(X, y)
    # meshgrid 형태인 모든 좌표값으로 예측 수행. 
    xx, yy = np.meshgrid(np.linspace(xlim_start,xlim_end, num=200),np.linspace(ylim_start,ylim_end, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
    
    # contourf() 를 이용하여 class boundary 를 visualization 수행. 
    n_classes = len(np.unique(y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3,
                           levels=np.arange(n_classes + 1) - 0.5,
                           cmap='rainbow', clim=(y.min(), y.max()),
                           zorder=1)
    
plt.title("3 Class values with 2 Features Sample data creation ")

# 2차원 시각화를 위해사 피처는 2개, 클래스는 3가지 유형의 분류 샘플 데이터 생성.
X_features, y_labels = make_classification(n_features=2, n_redundant=0, n_informative=2, n_classes=3, n_clusters_per_class=1, random_state=0)

plt.scatter(X_features[:,0], X_features[:,1], marker='o', c=y_labels, s=25, edgecolor='k')

# %%
dt_clf = DecisionTreeClassifier(random_state=156).fit(X_features, y_labels)
visualize_boundary(dt_clf, X_features, y_labels)

# %%
# 과적합이} 완화됨
dt_clf = DecisionTreeClassifier(min_samples_leaf = 6, random_state=156).fit(X_features, y_labels)
visualize_boundary(dt_clf, X_features, y_labels)

# %%
dt_clf = DecisionTreeClassifier(max_depth=3, random_state=156).fit(X_features, y_labels)
visualize_boundary(dt_clf, X_features, y_labels)

# %% [markdown]
# ## 결정 트리 실습- 사용자 행동 인식 데이터 세트

# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# feature 이름 불러오기
# sep='\s+': 공백문자는 건너 뜀, header=None : 피처네임이 없는 것
feature_name_df = pd.read_csv('human_activity/features.txt', sep='\s+', header=None, names=['column_index', 'column_name'])
feature_name = feature_name_df.iloc[:,1].values.tolist() # values로 피처이름만 받아온 후 tolist로 리스트 객체로 생성

# %%
# 겹치는 피처네임 없애기
def get_new_feature_name_df(old_feature_name_df):
    #column_name 컬럼에서 겹치는 이름을 찾아내서 몇번째 겹치는지 알려줌. 아래 박스에 결과를 보여주겠음
    feature_dup_df = pd.DataFrame(data=old_feature_name_df.groupby('column_name').cumcount(),\
                                                                  columns=['dup_cnt'])
    #인덱스를 리셋함
    feature_dup_df = feature_dup_df.reset_index()
    # 어느 한쪽에라도 NaN이 있는 경우 NaN이 되도록 합침
    new_feature_name_df = pd.merge(old_feature_name_df.reset_index(), feature_dup_df, how='outer')
    # columns 방향으로 lambda 함수를 사용함
    new_feature_name_df['column_name'] =new_feature_name_df[['column_name', 'dup_cnt']].apply(lambda x: x[0]+'_'+str(x[1])\
                                                                                             if x[1] >0 else x[0], axis=1) 
    new_feature_name_df = new_feature_name_df.drop(['index'], axis=1)
    return new_feature_name_df

# %%
feature_dup_df = pd.DataFrame(data=feature_name_df.groupby('column_name').cumcount(),\
                                                                  columns=['dup_cnt'])
feature_dup_df = feature_dup_df.reset_index()
new_feature_name_df = pd.merge(feature_name_df.reset_index(), feature_dup_df, how='outer')
new_feature_name_df['column_name'] =new_feature_name_df[['column_name', 'dup_cnt']].apply(lambda x: x[0]+'_'+str(x[1])\
                                                                                             if x[1] >0 else x[0], axis=1) 
new_feature_name_df = new_feature_name_df.drop(['index'], axis=1)
new_feature_name_df
# Out:
#      column_index                           column_name  dup_cnt
# 0               1                     tBodyAcc-mean()-X        0
# 1               2                     tBodyAcc-mean()-Y        0
# 2               3                     tBodyAcc-mean()-Z        0
# 3               4                      tBodyAcc-std()-X        0
# 4               5                      tBodyAcc-std()-Y        0
# ..            ...                                   ...      ...
# 556           557      angle(tBodyGyroMean,gravityMean)        0
# 557           558  angle(tBodyGyroJerkMean,gravityMean)        0
# 558           559                  angle(X,gravityMean)        0
# 559           560                  angle(Y,gravityMean)        0
# 560           561                  angle(Z,gravityMean)        0
#
# [561 rows x 3 columns]

# %%
def get_human_dataset():
    feature_name_df = pd.read_csv('human_activity/features.txt', sep='\s+', header=None, names=['column_index', 'column_name'])
    
    new_feature_name_df = get_new_feature_name_df(feature_name_df)
    feature_name = new_feature_name_df.iloc[:, 1].values.tolist()
    
    X_train = pd.read_csv('human_activity/train/X_train.txt', sep='\s+', header=None, names=feature_name)
    X_test = pd.read_csv('human_activity/test/X_test.txt', sep='\s+', header=None, names=feature_name)
    
    y_train = pd.read_csv('human_activity/train/y_train.txt', sep='\s+', header=None, names=['action'])
    y_test = pd.read_csv('human_activity/test/y_test.txt', sep='\s+', header=None, names=['action'])
    
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = get_human_dataset()

# %%
X_train
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# 1            -0.998245         -0.975300         -0.960322         -0.998807
# 2            -0.995380         -0.967187         -0.978944         -0.996520
# 3            -0.996091         -0.983403         -0.990675         -0.997099
# 4            -0.998139         -0.980817         -0.990482         -0.998321
# ...                ...               ...               ...               ...
# 7347         -0.195387          0.039905          0.077078         -0.282301
# 7348         -0.235309          0.004816          0.059280         -0.322552
# 7349         -0.218218         -0.103822          0.274533         -0.304515
# 7350         -0.219139         -0.111412          0.268893         -0.310487
# 7351         -0.269270         -0.087212          0.177404         -0.377404
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 0            -0.983185         -0.923527         -0.934724  ...
# 1            -0.974914         -0.957686         -0.943068  ...
# 2            -0.963668         -0.977469         -0.938692  ...
# 3            -0.982750         -0.989302         -0.938692  ...
# 4            -0.979672         -0.990441         -0.942469  ...
# ...                ...               ...               ...  ...
# 7347          0.043616          0.060410          0.210795  ...
# 7348         -0.029456          0.080585          0.117440  ...
# 7349         -0.098913          0.332584          0.043999  ...
# 7350         -0.068200          0.319473          0.101702  ...
# 7351         -0.038678          0.229430          0.269013  ...
#
#       fBodyBodyGyroJerkMag-meanFreq()  fBodyBodyGyroJerkMag-skewness()  \
# 0                           -0.074323                        -0.298676
# 1                            0.158075                        -0.595051
# 2                            0.414503                        -0.390748
# 3                            0.404573                        -0.117290
# 4                            0.087753                        -0.351471
# ...                               ...                              ...
# 7347                        -0.070157                        -0.588433
# 7348                         0.165259                        -0.390738
# 7349                         0.195034                         0.025145
# 7350                         0.013865                         0.063907
# 7351                        -0.058402                        -0.387052
#
#       fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                           -0.710304                    -0.112754
# 1                           -0.861499                     0.053477
# 2                           -0.760104                    -0.118559
# 3                           -0.482845                    -0.036788
# 4                           -0.699205                     0.123320
# ...                               ...                          ...
# 7347                        -0.880324                    -0.190437
# 7348                        -0.680744                     0.064907
# 7349                        -0.304029                     0.052806
# 7350                        -0.344314                    -0.101360
# 7351                        -0.740738                    -0.280088
#
#       angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                                 0.030400                         -0.464761
# 1                                -0.007435                         -0.732626
# 2                                 0.177899                          0.100699
# 3                                -0.012892                          0.640011
# 4                                 0.122542                          0.693578
# ...                                    ...                               ...
# 7347                              0.829718                          0.206972
# 7348                              0.875679                         -0.879033
# 7349                             -0.266724                          0.864404
# 7350                              0.700740                          0.936674
# 7351                             -0.007739                         -0.056088
#
#       angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                                -0.018446             -0.841247
# 1                                 0.703511             -0.844788
# 2                                 0.808529             -0.848933
# 3                                -0.485366             -0.848649
# 4                                -0.615971             -0.847865
# ...                                    ...                   ...
# 7347                             -0.425619             -0.791883
# 7348                              0.400219             -0.771840
# 7349                              0.701169             -0.779133
# 7350                             -0.589479             -0.785181
# 7351                             -0.616956             -0.783267
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)
# 0                 0.179941             -0.058627
# 1                 0.180289             -0.054317
# 2                 0.180637             -0.049118
# 3                 0.181935             -0.047663
# 4                 0.185151             -0.043892
# ...                    ...                   ...
# 7347              0.238604              0.049819
# 7348              0.252676              0.050053
# 7349              0.249145              0.040811
# 7350              0.246432              0.025339
# 7351              0.246809              0.036695
#
# [7352 rows x 561 columns]

# %%
# y 값이 고르게 분포함
y_train['action'].value_counts()
# Out:
# 6    1407
# 5    1374
# 4    1286
# 1    1226
# 2    1073
# 3     986
# Name: action, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

dt_clf = DecisionTreeClassifier(random_state=156)
dt_clf.fit(X_train, y_train)
pred = dt_clf.predict(X_test)
accuracy = accuracy_score(y_test, pred)
print("결정트리 정확도: {0:.4f}".format(accuracy))
print("결정트리 기본 하이퍼 파라미터:\n", dt_clf.get_params())
# Out:
# 결정트리 정확도: 0.8548
# 결정트리 기본 하이퍼 파라미터:
#  {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': 156, 'splitter': 'best'}

# %% [markdown]
# ## 최적의 하이퍼 파라미터 찾기

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'max_depth' : [6, 8, 10, 12, 16],
    'min_samples_split' : [16]
}

grid_cv = GridSearchCV(dt_clf, param_grid=params, scoring='accuracy', cv=5, verbose=1)
grid_cv.fit(X_train, y_train)
print('GridSearchCV 최고 평균 정확도 수치: {0:.4f}'.format(grid_cv.best_score_))
print('GridSearchCV 최적 하이퍼 파라미터:',grid_cv.best_params_)

결과값: 
Fitting 5 folds for each of 5 candidates, totalling 25 fits
GridSearchCV 최고 평균 정확도 수치: 0.8549
GridSearchCV 최적 하이퍼 파라미터: {'max_depth': 8, 'min_samples_split': 16}

# %%
# 그리그서치 객체의 cv_results_ 속성을 DataFrame으로 생성.
cv_result_df = pd.DataFrame(grid_cv.cv_results_)

#max_depth 파라미터 값과 그때의 테스트 세트, 학습 데이터 세트의 정확도 수치 추출
cv_result_df[['param_max_depth', 'mean_test_score']]
# Out:
#   param_max_depth  mean_test_score
# 0               6         0.847662
# 1               8         0.854879
# 2              10         0.852705
# 3              12         0.845768
# 4              16         0.847127

# %% [markdown]
# #### max_depth 파라미터가 과도하게 크면 과적합으로 인해 성능이 저하되는 모습을 볼 수 있음.

# %% [markdown]
# ## 1.2 앙상블 학습

# %% [markdown]
# 1. 보팅(Voting) : 서로 다른 알고리즘을 가진 여러 개의 분류기가 투표를 통해서 결정하는 방식
# 2. 배깅(Bagging) : 서로 같은 알고리즘을 가진 여러 개의 븐루기가 투표를 통해서 결정하는 방식
# 3. 부스팅(Boostin) : 여러 개의 븐루기가 순차적으로 학습을 수행하되, 점점 분류기를 개선시키는 방식

# %% [markdown]
# ### 보팅 유형
# 1. 하드보팅 : 분류기의 결과값만을 이용해서 투표를 진행함
# 2. 소프트 보팅 : 분류기의 확률을 모두 더해서 투표를 진행함

# %% [markdown]
# ## 1.2.1 랜덤포레스트

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

X_train, X_test, y_train, y_test = get_human_dataset()

rf_clf = RandomForestClassifier(random_state=0, max_depth=8)
rf_clf.fit(X_train, y_train)
print('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy_score(y_test, rf_clf.predict(X_test))))
# Out:
# 랜덤 포레스트 정확도: 0.9196

# %% [markdown]
# 트리 기반의 앙상블 알고리즘은 하이퍼 파라미터가 많아서 튜닝을 위한 시간이 오래걸리는 단점이 있다.

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'max_depth' : [8, 16, 24],
    'min_samples_leaf' : [1, 6, 12],
    'min_samples_split' : [2, 8, 16]
}

rf_clf = RandomForestClassifier(n_estimators=100, random_state=0, n_jobs=-1)
grid_cv = GridSearchCV(rf_clf, param_grid=params, cv=2, n_jobs=-1, )
grid_cv.fit(X_train, y_train)

print('최적 하이퍼 파라미터: \n', grid_cv.best_params_)
print('최고 예측 정확도: {0:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터:
#  {'max_depth': 16, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 최고 예측 정확도: 0.9165

# %%
rf_clf1 = RandomForestClassifier(n_estimators=100, min_samples_leaf=6, max_depth=16, min_samples_split=2, random_state=0)
rf_clf1.fit(X_train, y_train)
pred = rf_clf1.predict(X_test)
print('예측 정확도 {0:.4f}'.format(accuracy_score(y_test, pred)))
# Out:
# 예측 정확도 0.9260

# %% [markdown]
# # 1.2.2 GBM(Gradient Boosing Machine)
# ## GBM 원리에 대한 설명 링크
# https://yngie-c.github.io/machine%20learning/2021/03/21/gbm/

# %% [markdown]
# 부스팅 알고리즘은 여러 개의 약한 학습기를 순차적으로 학습-예측하면서 잘못 예측한 데이터에 가중치 부여를 통해 오류를 개선해 나가면서 학습하는 방식이다.

# %% [markdown]
# GBM알고리즘은 에이다부스트와 유사하나(code-it/Ensemble에 정리되어 있음) 가중치 업데이트를 경사라강법을 이용한다.
# 또한, GBM 알고리즘은 CART(Classification And Regression Tree)와 마찬가지로 회기도 가능하다.

# %% [markdown]
# ### GBM을 사용한 사용자 행동 데이터 분석

# %% [markdown]
# ``` python
# from sklearn.ensemble import GradientBoostingClassifier
# import time
# import warnings
# warnings.filterwarnings('ignore')
#
# X_train, X_test, y_train, y_test = get_human_dataset()
#
# #GBM 수행 시간 측정을 위함. 시작 시간 설정.
# start_time = time.time()
#
# gb_clf = GradientBoostingClassifier(random_state=0)
# gb_clf.fit(X_train, y_train)
# pred = gb_clf.predict(X_test)
# accuracy = accuracy_score(y_test, pred)
# print('GBM 정확도: {0:.4f}'. format(accuracy))
# print('GBM 수행시간: ', time.time()-start_time,"초")
# ```

# %% [markdown]
# ### GradientBoostingClassifier 하이퍼 파라미터
# 1. loss : 경사하강법에서 사용할 손실함수를 지정함. (depault = 'deviance')
# 2. learning_rate : GBM이 학습을 진행 할 때마다 적용하는 학습률을 설정함. (depault = 0.1)
# 3. n_estimators : weak learner의 개수 (depault = 100)
# 4. subsample : weak learner가 학습에 사용하는 데이터의 샘플링 비율 (depault = 1)

# %% [markdown]
# # 1.2.3 XGBoost (eXtra Gradient Boost)
# GBM의 과적합 규재 부재, 느린 수행 시간을 보완한 알고리즘.
# ## XGBoost의 향상점 링크
# https://towardsdatascience.com/xgboost-extreme-gradient-boosting-how-to-improve-on-regular-gradient-boosting-5c6acf66c70a

# %%
import xgboost as xgb
from xgboost import XGBClassifier

# %% [markdown]
# ## XGBoost의 하이퍼 파라미터
# ### 일반 파라미터
# ![image.png](attachment:image.png)
#
#
# ### 주요 부스터 파라미터
# ![image-2.png](attachment:image-2.png)
#
# ### 학습 태스크 파라미터
# : 학습 수행 시의 객체함수, 평가를 위한 지표 등을 설정하는 파라미터
#
# ![image-3.png](attachment:image-3.png)
#
#
# ### 과적합 제어
# 1. eta 값을 낮춥니다.(0.01 ~ 0.1) → eta 값을 낮추면 num_boost_round(n_estimator)를 반대로 높여주어야 합니다.
# 2. max_depth 값을 낮춥니다.
# 3. min_child_weight 값을 높입니다.
# 4. gamma 값을 높입니다.
# 5. subsample과 colsample_bytree를 낮춥니다.
#
#
# ### Early Stopping 기능 :
# GBM의 경우 n_estimators에 지정된 횟수만큼 학습을 끝까지 수행하지만, XGB의 경우 오류가 더 이상 개선되지 않으면 수행을 중지
# n_estimators 를 200으로 설정하고, 조기 중단 파라미터 값을 50으로 설정하면, 1부터 200회까지 부스팅을 반복하다가
# 50회를 반복하는 동안 학습오류가 감소하지 않으면 더 이상 부스팅을 진행하지 않고 종료합니다.
# (가령 100회에서 학습오류 값이 0.8인데 101~150회 반복하는 동안 예측 오류가 0.8보다 작은 값이 하나도 없으면 부스팅을 종료)

# %% [markdown]
# ## 파이썬 래퍼 XGB모듈을 이용한 위스콘신 유방암 예측

# %%
import xgboost as xgb
from xgboost import plot_importance
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

dataset = load_breast_cancer()
feature = dataset.data
labels = dataset.target

cancer_df = pd.DataFrame(data=feature, columns=dataset.feature_names)
cancer_df['target'] = labels

X_features = cancer_df.iloc[:, :-1]
y_labels = cancer_df.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X_features, y_labels, test_size=0.2, random_state=156)

# train 데이터를 검증용과 학습용으로 분리/ XGB에서 제공하는 조기종료와 검증 성능평가를 사용하기 위함.
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=156)

# 파이썬 래퍼 XGBoost는 데이터를 DMatrix 형식으로넘겨줘야 한다. 이때 주요 파라미터는 feature 와 label
dtr = xgb.DMatrix(data=X_tr, label=y_tr)
dval = xgb.DMatrix(data=X_val, label=y_val)
dtest = xgb.DMatrix(data=X_test, label=y_test)

# 파이썬 래퍼 XGBoost를 이용해 학습하려면 하이퍼파라미터를 딕셔너리 형태로 입력해줘야 한다.
params = {'max_depth':3,
          'eta' : 0.05,
          'objective' : 'binary:logistic',
          'eval_metric' : 'logloss'
        }
num_rounds = 400

# 학습 데이터 섹은 'train', 평가 데이터 셋은 'eval'로 명기함.
eval_list = [(dtr, 'train'), (dval, 'eval')]

# fit 대신 train을 이용해서 모델 학습
xgb_model = xgb.train(params= params, dtrain=dtr, num_boost_round=num_rounds, early_stopping_rounds=50, evals=eval_list)
# Out:
# [0]	train-logloss:0.65016	eval-logloss:0.66183
# [1]	train-logloss:0.61131	eval-logloss:0.63609
# [2]	train-logloss:0.57563	eval-logloss:0.61144
# [3]	train-logloss:0.54310	eval-logloss:0.59204
# [4]	train-logloss:0.51323	eval-logloss:0.57329
# [5]	train-logloss:0.48447	eval-logloss:0.55037
# [6]	train-logloss:0.45796	eval-logloss:0.52929
# [7]	train-logloss:0.43436	eval-logloss:0.51534
# [8]	train-logloss:0.41150	eval-logloss:0.49718
# [9]	train-logloss:0.39027	eval-logloss:0.48154
# [10]	train-logloss:0.37128	eval-logloss:0.46990
# [11]	train-logloss:0.35254	eval-logloss:0.45474
# [12]	train-logloss:0.33528	eval-logloss:0.44229
# [13]	train-logloss:0.31893	eval-logloss:0.42961
# [14]	train-logloss:0.30439	eval-logloss:0.42065
# [15]	train-logloss:0.29000	eval-logloss:0.40958
# [16]	train-logloss:0.27651	eval-logloss:0.39887
# [17]	train-logloss:0.26389	eval-logloss:0.39050
# [18]	train-logloss:0.25210	eval-logloss:0.38254
# [19]	train-logloss:0.24123	eval-logloss:0.37393
# [20]	train-logloss:0.23076	eval-logloss:0.36789
# [21]	train-logloss:0.22091	eval-logloss:0.36017
# [22]	train-logloss:0.21155	eval-logloss:0.35421
# [23]	train-logloss:0.20263	eval-logloss:0.34683
# [24]	train-logloss:0.19434	eval-logloss:0.34111
# [25]	train-logloss:0.18637	eval-logloss:0.33634
# [135]	train-logloss:0.01785	eval-logloss:0.25794
# [136]	train-logloss:0.01763	eval-logloss:0.25876
# [137]	train-logloss:0.01748	eval-logloss:0.25884
# [138]	train-logloss:0.01732	eval-logloss:0.25867
# [139]	train-logloss:0.01719	eval-logloss:0.25876
# [140]	train-logloss:0.01696	eval-logloss:0.25987
# [141]	train-logloss:0.01681	eval-logloss:0.25960
# [142]	train-logloss:0.01669	eval-logloss:0.25982
# [143]	train-logloss:0.01656	eval-logloss:0.25992
# [144]	train-logloss:0.01638	eval-logloss:0.26035
# [145]	train-logloss:0.01623	eval-logloss:0.26055
# [146]	train-logloss:0.01606	eval-logloss:0.26092
# [147]	train-logloss:0.01589	eval-logloss:0.26137
# [148]	train-logloss:0.01572	eval-logloss:0.25999
# [149]	train-logloss:0.01557	eval-logloss:0.26028
# [150]	train-logloss:0.01546	eval-logloss:0.26048
# [151]	train-logloss:0.01531	eval-logloss:0.26142
# [152]	train-logloss:0.01515	eval-logloss:0.26188
# [153]	train-logloss:0.01501	eval-logloss:0.26227
# [154]	train-logloss:0.01486	eval-logloss:0.26287
# [155]	train-logloss:0.01476	eval-logloss:0.26299
# [156]	train-logloss:0.01461	eval-logloss:0.26346
# [157]	train-logloss:0.01448	eval-logloss:0.26379
# [158]	train-logloss:0.01434	eval-logloss:0.26306
# [159]	train-logloss:0.01424	eval-logloss:0.26237
# [160]	train-logloss:0.01410	eval-logloss:0.26251
# [161]	train-logloss:0.01401	eval-logloss:0.26265
# [162]	train-logloss:0.01392	eval-logloss:0.26264
# [163]	train-logloss:0.01380	eval-logloss:0.26250
# [164]	train-logloss:0.01372	eval-logloss:0.26264
# [165]	train-logloss:0.01359	eval-logloss:0.26255
# [166]	train-logloss:0.01350	eval-logloss:0.26188
# [167]	train-logloss:0.01342	eval-logloss:0.26203
# [168]	train-logloss:0.01331	eval-logloss:0.26190
# [169]	train-logloss:0.01319	eval-logloss:0.26184
# [170]	train-logloss:0.01312	eval-logloss:0.26133
# [171]	train-logloss:0.01304	eval-logloss:0.26148
# [172]	train-logloss:0.01297	eval-logloss:0.26157
# [173]	train-logloss:0.01285	eval-logloss:0.26253
# [174]	train-logloss:0.01278	eval-logloss:0.26229
# [175]	train-logloss:0.01267	eval-logloss:0.26086
# [176]	train-logloss:0.01258	eval-logloss:0.26103

# %% [markdown]
# #### 126번째 이후로 50회 동안 모델이 향상되지 않았기 때문에 조기종료함. (log-loss가 낮을 수록 성능이 좋다.)

# %%
# 파이썬 래퍼 XGBoost에서의 predict는 결과를 예측할 수 있는 확률을 리턴함. 
pred_probs = xgb_model.predict(dtest)
print(np.round(pred_probs[:10],3))

preds = [1 if x>0.5 else 0 for x in pred_probs]
print(preds[:10])
# Out:
# [0.845 0.008 0.68  0.081 0.975 0.999 0.998 0.998 0.996 0.001]
# [1, 0, 1, 0, 1, 1, 1, 1, 1, 0]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    f1 = f1_score(y_test,pred)
    roc_auc = roc_auc_score(y_test, pred_proba)
    print('오차행렬:')
    print(confusion)
    print('\n정확도: {}, 정밀도: {}, 재현율: {}, f1 스코어: {}, AUC: {}'.format(round(accuracy,4), round(precision,4), round(recall,4), round(f1,4), round(roc_auc, 4)))

    print('\n')

# %%
get_clf_eval(y_test, preds, pred_probs)
# Out:
# 오차행렬:
# [[34  3]
#  [ 2 75]]
#
# 정확도: 0.9561, 정밀도: 0.9615, 재현율: 0.974, f1 스코어: 0.9677, AUC: 0.9937

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(xgb_model, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ## 사이킷런 래퍼 XGBoost를 사용한 데이터 분석

# %%
from xgboost import XGBClassifier

#warning 메시지를 방지하기 위해서 eval_metric 값을 파라미터로 입력
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.05, max_depth=3, eval_metrics="logloss")
xgb_wrapper.fit(X_train, y_train, verbose = 2)
w_preds = xgb_wrapper.predict(X_test)
w_preds_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

get_clf_eval(y_test, w_preds, w_preds_proba)
# Out:
# [20:02:26] WARNING: ..\src\learner.cc:576:
# Parameters: { "eval_metrics" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:02:26] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 오차행렬:
# [[34  3]
#  [ 1 76]]
#
# 정확도: 0.9649, 정밀도: 0.962, 재현율: 0.987, f1 스코어: 0.9744, AUC: 0.9954

# %% [markdown]
# ## 사이킷런 래퍼 XGBoost를 이용한 조기종료

# %%
from xgboost import XGBClassifier

xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.05, max_depth=3)
# 검증 세트 만들기
evals = [(X_tr, y_tr), (X_val, y_val)]

xgb_wrapper.fit(X_tr, y_tr, early_stopping_rounds=50, eval_metric="logloss", eval_set = evals, verbose=True)

ws50_preds = xgb_wrapper.predict(X_test)
ws50_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]
# Out:
# [0]	validation_0-logloss:0.65016	validation_1-logloss:0.66183
# [1]	validation_0-logloss:0.61131	validation_1-logloss:0.63609
# [2]	validation_0-logloss:0.57563	validation_1-logloss:0.61144
# [3]	validation_0-logloss:0.54310	validation_1-logloss:0.59204
# [4]	validation_0-logloss:0.51323	validation_1-logloss:0.57329
# [5]	validation_0-logloss:0.48447	validation_1-logloss:0.55037
# [6]	validation_0-logloss:0.45796	validation_1-logloss:0.52929
# [7]	validation_0-logloss:0.43436	validation_1-logloss:0.51534
# [8]	validation_0-logloss:0.41150	validation_1-logloss:0.49718
# [9]	validation_0-logloss:0.39027	validation_1-logloss:0.48154
# [10]	validation_0-logloss:0.37128	validation_1-logloss:0.46990
# [11]	validation_0-logloss:0.35254	validation_1-logloss:0.45474
# [12]	validation_0-logloss:0.33528	validation_1-logloss:0.44229
# [13]	validation_0-logloss:0.31893	validation_1-logloss:0.42961
# [14]	validation_0-logloss:0.30439	validation_1-logloss:0.42065
# [15]	validation_0-logloss:0.29000	validation_1-logloss:0.40958
# [16]	validation_0-logloss:0.27651	validation_1-logloss:0.39887
# [17]	validation_0-logloss:0.26389	validation_1-logloss:0.39050
# [18]	validation_0-logloss:0.25210	validation_1-logloss:0.38254
# [19]	validation_0-logloss:0.24123	validation_1-logloss:0.37393
# [20]	validation_0-logloss:0.23076	validation_1-logloss:0.36789
# [21]	validation_0-logloss:0.22091	validation_1-logloss:0.36017
# [22]	validation_0-logloss:0.21155	validation_1-logloss:0.35421
# [23]	validation_0-logloss:0.20263	validation_1-logloss:0.34683
# [24]	validation_0-logloss:0.19434	validation_1-logloss:0.34111
# [25]	validation_0-logloss:0.18637	validation_1-logloss:0.33634
# [26]	validation_0-logloss:0.17875	validation_1-logloss:0.33082
# [27]	validation_0-logloss:0.17167	validation_1-logloss:0.32675
# [28]	validation_0-logloss:0.16481	validation_1-logloss:0.32099
# [29]	validation_0-logloss:0.15835	validation_1-logloss:0.31671
# [30]	validation_0-logloss:0.15225	validation_1-logloss:0.31277
# [31]	validation_0-logloss:0.14650	validation_1-logloss:0.30882
# [32]	validation_0-logloss:0.14102	validation_1-logloss:0.30437
# [33]	validation_0-logloss:0.13590	validation_1-logloss:0.30103
# [34]	validation_0-logloss:0.13109	validation_1-logloss:0.29794
# [35]	validation_0-logloss:0.12647	validation_1-logloss:0.29499
# [36]	validation_0-logloss:0.12197	validation_1-logloss:0.29295
# [37]	validation_0-logloss:0.11784	validation_1-logloss:0.29043
# [38]	validation_0-logloss:0.11379	validation_1-logloss:0.28927
# [39]	validation_0-logloss:0.10994	validation_1-logloss:0.28578
# [40]	validation_0-logloss:0.10638	validation_1-logloss:0.28364
# [41]	validation_0-logloss:0.10302	validation_1-logloss:0.28183
# [42]	validation_0-logloss:0.09963	validation_1-logloss:0.28005
# [43]	validation_0-logloss:0.09649	validation_1-logloss:0.27972
# [44]	validation_0-logloss:0.09359	validation_1-logloss:0.27744
# [45]	validation_0-logloss:0.09080	validation_1-logloss:0.27542
# [46]	validation_0-logloss:0.08807	validation_1-logloss:0.27504
# [47]	validation_0-logloss:0.08541	validation_1-logloss:0.27458
# [48]	validation_0-logloss:0.08299	validation_1-logloss:0.27348
# [49]	validation_0-logloss:0.08035	validation_1-logloss:0.27247
# [50]	validation_0-logloss:0.07786	validation_1-logloss:0.27163
# [51]	validation_0-logloss:0.07550	validation_1-logloss:0.27094
# [52]	validation_0-logloss:0.07344	validation_1-logloss:0.26967
# [53]	validation_0-logloss:0.07147	validation_1-logloss:0.27008
# [54]	validation_0-logloss:0.06964	validation_1-logloss:0.26890
# [55]	validation_0-logloss:0.06766	validation_1-logloss:0.26854
# [56]	validation_0-logloss:0.06592	validation_1-logloss:0.26900
# [57]	validation_0-logloss:0.06433	validation_1-logloss:0.26790
# [58]	validation_0-logloss:0.06259	validation_1-logloss:0.26663
# [59]	validation_0-logloss:0.06107	validation_1-logloss:0.26743
# [60]	validation_0-logloss:0.05957	validation_1-logloss:0.26610
# [61]	validation_0-logloss:0.05817	validation_1-logloss:0.26644
# [62]	validation_0-logloss:0.05691	validation_1-logloss:0.26673
# [63]	validation_0-logloss:0.05550	validation_1-logloss:0.26550
# [64]	validation_0-logloss:0.05422	validation_1-logloss:0.26443
# [65]	validation_0-logloss:0.05311	validation_1-logloss:0.26500
# [66]	validation_0-logloss:0.05207	validation_1-logloss:0.26591
# [67]	validation_0-logloss:0.05093	validation_1-logloss:0.26501
# [68]	validation_0-logloss:0.04976	validation_1-logloss:0.26435
# [69]	validation_0-logloss:0.04872	validation_1-logloss:0.26360
# [70]	validation_0-logloss:0.04776	validation_1-logloss:0.26319
# [71]	validation_0-logloss:0.04680	validation_1-logloss:0.26255
# [72]	validation_0-logloss:0.04580	validation_1-logloss:0.26204
# [73]	validation_0-logloss:0.04484	validation_1-logloss:0.26254
# [74]	validation_0-logloss:0.04388	validation_1-logloss:0.26289
# [75]	validation_0-logloss:0.04309	validation_1-logloss:0.26249
# [76]	validation_0-logloss:0.04224	validation_1-logloss:0.26217
# [77]	validation_0-logloss:0.04133	validation_1-logloss:0.26166
# [78]	validation_0-logloss:0.04050	validation_1-logloss:0.26179
# [79]	validation_0-logloss:0.03967	validation_1-logloss:0.26103
# [80]	validation_0-logloss:0.03877	validation_1-logloss:0.26094
# [81]	validation_0-logloss:0.03806	validation_1-logloss:0.26148
# [82]	validation_0-logloss:0.03740	validation_1-logloss:0.26054
# [83]	validation_0-logloss:0.03676	validation_1-logloss:0.25967
# [84]	validation_0-logloss:0.03605	validation_1-logloss:0.25905
# [85]	validation_0-logloss:0.03545	validation_1-logloss:0.26007
# [86]	validation_0-logloss:0.03488	validation_1-logloss:0.25984
# [87]	validation_0-logloss:0.03425	validation_1-logloss:0.25933
# [88]	validation_0-logloss:0.03361	validation_1-logloss:0.25932
# [89]	validation_0-logloss:0.03311	validation_1-logloss:0.26002
# [90]	validation_0-logloss:0.03260	validation_1-logloss:0.25936
# [91]	validation_0-logloss:0.03202	validation_1-logloss:0.25886
# [92]	validation_0-logloss:0.03152	validation_1-logloss:0.25918
# [93]	validation_0-logloss:0.03107	validation_1-logloss:0.25865
# [94]	validation_0-logloss:0.03049	validation_1-logloss:0.25951
# [95]	validation_0-logloss:0.03007	validation_1-logloss:0.26091
# [96]	validation_0-logloss:0.02963	validation_1-logloss:0.26014
# [97]	validation_0-logloss:0.02913	validation_1-logloss:0.25974
# [98]	validation_0-logloss:0.02866	validation_1-logloss:0.25937
# [99]	validation_0-logloss:0.02829	validation_1-logloss:0.25893
# [100]	validation_0-logloss:0.02789	validation_1-logloss:0.25928
# [101]	validation_0-logloss:0.02751	validation_1-logloss:0.25955
# [102]	validation_0-logloss:0.02714	validation_1-logloss:0.25901
# [103]	validation_0-logloss:0.02668	validation_1-logloss:0.25991
# [104]	validation_0-logloss:0.02634	validation_1-logloss:0.25950
# [105]	validation_0-logloss:0.02594	validation_1-logloss:0.25924
# [106]	validation_0-logloss:0.02556	validation_1-logloss:0.25901
# [107]	validation_0-logloss:0.02522	validation_1-logloss:0.25738
# [108]	validation_0-logloss:0.02492	validation_1-logloss:0.25702
# [109]	validation_0-logloss:0.02453	validation_1-logloss:0.25789
# [110]	validation_0-logloss:0.02418	validation_1-logloss:0.25770
# [111]	validation_0-logloss:0.02384	validation_1-logloss:0.25842
# [112]	validation_0-logloss:0.02356	validation_1-logloss:0.25810
# [113]	validation_0-logloss:0.02322	validation_1-logloss:0.25848
# [114]	validation_0-logloss:0.02290	validation_1-logloss:0.25833
# [115]	validation_0-logloss:0.02260	validation_1-logloss:0.25820
# [116]	validation_0-logloss:0.02229	validation_1-logloss:0.25905
# [117]	validation_0-logloss:0.02204	validation_1-logloss:0.25878
# [118]	validation_0-logloss:0.02176	validation_1-logloss:0.25728
# [119]	validation_0-logloss:0.02149	validation_1-logloss:0.25722
# [120]	validation_0-logloss:0.02119	validation_1-logloss:0.25764
# [121]	validation_0-logloss:0.02095	validation_1-logloss:0.25761
# [122]	validation_0-logloss:0.02067	validation_1-logloss:0.25832
# [123]	validation_0-logloss:0.02045	validation_1-logloss:0.25808
# [124]	validation_0-logloss:0.02023	validation_1-logloss:0.25855
# [125]	validation_0-logloss:0.01998	validation_1-logloss:0.25714
# [126]	validation_0-logloss:0.01973	validation_1-logloss:0.25587
# [127]	validation_0-logloss:0.01946	validation_1-logloss:0.25640
# [128]	validation_0-logloss:0.01927	validation_1-logloss:0.25685
# [129]	validation_0-logloss:0.01908	validation_1-logloss:0.25665
# [130]	validation_0-logloss:0.01886	validation_1-logloss:0.25712
# [131]	validation_0-logloss:0.01863	validation_1-logloss:0.25609
# [132]	validation_0-logloss:0.01839	validation_1-logloss:0.25649
# [133]	validation_0-logloss:0.01816	validation_1-logloss:0.25789
# [134]	validation_0-logloss:0.01802	validation_1-logloss:0.25811
# [135]	validation_0-logloss:0.01785	validation_1-logloss:0.25794
# [136]	validation_0-logloss:0.01763	validation_1-logloss:0.25876
# [137]	validation_0-logloss:0.01748	validation_1-logloss:0.25884
# [138]	validation_0-logloss:0.01732	validation_1-logloss:0.25867
# [139]	validation_0-logloss:0.01719	validation_1-logloss:0.25876
# [140]	validation_0-logloss:0.01696	validation_1-logloss:0.25987
# [141]	validation_0-logloss:0.01681	validation_1-logloss:0.25960
# [142]	validation_0-logloss:0.01669	validation_1-logloss:0.25982
# [143]	validation_0-logloss:0.01656	validation_1-logloss:0.25992
# [144]	validation_0-logloss:0.01638	validation_1-logloss:0.26035
# [145]	validation_0-logloss:0.01623	validation_1-logloss:0.26055
# [146]	validation_0-logloss:0.01606	validation_1-logloss:0.26092
# [147]	validation_0-logloss:0.01589	validation_1-logloss:0.26137
# [148]	validation_0-logloss:0.01572	validation_1-logloss:0.25999
# [149]	validation_0-logloss:0.01557	validation_1-logloss:0.26028
# [150]	validation_0-logloss:0.01546	validation_1-logloss:0.26048
# [151]	validation_0-logloss:0.01531	validation_1-logloss:0.26142
# [152]	validation_0-logloss:0.01515	validation_1-logloss:0.26188
# [153]	validation_0-logloss:0.01501	validation_1-logloss:0.26227
# [154]	validation_0-logloss:0.01486	validation_1-logloss:0.26287
# [155]	validation_0-logloss:0.01476	validation_1-logloss:0.26299
# [156]	validation_0-logloss:0.01461	validation_1-logloss:0.26346
# [157]	validation_0-logloss:0.01448	validation_1-logloss:0.26379
# [158]	validation_0-logloss:0.01434	validation_1-logloss:0.26306
# [159]	validation_0-logloss:0.01424	validation_1-logloss:0.26237
# [160]	validation_0-logloss:0.01410	validation_1-logloss:0.26251
# [161]	validation_0-logloss:0.01401	validation_1-logloss:0.26265
# [162]	validation_0-logloss:0.01392	validation_1-logloss:0.26264
# [163]	validation_0-logloss:0.01380	validation_1-logloss:0.26250
# [164]	validation_0-logloss:0.01372	validation_1-logloss:0.26264
# [165]	validation_0-logloss:0.01359	validation_1-logloss:0.26255
# [166]	validation_0-logloss:0.01350	validation_1-logloss:0.26188
# [167]	validation_0-logloss:0.01342	validation_1-logloss:0.26203
# [168]	validation_0-logloss:0.01331	validation_1-logloss:0.26190
# [169]	validation_0-logloss:0.01319	validation_1-logloss:0.26184
# [170]	validation_0-logloss:0.01312	validation_1-logloss:0.26133
# [171]	validation_0-logloss:0.01304	validation_1-logloss:0.26148
# [172]	validation_0-logloss:0.01297	validation_1-logloss:0.26157
# [173]	validation_0-logloss:0.01285	validation_1-logloss:0.26253
# [174]	validation_0-logloss:0.01278	validation_1-logloss:0.26229
# [175]	validation_0-logloss:0.01267	validation_1-logloss:0.26086
# [176]	validation_0-logloss:0.01258	validation_1-logloss:0.26103

# %% [markdown]
# # 1.2.4 LightGBM
# - XGBoost보다 빠르다.
# - XGBoost보다 메모리 사용이 적다.
# - 카테고리형 피처의 자동 변환과 최적 분할

# %% [markdown]
# ## LightGBM 의 하이퍼 파라미터
#
# 앞서 설명했듯이 LightGBM은 리프 중심 트리 분할 방식을 이용해 트리의 깊이가 매우 깊어지기 때문에 max_depth에 대한 파라미터 설정이 중요합니다.
#
#
# ## 주요 파라미터
#
# - num_iteration [default=100] : 반복 수행하기 위한 트리의 개수 지정. 크게 지정할수록 예측 성능이 높아질 수 있지만 과적합 문제 가능성 또한 높아짐.
# - learning_rate [default=0.1] : 0~1 사이의 값을 지정해 부스팅 스텝을 반복적으로 수행할 때 업데이트 되는 학습률 값. 일반적으로 n_estimators를 크게하고 learning_rate을 작게 해서 예측 성능 향상 가능, 과적합 이슈 동반.
# - max_depth [default=-1]: 0보다 작은 값을 지정하면 깊이에 제한 없음.
# - min_data_in_leaf [default=20] : 결정 트리의 min_samples_leaf와 동일. 최종 결정 클래스인 리프 노드가 되기 위해 최소한으로 필요한 레코드 수. (과적합 방지용)
# - num_leaves [default=32] : 하나의 트리가 가질 수 있는 최대 리프 수
# - boosting [default=gbdt] : 부스팅 트리를 생성하는 알고리즘 (gbdt:일반적인 그래디언트 부스팅, rf:랜덤포레스트)
# - bagging_fraction [default=1.0] : 트리가 커져서 과적합 되는 것을 방지하기 위한 데이터 샘플링 비율.
# - feature_fraction [default=1.0] : 개별 트리를 학습할 때 무작위로 선택되는 피처의 비율 (GBM의 max_features와 동일)
# - lambda_I2 [default=0.0] : L2 regulation 제어를 위한 값. 피처 개수가 많을 경우 적용 검토. 값이 클수록 과적합 감소 효과
# - lambda_I1[default=0.0] : L1 regulation 제어를 위한 값. 과적합 방지용.
# ![image.png](attachment:image.png)
#
# ## Learning Task 파라미터¶
#
# - objective : 최솟값을 가져야 할 손실함수 정의. (회귀, 분류(다중, 이진) 문제에 따라 지정)
#
# ## 하이퍼 파라미터 튜닝 방안¶
#
# num_leaves의 개수를 중심으로 min_child_samples(min_data_in_leaf), max_depth를 함께 조정하는 것이 모델의 복잡도를 줄이는 가장 기본적인 튜닝 방식입니다.
#
#
# - num_leaves 는 개별 트리가 가질 수 있는 최대 리프의 개수를 지정합니다. (LightGBM 복잡도를 제어하는 주 파라미터) num_leaves가 클수록 모델의 깊이가 깊어지므로 모델 정확도가 높아질 수 있지만 과적합 문제가 발생할 확률 또한 높아집니다.
# - min_data_in_leaf(min_child_in_leaf)는 과적합 개선을 위해 사용되는 주 파라미터로 큰 값을 설정하는 경우 트리가 깊어지는 것을 방지합니다.
# - max_depth는 명시적으로 트리의 깊이를 제어하는 파라미터 입니다.

# %% [markdown]
# ## 사이킷런 래퍼 lightGBM 을 이용한 위스콘신 유방암 예측

# %%
from lightgbm import LGBMClassifier

import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

dataset = load_breast_cancer()

cancer_df = pd.DataFrame(data=dataset.data, columns= dataset.feature_names)
cancer_df['target'] = dataset.target

X=cancer_df.iloc[:, :-1]
y = cancer_df.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=156)

X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=156)

lgbm_wrapper = LGBMClassifier(n_estimators=400, learning_rate=0.05)

evals = [(X_tr, y_tr), (X_val, y_val)]
lgbm_wrapper.fit(X_tr, y_tr, early_stopping_rounds=50, eval_metric="logloss", eval_set=evals, verbose=False)
pred = lgbm_wrapper.predict(X_test)
pred_proba = lgbm_wrapper.predict_proba(X_test)[:, 1]

# %%
get_clf_eval(y_test, pred, pred_proba)
# Out:
# 오차행렬:
# [[34  3]
#  [ 2 75]]
#
# 정확도: 0.9561, 정밀도: 0.9615, 재현율: 0.974, f1 스코어: 0.9677, AUC: 0.9877

# %% [markdown]
# # 1.3 베이지안 최적화 기반의 HyperOpt를 이용한 하이퍼 파라미터 튜닝

# %% [markdown]
# 베이지안 최적화란 블랙박스 형태의 함수를 다룰 때 유용하다.
#
# 들어가는 변수(파라미터)에 대한 아웃풋의 변화를 아웃풋의 결과로만 알 수 있을 때 유용하게 사용될 수 있다. <br>
# 간단한 논리?는 반복을 통한 개선이다. <br>
# 관측을 통해서 다음에 들어올 변수를 추천하는 것이다.
#
# 앞선 gridsearch 를 사용하면 시간이 어어어어어어엄청나게 오래 걸리는걸 경험했다. 이럴 때 베이지안 최적화를 사용하면 될 것 같다.
#
# 근데 의문이 드는게 한가지 있다. 왜?? GBM, XGB, LGBM 머신러닝 식들이 블랙박스 형태일까?? 결국 식으로 이루어져 있을 것 같은데, 잘 이해가 안간다.

# %% [markdown]
# ## hyperopt 검색 공간

# %%
from hyperopt import hp

#-10 ~ 10 까지 1간격을 가지는 입력 변수 x와 -15~15까지 1간격으로 입력 변수 y 설정.
search_space = {'x':hp.quniform('x', -10, 10, 1), 'y':hp.quniform('y',-15,15,1)}

# %% [markdown]
# - hp.choice(label, options)
#
# Returns one of the options, which should be a list or tuple. The elements of options can themselves be [nested] stochastic expressions. In this case, the stochastic choices that only appear in some of the options become conditional parameters.
#
# - hp.randint(label, upper)
#
# Returns a random integer in the range [0, upper). The semantics of this distribution is that there is no more correlation in the loss function between nearby integer values, as compared with more distant integer values. This is an appropriate distribution for describing random seeds for example. If the loss function is probably more correlated for nearby integer values, then you should probably use one of the "quantized" continuous distributions, such as either quniform, qloguniform, qnormal or qlognormal.
#
# - hp.uniform(label, low, high)
#
# Returns a value uniformly between low and high.
# When optimizing, this variable is constrained to a two-sided interval.
#
# - hp.quniform(label, low, high, q)
#
# Returns a value like round(uniform(low, high) / q) * q
# Suitable for a discrete value with respect to which the objective is still somewhat "smooth", but which should be bounded both above and below.
#
# - hp.loguniform(label, low, high)
#
# Returns a value drawn according to exp(uniform(low, high)) so that the logarithm of the return value is uniformly distributed.
# When optimizing, this variable is constrained to the interval [exp(low), exp(high)].

# %% [markdown]
# ## hyperopt 목적 함수

# %% [markdown]
# 목적함수는 반드시 변수값과 검색 공간을 가지는 딕셔너리를 인자로 받고, 숫자형 단일값 또는 {'loss':retval, 'status':STATUS_OK} 형태의 딕셔너리를 리턴해야함.

# %%
from hyperopt import STATUS_OK

def objective_func(search_space):
    x = search_space['x']
    y = search_space['y']
    retval = x**2 - 20*y
    
    return retval

# %% [markdown]
# ## hyperopt::fmin()
# fmin(fn: 목적함수, space, algo(depault='TPE'), max_evals: 입력값 시도 횟수,trials: 입력값 및 목적 함수 반환값 결과를 저장/ Trials 클래스를 객체로 생성한 변수명 입력)

# %%
from hyperopt import fmin, tpe, Trials

trial_val = Trials()

best_01 = fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=5, trials=trial_val, rstate=np.random.default_rng(seed=0))

print("best", best_01)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 250.69trial/s, best loss: -224.0]
# best {'x': -4.0, 'y': 12.0}

# %%
trial_val = Trials()

best_02 = fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=20, trials=trial_val, rstate=np.random.default_rng(seed=0))

print("best", best_02)
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 418.60trial/s, best loss: -296.0]
# best {'x': 2.0, 'y': 15.0}

# %% [markdown]
# ## Trials 객체의 구조
# - result: [{'loss':함수 반환값, 'status':반환 상태값}] = 함수의 반복 수행 시마다 반환되는 반환값
# - vals: {'입력변수명': 개별 수행 시마다 입력된 값 리스트}  = 함수의 반복수행 시마다 입력되는 입력 변숫값

# %%
print(trial_val.results)
print(trial_val.vals)
# Out:
# [{'loss': -64.0, 'status': 'ok'}, {'loss': -184.0, 'status': 'ok'}, {'loss': 56.0, 'status': 'ok'}, {'loss': -224.0, 'status': 'ok'}, {'loss': 61.0, 'status': 'ok'}, {'loss': -296.0, 'status': 'ok'}, {'loss': -40.0, 'status': 'ok'}, {'loss': 281.0, 'status': 'ok'}, {'loss': 64.0, 'status': 'ok'}, {'loss': 100.0, 'status': 'ok'}, {'loss': 60.0, 'status': 'ok'}, {'loss': -39.0, 'status': 'ok'}, {'loss': 1.0, 'status': 'ok'}, {'loss': -164.0, 'status': 'ok'}, {'loss': 21.0, 'status': 'ok'}, {'loss': -56.0, 'status': 'ok'}, {'loss': 284.0, 'status': 'ok'}, {'loss': 176.0, 'status': 'ok'}, {'loss': -171.0, 'status': 'ok'}, {'loss': 0.0, 'status': 'ok'}]
# {'x': [-6.0, -4.0, 4.0, -4.0, 9.0, 2.0, 10.0, -9.0, -8.0, -0.0, -0.0, 1.0, 9.0, 6.0, 9.0, 2.0, -2.0, -4.0, 7.0, -0.0], 'y': [5.0, 10.0, -2.0, 12.0, 1.0, 15.0, 7.0, -10.0, 0.0, -5.0, -3.0, 2.0, 4.0, 10.0, 3.0, 3.0, -14.0, -8.0, 11.0, -0.0]}

# %%
import pandas as pd
losses = [loss_dict['loss'] for loss_dict in trial_val.results]

result_df = pd.DataFrame({'x': trial_val.vals['x'], 'y':trial_val.vals['y'], 'losses':losses})
result_df
# Out:
#        x     y  losses
# 0   -6.0   5.0   -64.0
# 1   -4.0  10.0  -184.0
# 2    4.0  -2.0    56.0
# 3   -4.0  12.0  -224.0
# 4    9.0   1.0    61.0
# 5    2.0  15.0  -296.0
# 6   10.0   7.0   -40.0
# 7   -9.0 -10.0   281.0
# 8   -8.0   0.0    64.0
# 9   -0.0  -5.0   100.0
# 10  -0.0  -3.0    60.0
# 11   1.0   2.0   -39.0
# 12   9.0   4.0     1.0
# 13   6.0  10.0  -164.0
# 14   9.0   3.0    21.0
# 15   2.0   3.0   -56.0
# 16  -2.0 -14.0   284.0
# 17  -4.0  -8.0   176.0
# 18   7.0  11.0  -171.0
# 19  -0.0  -0.0     0.0

# %% [markdown]
# # HyperOpt를 이용한 XGBoost 하이퍼 파라미터 최적화

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=156)
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=156)

# %%
from hyperopt import hp

xgb_search_space = {'max_depth': hp.quniform('max_depth', 5, 20, 1),
                   'min_child_weight': hp.quniform('min_child_weight', 1, 2, 1),
                   'learning_rate': hp.uniform('learning_rate', 0.01, 2), 
                   'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1)} #uniform: 정규분포

# %% [markdown]
# ## 유의사항
# 1. 검색 공간에서 목적 함수로 입력되는 모든 인자들은 실수형 값이므로 이들을 XGBoostClassifier의 정수형 하이퍼 파라미터값으로 설정할 떄는 정수형으로 형변환을 해야함. ex) XGBoostClassifier(max_depth=int(search_space['max_depth'])
# 2. fmin을 사용하기 때문에 정확도같이 값이 클수록 좋은 성능 지표일 경우 -1를 곱한 뒤 반환해야 한다.

# %%
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from hyperopt import STATUS_OK

def objective_func(search_space):
    xgb_clf = XGBClassifier(n_estimators=100, max_depth=int(search_space['max_depth']),
                           min_child_weight=int(search_space['min_child_weight']),
                           learning_rate=(search_space['learning_rate']),
                           colsample_bytree=search_space['colsample_bytree'],
                           eval_metric='logloss')
    accuracy = cross_val_score(xgb_clf, X_train, y_train, scoring='accuracy', cv=3)
    
    return {'loss':-1*np.mean(accuracy), 'status': STATUS_OK}

# %%
from hyperopt import fmin, tpe, Trials

trial_val = Trials()
best = fmin(fn=objective_func,
           space=xgb_search_space,
           algo=tpe.suggest,
           max_evals=50,
           trials=trial_val, rstate=np.random.default_rng(seed=9))
print('best: ',best)
# Out:
# 100%|██████████| 50/50 [00:27<00:00,  1.82trial/s, best loss: -0.9780411293133495]
# best:  {'colsample_bytree': 0.5267585221196857, 'learning_rate': 0.7962636421852388, 'max_depth': 8.0, 'min_child_weight': 1.0}

# %% [markdown]
# # 1.4 캐글 산탄데르 고객 만족 예측

# %% [markdown]
# ## 1.4.1 데이터전처리

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

cust_df = pd.read_csv('train_santander.csv',encoding='latin-1')

# %%
cust_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76020 entries, 0 to 76019
# Columns: 371 entries, ID to TARGET
# dtypes: float64(111), int64(260)
# memory usage: 215.2 MB

# %%
cust_df['TARGET'].value_counts()
#unsatisfied 비율은 0.04%
# Out:
# 0    73012
# 1     3008
# Name: TARGET, dtype: int64

# %%
cust_df.describe()
# Out:
#                   ID           var3         var15  imp_ent_var16_ult1  \
# count   76020.000000   76020.000000  76020.000000        76020.000000
# mean    75964.050723   -1523.199277     33.212865           86.208265
# std     43781.947379   39033.462364     12.956486         1614.757313
# min         1.000000 -999999.000000      5.000000            0.000000
# 25%     38104.750000       2.000000     23.000000            0.000000
# 50%     76043.000000       2.000000     28.000000            0.000000
# 75%    113748.750000       2.000000     40.000000            0.000000
# max    151838.000000     238.000000    105.000000       210000.000000
#
#        imp_op_var39_comer_ult1  imp_op_var39_comer_ult3  \
# count             76020.000000             76020.000000
# mean                 72.363067               119.529632
# std                 339.315831               546.266294
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max               12888.030000             21024.810000
#
#        imp_op_var40_comer_ult1  imp_op_var40_comer_ult3  \
# count             76020.000000             76020.000000
# mean                  3.559130                 6.472698
# std                  93.155749               153.737066
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                8237.820000             11073.570000
#
#        imp_op_var40_efect_ult1  imp_op_var40_efect_ult3  ...  \
# count             76020.000000             76020.000000  ...
# mean                  0.412946                 0.567352  ...
# std                  30.604864                36.513513  ...
# min                   0.000000                 0.000000  ...
# 25%                   0.000000                 0.000000  ...
# 50%                   0.000000                 0.000000  ...
# 75%                   0.000000                 0.000000  ...
# max                6600.000000              6600.000000  ...
#
#        saldo_medio_var33_hace2  saldo_medio_var33_hace3  \
# count             76020.000000             76020.000000
# mean                  7.935824                 1.365146
# std                 455.887218               113.959637
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max               50003.880000             20385.720000
#
#        saldo_medio_var33_ult1  saldo_medio_var33_ult3  \
# count            76020.000000            76020.000000
# mean                12.215580                8.784074
# std                783.207399              538.439211
# min                  0.000000                0.000000
# 25%                  0.000000                0.000000
# 50%                  0.000000                0.000000
# 75%                  0.000000                0.000000
# max             138831.630000            91778.730000
#
#        saldo_medio_var44_hace2  saldo_medio_var44_hace3  \
# count             76020.000000             76020.000000
# mean                 31.505324                 1.858575
# std                2013.125393               147.786584
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max              438329.220000             24650.010000
#
#        saldo_medio_var44_ult1  saldo_medio_var44_ult3         var38  \
# count            76020.000000            76020.000000  7.602000e+04
# mean                76.026165               56.614351  1.172358e+05
# std               4040.337842             2852.579397  1.826646e+05
# min                  0.000000                0.000000  5.163750e+03
# 25%                  0.000000                0.000000  6.787061e+04
# 50%                  0.000000                0.000000  1.064092e+05
# 75%                  0.000000                0.000000  1.187563e+05
# max             681462.900000           397884.300000  2.203474e+07
#
#              TARGET
# count  76020.000000
# mean       0.039569
# std        0.194945
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 371 columns]

# %% [markdown]
# - 99999는 이상한 값인 것 같다.

# %%
print(cust_df['var3'].value_counts()[:3])
# Out:
#  2         74165
#  8           138
# -999999      116
# Name: var3, dtype: int64

# %%
cust_df['var3'].replace(-999999, 2, inplace=True)

X_features = cust_df.iloc[:,:-1]
y_labels = cust_df.iloc[:, -1]
print("피처 데이터 크기: ",X_features.shape)
# Out:
# 피처 데이터 크기:  (76020, 370)

# %% [markdown]
# - train test 셋 분리. 비대칭적 데이터셋이므로 비율에 맞게 분리되었는지 판단하기

# %%
X_train,X_test, y_train, y_test = train_test_split(X_features, y_labels, test_size=0.2, random_state=0)

print("test셋 분포 비: \n")
print(y_test.value_counts()/y_test.count())
print("\ntrain셋 분포 비: \n")
print(y_train.value_counts()/y_train.count())
# Out:
# test셋 분포 비:
#
# 0    0.9583
# 1    0.0417
# Name: TARGET, dtype: float64
#
# train셋 분포 비:
#
# 0    0.960964
# 1    0.039036
# Name: TARGET, dtype: float64

# %% [markdown]
# - 조기중단을 위해서 검증셋 만들기

# %%
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=0)

# %% [markdown]
# ## 1.4.2 XGBoost 모델학습, 하이퍼 파라미터 튜닝

# %%
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score

xgb_clf = XGBClassifier(n_estimators=500, learning_rate=0.05, random_state=156)
xgb_clf.fit(X_tr, y_tr,  early_stopping_rounds=100, eval_metric='auc', eval_set=[(X_tr, y_tr),(X_val,y_val)])

xgb_roc_score = roc_auc_score(y_test, xgb_clf.predict_proba(X_test)[:,1])
print('ROC AUC:{0:.4f}'.format(xgb_roc_score))
# Out:
# [0]	validation_0-auc:0.82178	validation_1-auc:0.80117
# [1]	validation_0-auc:0.83011	validation_1-auc:0.80957
# [2]	validation_0-auc:0.83182	validation_1-auc:0.80969
# [3]	validation_0-auc:0.83270	validation_1-auc:0.80948
# [4]	validation_0-auc:0.83393	validation_1-auc:0.80979
# [5]	validation_0-auc:0.83486	validation_1-auc:0.80945
# [6]	validation_0-auc:0.83583	validation_1-auc:0.81030
# [7]	validation_0-auc:0.83858	validation_1-auc:0.81193
# [8]	validation_0-auc:0.83891	validation_1-auc:0.81395
# [9]	validation_0-auc:0.83954	validation_1-auc:0.81432
# [10]	validation_0-auc:0.83920	validation_1-auc:0.81371
# [11]	validation_0-auc:0.83920	validation_1-auc:0.81344
# [12]	validation_0-auc:0.84017	validation_1-auc:0.81407
# [13]	validation_0-auc:0.84040	validation_1-auc:0.81401
# [14]	validation_0-auc:0.84071	validation_1-auc:0.81399
# [15]	validation_0-auc:0.84279	validation_1-auc:0.81586
# [16]	validation_0-auc:0.84306	validation_1-auc:0.81606
# [17]	validation_0-auc:0.84366	validation_1-auc:0.81638
# [18]	validation_0-auc:0.84432	validation_1-auc:0.81626
# [19]	validation_0-auc:0.84634	validation_1-auc:0.81674
# [20]	validation_0-auc:0.84670	validation_1-auc:0.81683
# [21]	validation_0-auc:0.84733	validation_1-auc:0.81727
# [22]	validation_0-auc:0.84789	validation_1-auc:0.81711
# [23]	validation_0-auc:0.84812	validation_1-auc:0.81725
# [24]	validation_0-auc:0.84879	validation_1-auc:0.81705
# [25]	validation_0-auc:0.84937	validation_1-auc:0.81701
# [26]	validation_0-auc:0.85162	validation_1-auc:0.81811
# [27]	validation_0-auc:0.85254	validation_1-auc:0.81838
# [28]	validation_0-auc:0.85354	validation_1-auc:0.81876
# [29]	validation_0-auc:0.85517	validation_1-auc:0.81975
# [30]	validation_0-auc:0.85725	validation_1-auc:0.82148
# [31]	validation_0-auc:0.85800	validation_1-auc:0.82164
# [32]	validation_0-auc:0.85845	validation_1-auc:0.82232
# [33]	validation_0-auc:0.85915	validation_1-auc:0.82290
# [34]	validation_0-auc:0.85958	validation_1-auc:0.82337
# [35]	validation_0-auc:0.86044	validation_1-auc:0.82361
# [36]	validation_0-auc:0.86097	validation_1-auc:0.82436
# [37]	validation_0-auc:0.86190	validation_1-auc:0.82489
# [38]	validation_0-auc:0.86232	validation_1-auc:0.82558
# [39]	validation_0-auc:0.86304	validation_1-auc:0.82571
# [40]	validation_0-auc:0.86365	validation_1-auc:0.82613
# [41]	validation_0-auc:0.86446	validation_1-auc:0.82660
# [42]	validation_0-auc:0.86557	validation_1-auc:0.82667
# [43]	validation_0-auc:0.86663	validation_1-auc:0.82686
# [44]	validation_0-auc:0.86752	validation_1-auc:0.82761
# [45]	validation_0-auc:0.86797	validation_1-auc:0.82764
# [46]	validation_0-auc:0.86900	validation_1-auc:0.82803
# [47]	validation_0-auc:0.86956	validation_1-auc:0.82815
# [48]	validation_0-auc:0.87017	validation_1-auc:0.82863
# [49]	validation_0-auc:0.87073	validation_1-auc:0.82873
# [50]	validation_0-auc:0.87153	validation_1-auc:0.82936
# [51]	validation_0-auc:0.87231	validation_1-auc:0.82916
# [52]	validation_0-auc:0.87257	validation_1-auc:0.82911
# [53]	validation_0-auc:0.87314	validation_1-auc:0.82940
# [54]	validation_0-auc:0.87380	validation_1-auc:0.83014
# [55]	validation_0-auc:0.87439	validation_1-auc:0.83016
# [56]	validation_0-auc:0.87484	validation_1-auc:0.83074
# [57]	validation_0-auc:0.87528	validation_1-auc:0.83075
# [58]	validation_0-auc:0.87586	validation_1-auc:0.83101
# [59]	validation_0-auc:0.87645	validation_1-auc:0.83142
# [60]	validation_0-auc:0.87700	validation_1-auc:0.83142
# [61]	validation_0-auc:0.87788	validation_1-auc:0.83167
# [62]	validation_0-auc:0.87835	validation_1-auc:0.83155
# [63]	validation_0-auc:0.87902	validation_1-auc:0.83171
# [64]	validation_0-auc:0.87972	validation_1-auc:0.83198
# [65]	validation_0-auc:0.88029	validation_1-auc:0.83201
# [66]	validation_0-auc:0.88096	validation_1-auc:0.83238
# [67]	validation_0-auc:0.88169	validation_1-auc:0.83223
# [68]	validation_0-auc:0.88227	validation_1-auc:0.83254
# [69]	validation_0-auc:0.88258	validation_1-auc:0.83274
# [70]	validation_0-auc:0.88309	validation_1-auc:0.83278
# [71]	validation_0-auc:0.88357	validation_1-auc:0.83267
# [72]	validation_0-auc:0.88409	validation_1-auc:0.83264
# [73]	validation_0-auc:0.88448	validation_1-auc:0.83279
# [74]	validation_0-auc:0.88495	validation_1-auc:0.83271
# [75]	validation_0-auc:0.88541	validation_1-auc:0.83257
# [76]	validation_0-auc:0.88620	validation_1-auc:0.83278
# [77]	validation_0-auc:0.88692	validation_1-auc:0.83286
# [78]	validation_0-auc:0.88733	validation_1-auc:0.83294
# [79]	validation_0-auc:0.88763	validation_1-auc:0.83310
# [80]	validation_0-auc:0.88805	validation_1-auc:0.83308
# [81]	validation_0-auc:0.88885	validation_1-auc:0.83319
# [82]	validation_0-auc:0.88933	validation_1-auc:0.83313
# [83]	validation_0-auc:0.88977	validation_1-auc:0.83315
# [84]	validation_0-auc:0.89012	validation_1-auc:0.83330
# [85]	validation_0-auc:0.89056	validation_1-auc:0.83323
# [86]	validation_0-auc:0.89092	validation_1-auc:0.83315
# [87]	validation_0-auc:0.89134	validation_1-auc:0.83301
# [88]	validation_0-auc:0.89191	validation_1-auc:0.83297
# [89]	validation_0-auc:0.89230	validation_1-auc:0.83298
# [90]	validation_0-auc:0.89306	validation_1-auc:0.83283
# [91]	validation_0-auc:0.89351	validation_1-auc:0.83283
# [92]	validation_0-auc:0.89388	validation_1-auc:0.83265
# [93]	validation_0-auc:0.89421	validation_1-auc:0.83251
# [94]	validation_0-auc:0.89449	validation_1-auc:0.83236
# [95]	validation_0-auc:0.89481	validation_1-auc:0.83235
# [96]	validation_0-auc:0.89512	validation_1-auc:0.83247
# [97]	validation_0-auc:0.89543	validation_1-auc:0.83271
# [98]	validation_0-auc:0.89576	validation_1-auc:0.83271
# [99]	validation_0-auc:0.89614	validation_1-auc:0.83269
# [100]	validation_0-auc:0.89640	validation_1-auc:0.83269
# [101]	validation_0-auc:0.89673	validation_1-auc:0.83251
# [102]	validation_0-auc:0.89716	validation_1-auc:0.83267
# [103]	validation_0-auc:0.89737	validation_1-auc:0.83268
# [104]	validation_0-auc:0.89766	validation_1-auc:0.83274
# [105]	validation_0-auc:0.89794	validation_1-auc:0.83287
# [106]	validation_0-auc:0.89850	validation_1-auc:0.83302
# [107]	validation_0-auc:0.89880	validation_1-auc:0.83297
# [108]	validation_0-auc:0.89914	validation_1-auc:0.83310
# [109]	validation_0-auc:0.89962	validation_1-auc:0.83312
# [110]	validation_0-auc:0.89990	validation_1-auc:0.83314
# [111]	validation_0-auc:0.90021	validation_1-auc:0.83317
# [112]	validation_0-auc:0.90035	validation_1-auc:0.83322
# [113]	validation_0-auc:0.90068	validation_1-auc:0.83322
# [114]	validation_0-auc:0.90092	validation_1-auc:0.83319
# [115]	validation_0-auc:0.90121	validation_1-auc:0.83310
# [116]	validation_0-auc:0.90141	validation_1-auc:0.83315
# [117]	validation_0-auc:0.90155	validation_1-auc:0.83308
# [118]	validation_0-auc:0.90191	validation_1-auc:0.83314
# [119]	validation_0-auc:0.90202	validation_1-auc:0.83322
# [120]	validation_0-auc:0.90222	validation_1-auc:0.83328
# [121]	validation_0-auc:0.90279	validation_1-auc:0.83348
# [122]	validation_0-auc:0.90306	validation_1-auc:0.83351
# [123]	validation_0-auc:0.90363	validation_1-auc:0.83340
# [124]	validation_0-auc:0.90387	validation_1-auc:0.83335
# [125]	validation_0-auc:0.90429	validation_1-auc:0.83340
# [126]	validation_0-auc:0.90443	validation_1-auc:0.83355
# [127]	validation_0-auc:0.90493	validation_1-auc:0.83350
# [128]	validation_0-auc:0.90519	validation_1-auc:0.83365
# [129]	validation_0-auc:0.90530	validation_1-auc:0.83355
# [130]	validation_0-auc:0.90552	validation_1-auc:0.83364
# [131]	validation_0-auc:0.90571	validation_1-auc:0.83360
# [132]	validation_0-auc:0.90573	validation_1-auc:0.83366
# [133]	validation_0-auc:0.90621	validation_1-auc:0.83369
# [134]	validation_0-auc:0.90644	validation_1-auc:0.83368
# [135]	validation_0-auc:0.90648	validation_1-auc:0.83371
# [136]	validation_0-auc:0.90673	validation_1-auc:0.83368
# [137]	validation_0-auc:0.90688	validation_1-auc:0.83374
# [138]	validation_0-auc:0.90725	validation_1-auc:0.83378
# [139]	validation_0-auc:0.90748	validation_1-auc:0.83382
# [140]	validation_0-auc:0.90754	validation_1-auc:0.83381
# [141]	validation_0-auc:0.90766	validation_1-auc:0.83381
# [142]	validation_0-auc:0.90805	validation_1-auc:0.83380
# [143]	validation_0-auc:0.90838	validation_1-auc:0.83388
# [144]	validation_0-auc:0.90864	validation_1-auc:0.83391
# [145]	validation_0-auc:0.90873	validation_1-auc:0.83393
# [146]	validation_0-auc:0.90880	validation_1-auc:0.83388
# [147]	validation_0-auc:0.90882	validation_1-auc:0.83393
# [148]	validation_0-auc:0.90922	validation_1-auc:0.83391
# [149]	validation_0-auc:0.90927	validation_1-auc:0.83398
# [150]	validation_0-auc:0.90939	validation_1-auc:0.83408
# [151]	validation_0-auc:0.90953	validation_1-auc:0.83403
# [152]	validation_0-auc:0.90958	validation_1-auc:0.83399
# [153]	validation_0-auc:0.90969	validation_1-auc:0.83403
# [154]	validation_0-auc:0.90978	validation_1-auc:0.83403
# [155]	validation_0-auc:0.90996	validation_1-auc:0.83410
# [156]	validation_0-auc:0.91009	validation_1-auc:0.83405
# [157]	validation_0-auc:0.91024	validation_1-auc:0.83402
# [158]	validation_0-auc:0.91030	validation_1-auc:0.83408
# [159]	validation_0-auc:0.91033	validation_1-auc:0.83410
# [160]	validation_0-auc:0.91039	validation_1-auc:0.83412
# [161]	validation_0-auc:0.91046	validation_1-auc:0.83413
# [162]	validation_0-auc:0.91059	validation_1-auc:0.83410
# [163]	validation_0-auc:0.91071	validation_1-auc:0.83415
# [164]	validation_0-auc:0.91077	validation_1-auc:0.83411
# [165]	validation_0-auc:0.91082	validation_1-auc:0.83412
# [166]	validation_0-auc:0.91114	validation_1-auc:0.83425
# [167]	validation_0-auc:0.91125	validation_1-auc:0.83423
# [168]	validation_0-auc:0.91158	validation_1-auc:0.83421
# [169]	validation_0-auc:0.91163	validation_1-auc:0.83420
# [170]	validation_0-auc:0.91188	validation_1-auc:0.83422
# [171]	validation_0-auc:0.91196	validation_1-auc:0.83425
# [172]	validation_0-auc:0.91199	validation_1-auc:0.83419
# [173]	validation_0-auc:0.91207	validation_1-auc:0.83413
# [174]	validation_0-auc:0.91234	validation_1-auc:0.83406
# [175]	validation_0-auc:0.91240	validation_1-auc:0.83407
# [176]	validation_0-auc:0.91242	validation_1-auc:0.83416
# [177]	validation_0-auc:0.91260	validation_1-auc:0.83411
# [178]	validation_0-auc:0.91287	validation_1-auc:0.83409
# [179]	validation_0-auc:0.91293	validation_1-auc:0.83404
# [180]	validation_0-auc:0.91300	validation_1-auc:0.83408
# [181]	validation_0-auc:0.91310	validation_1-auc:0.83408
# [182]	validation_0-auc:0.91324	validation_1-auc:0.83417
# [183]	validation_0-auc:0.91330	validation_1-auc:0.83417
# [184]	validation_0-auc:0.91334	validation_1-auc:0.83409
# [185]	validation_0-auc:0.91368	validation_1-auc:0.83391
# [186]	validation_0-auc:0.91387	validation_1-auc:0.83388
# [187]	validation_0-auc:0.91399	validation_1-auc:0.83381
# [188]	validation_0-auc:0.91410	validation_1-auc:0.83378
# [189]	validation_0-auc:0.91414	validation_1-auc:0.83380
# [190]	validation_0-auc:0.91423	validation_1-auc:0.83384
# [191]	validation_0-auc:0.91434	validation_1-auc:0.83380
# [192]	validation_0-auc:0.91444	validation_1-auc:0.83384
# [193]	validation_0-auc:0.91471	validation_1-auc:0.83378
# [194]	validation_0-auc:0.91474	validation_1-auc:0.83377
# [195]	validation_0-auc:0.91481	validation_1-auc:0.83369
# [196]	validation_0-auc:0.91490	validation_1-auc:0.83364
# [197]	validation_0-auc:0.91500	validation_1-auc:0.83363
# [198]	validation_0-auc:0.91505	validation_1-auc:0.83365
# [199]	validation_0-auc:0.91514	validation_1-auc:0.83363
# [200]	validation_0-auc:0.91517	validation_1-auc:0.83360
# [201]	validation_0-auc:0.91524	validation_1-auc:0.83360
# [202]	validation_0-auc:0.91561	validation_1-auc:0.83372
# [203]	validation_0-auc:0.91571	validation_1-auc:0.83367
# [204]	validation_0-auc:0.91577	validation_1-auc:0.83366
# [205]	validation_0-auc:0.91590	validation_1-auc:0.83356
# [206]	validation_0-auc:0.91595	validation_1-auc:0.83356
# [207]	validation_0-auc:0.91607	validation_1-auc:0.83346
# [208]	validation_0-auc:0.91614	validation_1-auc:0.83344
# [209]	validation_0-auc:0.91621	validation_1-auc:0.83350
# [210]	validation_0-auc:0.91639	validation_1-auc:0.83344
# [211]	validation_0-auc:0.91660	validation_1-auc:0.83344
# [212]	validation_0-auc:0.91664	validation_1-auc:0.83339
# [213]	validation_0-auc:0.91669	validation_1-auc:0.83341
# [214]	validation_0-auc:0.91724	validation_1-auc:0.83338
# [215]	validation_0-auc:0.91742	validation_1-auc:0.83332
# [216]	validation_0-auc:0.91749	validation_1-auc:0.83331
# [217]	validation_0-auc:0.91754	validation_1-auc:0.83329
# [218]	validation_0-auc:0.91756	validation_1-auc:0.83332
# [219]	validation_0-auc:0.91769	validation_1-auc:0.83335
# [220]	validation_0-auc:0.91772	validation_1-auc:0.83334
# [221]	validation_0-auc:0.91777	validation_1-auc:0.83335
# [222]	validation_0-auc:0.91779	validation_1-auc:0.83331
# [223]	validation_0-auc:0.91803	validation_1-auc:0.83327
# [224]	validation_0-auc:0.91808	validation_1-auc:0.83325
# [225]	validation_0-auc:0.91821	validation_1-auc:0.83307
# [226]	validation_0-auc:0.91827	validation_1-auc:0.83305
# [227]	validation_0-auc:0.91830	validation_1-auc:0.83304
# [228]	validation_0-auc:0.91841	validation_1-auc:0.83308
# [229]	validation_0-auc:0.91852	validation_1-auc:0.83292
# [230]	validation_0-auc:0.91869	validation_1-auc:0.83293
# [231]	validation_0-auc:0.91875	validation_1-auc:0.83287
# [232]	validation_0-auc:0.91890	validation_1-auc:0.83294
# [233]	validation_0-auc:0.91915	validation_1-auc:0.83304
# [234]	validation_0-auc:0.91930	validation_1-auc:0.83301
# [235]	validation_0-auc:0.91934	validation_1-auc:0.83298
# [236]	validation_0-auc:0.91944	validation_1-auc:0.83300
# [237]	validation_0-auc:0.91950	validation_1-auc:0.83304
# [238]	validation_0-auc:0.91954	validation_1-auc:0.83303
# [239]	validation_0-auc:0.91958	validation_1-auc:0.83298
# [240]	validation_0-auc:0.91961	validation_1-auc:0.83301
# [241]	validation_0-auc:0.91979	validation_1-auc:0.83290
# [242]	validation_0-auc:0.91982	validation_1-auc:0.83291
# [243]	validation_0-auc:0.91987	validation_1-auc:0.83292
# [244]	validation_0-auc:0.91993	validation_1-auc:0.83290
# [245]	validation_0-auc:0.91999	validation_1-auc:0.83286
# [246]	validation_0-auc:0.92007	validation_1-auc:0.83286
# [247]	validation_0-auc:0.92012	validation_1-auc:0.83285
# [248]	validation_0-auc:0.92014	validation_1-auc:0.83285
# [249]	validation_0-auc:0.92018	validation_1-auc:0.83279
# [250]	validation_0-auc:0.92026	validation_1-auc:0.83284
# [251]	validation_0-auc:0.92035	validation_1-auc:0.83277
# [252]	validation_0-auc:0.92042	validation_1-auc:0.83271
# [253]	validation_0-auc:0.92064	validation_1-auc:0.83266
# [254]	validation_0-auc:0.92065	validation_1-auc:0.83264
# [255]	validation_0-auc:0.92069	validation_1-auc:0.83263
# [256]	validation_0-auc:0.92090	validation_1-auc:0.83266
# [257]	validation_0-auc:0.92094	validation_1-auc:0.83261
# [258]	validation_0-auc:0.92115	validation_1-auc:0.83255
# [259]	validation_0-auc:0.92134	validation_1-auc:0.83248
# [260]	validation_0-auc:0.92140	validation_1-auc:0.83248
# [261]	validation_0-auc:0.92144	validation_1-auc:0.83249
# [262]	validation_0-auc:0.92150	validation_1-auc:0.83249
# [263]	validation_0-auc:0.92159	validation_1-auc:0.83246
# [264]	validation_0-auc:0.92195	validation_1-auc:0.83242
# [265]	validation_0-auc:0.92196	validation_1-auc:0.83241
# [266]	validation_0-auc:0.92201	validation_1-auc:0.83242
# ROC AUC:0.8416

# %% [markdown]
# - 베이지안 최적화를 통한 하이퍼 파라미터 튜닝

# %%
from hyperopt import hp
xgb_search_space={'max_depth':hp.quniform('max_depth',5, 15, 1),
                  'min_child_weight':hp.quniform('min_chile_weight', 1, 6, 1),
                  'colsample_bytree':hp.uniform('colsample_bytree', 0.5, 0.95),
                  'learning_rate':hp.uniform('learning_rate', 0.01, 0.2)}

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score

def objective_func(search_space):
    xgb_clf = XGBClassifier(n_estimators=100, max_depth=int(search_space['max_depth']),
                           min_child_weight=int(search_space['min_child_weight']),
                           colsample_bytree=search_space['colsample_bytree'],
                            learning_rate=search_space['learning_rate'])
    roc_auc_list= []
    skf = StratifiedKFold(n_splits=3)
    
    for tr_index, val_index in skf.split(X_train, y_train):
        X_tr, y_tr = X_train.iloc[tr_index], y_train.iloc[tr_index]
        X_val, y_val = X_train.iloc[val_index], y_train.iloc[val_index]
        
        xgb_clf.fit(X_tr, y_tr, early_stopping_rounds=30, eval_metric='auc', eval_set=[(X_tr, y_tr),(X_val,y_val)], )
        
        score = roc_auc_score(y_val, xgb_clf.predict_proba(X_val)[:,1])
        roc_auc_list.append(score)
    return -1*np.mean(roc_auc_list)

# %%
from hyperopt import fmin, tpe, Trials

trials = Trials()

best = fmin(fn=objective_func,
           space=xgb_search_space,
           algo=tpe.suggest,
           max_evals=5,
           trials=trials,rstate=np.random.default_rng(seed=30))
print(best)
# Out:
# [0]	validation_0-auc:0.82206	validation_1-auc:0.79877
# [1]	validation_0-auc:0.82652	validation_1-auc:0.80316
# [2]	validation_0-auc:0.83272	validation_1-auc:0.80504
# [3]	validation_0-auc:0.83454	validation_1-auc:0.80676
# [4]	validation_0-auc:0.83845	validation_1-auc:0.80983
# [5]	validation_0-auc:0.84040	validation_1-auc:0.81326
# [6]	validation_0-auc:0.84123	validation_1-auc:0.81375
# [7]	validation_0-auc:0.84264	validation_1-auc:0.81540
# [8]	validation_0-auc:0.84363	validation_1-auc:0.81517
# [9]	validation_0-auc:0.84494	validation_1-auc:0.81530
# [10]	validation_0-auc:0.84605	validation_1-auc:0.81592
# [11]	validation_0-auc:0.84620	validation_1-auc:0.81522
# [12]	validation_0-auc:0.84669	validation_1-auc:0.81515
# [13]	validation_0-auc:0.84774	validation_1-auc:0.81602
# [14]	validation_0-auc:0.84913	validation_1-auc:0.81687
# [15]	validation_0-auc:0.85231	validation_1-auc:0.81905
# [16]	validation_0-auc:0.85311	validation_1-auc:0.82027
# [17]	validation_0-auc:0.85497	validation_1-auc:0.82379
# [18]	validation_0-auc:0.85627	validation_1-auc:0.82565
# [19]	validation_0-auc:0.85753	validation_1-auc:0.82629
# [20]	validation_0-auc:0.85854	validation_1-auc:0.82602
# [21]	validation_0-auc:0.86118	validation_1-auc:0.82757
# [22]	validation_0-auc:0.86227	validation_1-auc:0.82730
# [23]	validation_0-auc:0.86399	validation_1-auc:0.82787
# [24]	validation_0-auc:0.86502	validation_1-auc:0.82815
# [25]	validation_0-auc:0.86603	validation_1-auc:0.82810
# [26]	validation_0-auc:0.86684	validation_1-auc:0.82824
# [27]	validation_0-auc:0.86783	validation_1-auc:0.82865
# [28]	validation_0-auc:0.86900	validation_1-auc:0.82859
# [29]	validation_0-auc:0.86976	validation_1-auc:0.82924
# [30]	validation_0-auc:0.87047	validation_1-auc:0.82960
# [31]	validation_0-auc:0.87147	validation_1-auc:0.82956
# [32]	validation_0-auc:0.87249	validation_1-auc:0.82997
# [33]	validation_0-auc:0.87423	validation_1-auc:0.82987
# [34]	validation_0-auc:0.87461	validation_1-auc:0.83013
# [35]	validation_0-auc:0.87533	validation_1-auc:0.83040
# [36]	validation_0-auc:0.87643	validation_1-auc:0.83062
# [37]	validation_0-auc:0.87735	validation_1-auc:0.83097
# [38]	validation_0-auc:0.87847	validation_1-auc:0.83081
# [39]	validation_0-auc:0.87928	validation_1-auc:0.83164
# [40]	validation_0-auc:0.87989	validation_1-auc:0.83177
# [41]	validation_0-auc:0.88111	validation_1-auc:0.83142
# [42]	validation_0-auc:0.88249	validation_1-auc:0.83234
# [43]	validation_0-auc:0.88342	validation_1-auc:0.83224
# [44]	validation_0-auc:0.88411	validation_1-auc:0.83214
# [45]	validation_0-auc:0.88452	validation_1-auc:0.83241
# [46]	validation_0-auc:0.88504	validation_1-auc:0.83228
# [47]	validation_0-auc:0.88580	validation_1-auc:0.83266
# [48]	validation_0-auc:0.88659	validation_1-auc:0.83291
# [49]	validation_0-auc:0.88741	validation_1-auc:0.83271
# [50]	validation_0-auc:0.88809	validation_1-auc:0.83283
# [51]	validation_0-auc:0.88858	validation_1-auc:0.83300
# [52]	validation_0-auc:0.88977	validation_1-auc:0.83341
# [53]	validation_0-auc:0.89066	validation_1-auc:0.83335
# [54]	validation_0-auc:0.89155	validation_1-auc:0.83359
# [55]	validation_0-auc:0.89187	validation_1-auc:0.83361
# [56]	validation_0-auc:0.89237	validation_1-auc:0.83384
# [57]	validation_0-auc:0.89287	validation_1-auc:0.83385
# [58]	validation_0-auc:0.89312	validation_1-auc:0.83404
# [59]	validation_0-auc:0.89358	validation_1-auc:0.83425
# [60]	validation_0-auc:0.89413	validation_1-auc:0.83436
# [61]	validation_0-auc:0.89469	validation_1-auc:0.83422
# [62]	validation_0-auc:0.89511	validation_1-auc:0.83438
# [63]	validation_0-auc:0.89540	validation_1-auc:0.83456
# [64]	validation_0-auc:0.89607	validation_1-auc:0.83455
# [65]	validation_0-auc:0.89638	validation_1-auc:0.83442
# [66]	validation_0-auc:0.89682	validation_1-auc:0.83405
# [67]	validation_0-auc:0.89737	validation_1-auc:0.83378
# [68]	validation_0-auc:0.89765	validation_1-auc:0.83359
# [69]	validation_0-auc:0.89780	validation_1-auc:0.83373
# [70]	validation_0-auc:0.89804	validation_1-auc:0.83370
# [71]	validation_0-auc:0.89829	validation_1-auc:0.83358
# [72]	validation_0-auc:0.89872	validation_1-auc:0.83358
# [73]	validation_0-auc:0.89903	validation_1-auc:0.83327
# [74]	validation_0-auc:0.89941	validation_1-auc:0.83296
# [75]	validation_0-auc:0.89970	validation_1-auc:0.83292
# [76]	validation_0-auc:0.89987	validation_1-auc:0.83295
# [77]	validation_0-auc:0.90014	validation_1-auc:0.83287
# [78]	validation_0-auc:0.90060	validation_1-auc:0.83279
# [79]	validation_0-auc:0.90080	validation_1-auc:0.83271
# [80]	validation_0-auc:0.90133	validation_1-auc:0.83275
# [81]	validation_0-auc:0.90136	validation_1-auc:0.83285
# [82]	validation_0-auc:0.90207	validation_1-auc:0.83280
# [83]	validation_0-auc:0.90235	validation_1-auc:0.83292
# [84]	validation_0-auc:0.90270	validation_1-auc:0.83297
# [85]	validation_0-auc:0.90350	validation_1-auc:0.83313
# [86]	validation_0-auc:0.90362	validation_1-auc:0.83319
# [87]	validation_0-auc:0.90448	validation_1-auc:0.83281
# [88]	validation_0-auc:0.90508	validation_1-auc:0.83263
# [89]	validation_0-auc:0.90552	validation_1-auc:0.83254
# [90]	validation_0-auc:0.90567	validation_1-auc:0.83259
# [91]	validation_0-auc:0.90576	validation_1-auc:0.83249
# [92]	validation_0-auc:0.90625	validation_1-auc:0.83252
# [0]	validation_0-auc:0.81603	validation_1-auc:0.80264
# [1]	validation_0-auc:0.82200	validation_1-auc:0.80954
# [2]	validation_0-auc:0.82430	validation_1-auc:0.81089
# [3]	validation_0-auc:0.83115	validation_1-auc:0.81681
# [4]	validation_0-auc:0.83392	validation_1-auc:0.81672
# [5]	validation_0-auc:0.83515	validation_1-auc:0.81861
# [6]	validation_0-auc:0.83879	validation_1-auc:0.82139
# [7]	validation_0-auc:0.84019	validation_1-auc:0.82283
# [8]	validation_0-auc:0.84253	validation_1-auc:0.82372
# [9]	validation_0-auc:0.84300	validation_1-auc:0.82339
# [10]	validation_0-auc:0.84551	validation_1-auc:0.82344
# [11]	validation_0-auc:0.84535	validation_1-auc:0.82406
# [12]	validation_0-auc:0.84583	validation_1-auc:0.82402
# [13]	validation_0-auc:0.84864	validation_1-auc:0.82596
# [14]	validation_0-auc:0.84962	validation_1-auc:0.82648
# [15]	validation_0-auc:0.85310	validation_1-auc:0.82771
# [16]	validation_0-auc:0.85582	validation_1-auc:0.82746
# [17]	validation_0-auc:0.85740	validation_1-auc:0.82842
# [18]	validation_0-auc:0.85935	validation_1-auc:0.82802
# [19]	validation_0-auc:0.86089	validation_1-auc:0.82840
# [20]	validation_0-auc:0.86179	validation_1-auc:0.82855
# [21]	validation_0-auc:0.86334	validation_1-auc:0.83029
# [22]	validation_0-auc:0.86482	validation_1-auc:0.83032
# [23]	validation_0-auc:0.86538	validation_1-auc:0.83050
# [24]	validation_0-auc:0.86694	validation_1-auc:0.82983
# [25]	validation_0-auc:0.86837	validation_1-auc:0.83069
# [26]	validation_0-auc:0.86907	validation_1-auc:0.83081
# [27]	validation_0-auc:0.86975	validation_1-auc:0.82986
# [28]	validation_0-auc:0.87130	validation_1-auc:0.83004
# [29]	validation_0-auc:0.87147	validation_1-auc:0.83064
# [30]	validation_0-auc:0.87255	validation_1-auc:0.83118
# [31]	validation_0-auc:0.87299	validation_1-auc:0.83098
# [32]	validation_0-auc:0.87421	validation_1-auc:0.83164
# [33]	validation_0-auc:0.87498	validation_1-auc:0.83208
# [34]	validation_0-auc:0.87585	validation_1-auc:0.83258
# [35]	validation_0-auc:0.87620	validation_1-auc:0.83208
# [36]	validation_0-auc:0.87700	validation_1-auc:0.83269
# [37]	validation_0-auc:0.87807	validation_1-auc:0.83293
# [38]	validation_0-auc:0.87876	validation_1-auc:0.83296
# [39]	validation_0-auc:0.88024	validation_1-auc:0.83358
# [40]	validation_0-auc:0.88097	validation_1-auc:0.83420
# [41]	validation_0-auc:0.88194	validation_1-auc:0.83487
# [42]	validation_0-auc:0.88314	validation_1-auc:0.83430
# [43]	validation_0-auc:0.88404	validation_1-auc:0.83436
# [44]	validation_0-auc:0.88486	validation_1-auc:0.83488
# [45]	validation_0-auc:0.88550	validation_1-auc:0.83496
# [46]	validation_0-auc:0.88599	validation_1-auc:0.83531
# [47]	validation_0-auc:0.88686	validation_1-auc:0.83548
# [48]	validation_0-auc:0.88756	validation_1-auc:0.83523
# [49]	validation_0-auc:0.88833	validation_1-auc:0.83494
# [50]	validation_0-auc:0.88902	validation_1-auc:0.83483
# [51]	validation_0-auc:0.88936	validation_1-auc:0.83491
# [52]	validation_0-auc:0.89002	validation_1-auc:0.83497
# [53]	validation_0-auc:0.89051	validation_1-auc:0.83504
# [54]	validation_0-auc:0.89116	validation_1-auc:0.83507
# [55]	validation_0-auc:0.89169	validation_1-auc:0.83504
# [56]	validation_0-auc:0.89225	validation_1-auc:0.83508
# [57]	validation_0-auc:0.89295	validation_1-auc:0.83468
# [58]	validation_0-auc:0.89327	validation_1-auc:0.83504
# [59]	validation_0-auc:0.89406	validation_1-auc:0.83505
# [60]	validation_0-auc:0.89465	validation_1-auc:0.83527
# [61]	validation_0-auc:0.89485	validation_1-auc:0.83545
# [62]	validation_0-auc:0.89521	validation_1-auc:0.83522
# [63]	validation_0-auc:0.89540	validation_1-auc:0.83515
# [64]	validation_0-auc:0.89582	validation_1-auc:0.83491
# [65]	validation_0-auc:0.89651	validation_1-auc:0.83479
# [66]	validation_0-auc:0.89697	validation_1-auc:0.83493
# [67]	validation_0-auc:0.89748	validation_1-auc:0.83522
# [68]	validation_0-auc:0.89769	validation_1-auc:0.83528
# [69]	validation_0-auc:0.89779	validation_1-auc:0.83545
# [70]	validation_0-auc:0.89807	validation_1-auc:0.83551
# [71]	validation_0-auc:0.89829	validation_1-auc:0.83549
# [72]	validation_0-auc:0.89864	validation_1-auc:0.83552
# [73]	validation_0-auc:0.89911	validation_1-auc:0.83544
# [74]	validation_0-auc:0.89937	validation_1-auc:0.83535
# [75]	validation_0-auc:0.89957	validation_1-auc:0.83520
# [76]	validation_0-auc:0.90043	validation_1-auc:0.83494
# [77]	validation_0-auc:0.90110	validation_1-auc:0.83470
# [78]	validation_0-auc:0.90139	validation_1-auc:0.83481
# [79]	validation_0-auc:0.90176	validation_1-auc:0.83471
# [80]	validation_0-auc:0.90215	validation_1-auc:0.83469
# [81]	validation_0-auc:0.90246	validation_1-auc:0.83447
# [82]	validation_0-auc:0.90261	validation_1-auc:0.83446
# [83]	validation_0-auc:0.90278	validation_1-auc:0.83434
# [84]	validation_0-auc:0.90306	validation_1-auc:0.83416
# [85]	validation_0-auc:0.90351	validation_1-auc:0.83427
# [86]	validation_0-auc:0.90382	validation_1-auc:0.83439
# [87]	validation_0-auc:0.90465	validation_1-auc:0.83439
# [88]	validation_0-auc:0.90492	validation_1-auc:0.83436
# [89]	validation_0-auc:0.90538	validation_1-auc:0.83418
# [90]	validation_0-auc:0.90572	validation_1-auc:0.83402
# [91]	validation_0-auc:0.90588	validation_1-auc:0.83398
# [92]	validation_0-auc:0.90619	validation_1-auc:0.83423
# [93]	validation_0-auc:0.90648	validation_1-auc:0.83419
# [94]	validation_0-auc:0.90654	validation_1-auc:0.83427
# [95]	validation_0-auc:0.90709	validation_1-auc:0.83444
# [96]	validation_0-auc:0.90714	validation_1-auc:0.83442
# [97]	validation_0-auc:0.90727	validation_1-auc:0.83430
# [98]	validation_0-auc:0.90737	validation_1-auc:0.83433
# [99]	validation_0-auc:0.90754	validation_1-auc:0.83431
# [0]	validation_0-auc:0.82435	validation_1-auc:0.81007
# [1]	validation_0-auc:0.83105	validation_1-auc:0.81450
# [2]	validation_0-auc:0.83661	validation_1-auc:0.81582
# [3]	validation_0-auc:0.83811	validation_1-auc:0.81709
# [4]	validation_0-auc:0.83918	validation_1-auc:0.81729
# [5]	validation_0-auc:0.84146	validation_1-auc:0.81800
# [6]	validation_0-auc:0.84255	validation_1-auc:0.81854
# [7]	validation_0-auc:0.84408	validation_1-auc:0.81835
# [8]	validation_0-auc:0.84437	validation_1-auc:0.81834
# [9]	validation_0-auc:0.84710	validation_1-auc:0.82196
# [10]	validation_0-auc:0.84790	validation_1-auc:0.82236
# [11]	validation_0-auc:0.84843	validation_1-auc:0.82284
# [12]	validation_0-auc:0.85080	validation_1-auc:0.82421
# [13]	validation_0-auc:0.85137	validation_1-auc:0.82383
# [14]	validation_0-auc:0.85189	validation_1-auc:0.82356
# [15]	validation_0-auc:0.85436	validation_1-auc:0.82527
# [16]	validation_0-auc:0.85533	validation_1-auc:0.82628
# [17]	validation_0-auc:0.85740	validation_1-auc:0.82825
# [18]	validation_0-auc:0.85897	validation_1-auc:0.82855
# [19]	validation_0-auc:0.86099	validation_1-auc:0.83005
# [20]	validation_0-auc:0.86256	validation_1-auc:0.83060
# [21]	validation_0-auc:0.86363	validation_1-auc:0.83178
# [22]	validation_0-auc:0.86411	validation_1-auc:0.83203
# [23]	validation_0-auc:0.86493	validation_1-auc:0.83168
# [24]	validation_0-auc:0.86557	validation_1-auc:0.83201
# [25]	validation_0-auc:0.86626	validation_1-auc:0.83237
# [26]	validation_0-auc:0.86685	validation_1-auc:0.83245
# [27]	validation_0-auc:0.86753	validation_1-auc:0.83203
# [28]	validation_0-auc:0.86902	validation_1-auc:0.83276
# [29]	validation_0-auc:0.86923	validation_1-auc:0.83282
# [30]	validation_0-auc:0.87011	validation_1-auc:0.83317
# [31]	validation_0-auc:0.87075	validation_1-auc:0.83417
# [32]	validation_0-auc:0.87222	validation_1-auc:0.83459
# [33]	validation_0-auc:0.87331	validation_1-auc:0.83447
# [34]	validation_0-auc:0.87436	validation_1-auc:0.83415
# [35]	validation_0-auc:0.87547	validation_1-auc:0.83412
# [36]	validation_0-auc:0.87662	validation_1-auc:0.83390
# [37]	validation_0-auc:0.87827	validation_1-auc:0.83422
# [38]	validation_0-auc:0.87926	validation_1-auc:0.83411
# [39]	validation_0-auc:0.88043	validation_1-auc:0.83433
# [40]	validation_0-auc:0.88119	validation_1-auc:0.83515
# [41]	validation_0-auc:0.88204	validation_1-auc:0.83529
# [42]	validation_0-auc:0.88341	validation_1-auc:0.83590
# [43]	validation_0-auc:0.88445	validation_1-auc:0.83631
# [44]	validation_0-auc:0.88515	validation_1-auc:0.83670
# [45]	validation_0-auc:0.88568	validation_1-auc:0.83647
# [46]	validation_0-auc:0.88634	validation_1-auc:0.83665
# [47]	validation_0-auc:0.88718	validation_1-auc:0.83654
# [48]	validation_0-auc:0.88756	validation_1-auc:0.83635
# [49]	validation_0-auc:0.88812	validation_1-auc:0.83638
# [50]	validation_0-auc:0.88953	validation_1-auc:0.83637
# [51]	validation_0-auc:0.88993	validation_1-auc:0.83679
# [52]	validation_0-auc:0.89101	validation_1-auc:0.83722
# [53]	validation_0-auc:0.89157	validation_1-auc:0.83749
# [54]	validation_0-auc:0.89218	validation_1-auc:0.83746
# [55]	validation_0-auc:0.89239	validation_1-auc:0.83774
# [56]	validation_0-auc:0.89310	validation_1-auc:0.83762
# [57]	validation_0-auc:0.89425	validation_1-auc:0.83771
# [58]	validation_0-auc:0.89451	validation_1-auc:0.83787
# [59]	validation_0-auc:0.89475	validation_1-auc:0.83780
# [60]	validation_0-auc:0.89503	validation_1-auc:0.83789
# [61]	validation_0-auc:0.89552	validation_1-auc:0.83818
# [62]	validation_0-auc:0.89579	validation_1-auc:0.83845
# [63]	validation_0-auc:0.89599	validation_1-auc:0.83831
# [64]	validation_0-auc:0.89643	validation_1-auc:0.83815
# [65]	validation_0-auc:0.89686	validation_1-auc:0.83788
# [66]	validation_0-auc:0.89713	validation_1-auc:0.83800
# [67]	validation_0-auc:0.89732	validation_1-auc:0.83780
# [68]	validation_0-auc:0.89785	validation_1-auc:0.83765
# [69]	validation_0-auc:0.89829	validation_1-auc:0.83768
# [70]	validation_0-auc:0.89867	validation_1-auc:0.83807
# [71]	validation_0-auc:0.89896	validation_1-auc:0.83829
# [72]	validation_0-auc:0.89941	validation_1-auc:0.83835
# [73]	validation_0-auc:0.89963	validation_1-auc:0.83827
# [74]	validation_0-auc:0.90006	validation_1-auc:0.83854
# [75]	validation_0-auc:0.90051	validation_1-auc:0.83875
# [76]	validation_0-auc:0.90094	validation_1-auc:0.83872
# [77]	validation_0-auc:0.90111	validation_1-auc:0.83903
# [78]	validation_0-auc:0.90153	validation_1-auc:0.83915
# [79]	validation_0-auc:0.90179	validation_1-auc:0.83913
# [80]	validation_0-auc:0.90219	validation_1-auc:0.83925
# [81]	validation_0-auc:0.90254	validation_1-auc:0.83915
# [82]	validation_0-auc:0.90312	validation_1-auc:0.83883
# [83]	validation_0-auc:0.90373	validation_1-auc:0.83880
# [84]	validation_0-auc:0.90429	validation_1-auc:0.83881
# [85]	validation_0-auc:0.90466	validation_1-auc:0.83893
# [86]	validation_0-auc:0.90529	validation_1-auc:0.83890
# [87]	validation_0-auc:0.90585	validation_1-auc:0.83878
# [88]	validation_0-auc:0.90655	validation_1-auc:0.83856
# [89]	validation_0-auc:0.90693	validation_1-auc:0.83847
# [90]	validation_0-auc:0.90728	validation_1-auc:0.83855
# [91]	validation_0-auc:0.90746	validation_1-auc:0.83832
# [92]	validation_0-auc:0.90770	validation_1-auc:0.83818
# [93]	validation_0-auc:0.90779	validation_1-auc:0.83808
# [94]	validation_0-auc:0.90796	validation_1-auc:0.83805
# [95]	validation_0-auc:0.90861	validation_1-auc:0.83806
# [96]	validation_0-auc:0.90887	validation_1-auc:0.83812
# [97]	validation_0-auc:0.90894	validation_1-auc:0.83829
# [98]	validation_0-auc:0.90904	validation_1-auc:0.83826
# [99]	validation_0-auc:0.90914	validation_1-auc:0.83817
# [0]	validation_0-auc:0.82774	validation_1-auc:0.79991
# [1]	validation_0-auc:0.82471	validation_1-auc:0.79192
# [2]	validation_0-auc:0.82087	validation_1-auc:0.79100
# [3]	validation_0-auc:0.82030	validation_1-auc:0.78626
# [4]	validation_0-auc:0.83500	validation_1-auc:0.79754
# [5]	validation_0-auc:0.83666	validation_1-auc:0.79686
# [6]	validation_0-auc:0.84268	validation_1-auc:0.80330
# [7]	validation_0-auc:0.84746	validation_1-auc:0.80539
# [8]	validation_0-auc:0.85130	validation_1-auc:0.80922
# [9]	validation_0-auc:0.85476	validation_1-auc:0.81276
# [10]	validation_0-auc:0.85928	validation_1-auc:0.81688
# [11]	validation_0-auc:0.85969	validation_1-auc:0.81710
# [12]	validation_0-auc:0.86017	validation_1-auc:0.81417
# [13]	validation_0-auc:0.86412	validation_1-auc:0.81676
# [14]	validation_0-auc:0.86694	validation_1-auc:0.82000
# [15]	validation_0-auc:0.86945	validation_1-auc:0.82079
# [16]	validation_0-auc:0.87043	validation_1-auc:0.82056
# [17]	validation_0-auc:0.87178	validation_1-auc:0.81991
# [18]	validation_0-auc:0.87303	validation_1-auc:0.81963
# [19]	validation_0-auc:0.87633	validation_1-auc:0.82210
# [20]	validation_0-auc:0.87816	validation_1-auc:0.82287
# [21]	validation_0-auc:0.88003	validation_1-auc:0.82345
# [22]	validation_0-auc:0.88003	validation_1-auc:0.82216
# [23]	validation_0-auc:0.88022	validation_1-auc:0.82218
# [24]	validation_0-auc:0.88245	validation_1-auc:0.82500
# [25]	validation_0-auc:0.88420	validation_1-auc:0.82614
# [26]	validation_0-auc:0.88614	validation_1-auc:0.82701
# [27]	validation_0-auc:0.88718	validation_1-auc:0.82626
# [28]	validation_0-auc:0.88800	validation_1-auc:0.82616
# [29]	validation_0-auc:0.88858	validation_1-auc:0.82741
# [30]	validation_0-auc:0.88945	validation_1-auc:0.82559
# [31]	validation_0-auc:0.89085	validation_1-auc:0.82761
# [32]	validation_0-auc:0.89273	validation_1-auc:0.82895
# [33]	validation_0-auc:0.89533	validation_1-auc:0.82959
# [34]	validation_0-auc:0.89529	validation_1-auc:0.82875
# [35]	validation_0-auc:0.89562	validation_1-auc:0.82823
# [36]	validation_0-auc:0.89715	validation_1-auc:0.82856
# [37]	validation_0-auc:0.89868	validation_1-auc:0.82856
# [38]	validation_0-auc:0.89851	validation_1-auc:0.82793
# [39]	validation_0-auc:0.89926	validation_1-auc:0.82702
# [40]	validation_0-auc:0.90047	validation_1-auc:0.82789
# [41]	validation_0-auc:0.90339	validation_1-auc:0.82794
# [42]	validation_0-auc:0.90368	validation_1-auc:0.82794
# [43]	validation_0-auc:0.90424	validation_1-auc:0.82761
# [44]	validation_0-auc:0.90488	validation_1-auc:0.82870
# [45]	validation_0-auc:0.90518	validation_1-auc:0.82813
# [46]	validation_0-auc:0.90661	validation_1-auc:0.82868
# [47]	validation_0-auc:0.90844	validation_1-auc:0.82900
# [48]	validation_0-auc:0.91013	validation_1-auc:0.82933
# [49]	validation_0-auc:0.91200	validation_1-auc:0.83026
# [50]	validation_0-auc:0.91190	validation_1-auc:0.82967
# [51]	validation_0-auc:0.91196	validation_1-auc:0.82898
# [52]	validation_0-auc:0.91311	validation_1-auc:0.82997
# [53]	validation_0-auc:0.91483	validation_1-auc:0.83044
# [54]	validation_0-auc:0.91583	validation_1-auc:0.83115
# [55]	validation_0-auc:0.91612	validation_1-auc:0.83034
# [56]	validation_0-auc:0.91654	validation_1-auc:0.83022
# [57]	validation_0-auc:0.91773	validation_1-auc:0.83013
# [58]	validation_0-auc:0.91819	validation_1-auc:0.83037
# [59]	validation_0-auc:0.91891	validation_1-auc:0.82991
# [60]	validation_0-auc:0.91964	validation_1-auc:0.83044
# [61]	validation_0-auc:0.92038	validation_1-auc:0.83053
# [62]	validation_0-auc:0.92131	validation_1-auc:0.83095
# [63]	validation_0-auc:0.92199	validation_1-auc:0.83118
# [64]	validation_0-auc:0.92250	validation_1-auc:0.83172
# [65]	validation_0-auc:0.92308	validation_1-auc:0.83087
# [66]	validation_0-auc:0.92352	validation_1-auc:0.83011
# [67]	validation_0-auc:0.92406	validation_1-auc:0.83003
# [68]	validation_0-auc:0.92431	validation_1-auc:0.82953
# [69]	validation_0-auc:0.92443	validation_1-auc:0.82935
# [70]	validation_0-auc:0.92501	validation_1-auc:0.82895
# [71]	validation_0-auc:0.92563	validation_1-auc:0.82968
# [72]	validation_0-auc:0.92640	validation_1-auc:0.82939
# [73]	validation_0-auc:0.92689	validation_1-auc:0.82952
# [74]	validation_0-auc:0.92723	validation_1-auc:0.82988
# [75]	validation_0-auc:0.92760	validation_1-auc:0.82944
# [76]	validation_0-auc:0.92783	validation_1-auc:0.82932
# [77]	validation_0-auc:0.92858	validation_1-auc:0.82949
# [78]	validation_0-auc:0.92905	validation_1-auc:0.82957
# [79]	validation_0-auc:0.92948	validation_1-auc:0.82972
# [80]	validation_0-auc:0.92985	validation_1-auc:0.82978
# [81]	validation_0-auc:0.93027	validation_1-auc:0.82971
# [82]	validation_0-auc:0.93041	validation_1-auc:0.82956
# [83]	validation_0-auc:0.93080	validation_1-auc:0.82958
# [84]	validation_0-auc:0.93158	validation_1-auc:0.82914
# [85]	validation_0-auc:0.93187	validation_1-auc:0.82938
# [86]	validation_0-auc:0.93208	validation_1-auc:0.82917
# [87]	validation_0-auc:0.93246	validation_1-auc:0.82919
# [88]	validation_0-auc:0.93333	validation_1-auc:0.82936
# [89]	validation_0-auc:0.93366	validation_1-auc:0.82930
# [90]	validation_0-auc:0.93409	validation_1-auc:0.82966
# [91]	validation_0-auc:0.93441	validation_1-auc:0.82950
# [92]	validation_0-auc:0.93460	validation_1-auc:0.82959
# [93]	validation_0-auc:0.93511	validation_1-auc:0.82924
# [94]	validation_0-auc:0.93525	validation_1-auc:0.82930
# [0]	validation_0-auc:0.82101	validation_1-auc:0.80238
# [1]	validation_0-auc:0.82048	validation_1-auc:0.79437
# [2]	validation_0-auc:0.82118	validation_1-auc:0.79077
# [3]	validation_0-auc:0.82077	validation_1-auc:0.78887
# [4]	validation_0-auc:0.83867	validation_1-auc:0.80551
# [5]	validation_0-auc:0.83949	validation_1-auc:0.80463
# [6]	validation_0-auc:0.84635	validation_1-auc:0.81259
# [7]	validation_0-auc:0.85078	validation_1-auc:0.81718
# [8]	validation_0-auc:0.85493	validation_1-auc:0.82038
# [9]	validation_0-auc:0.85927	validation_1-auc:0.82310
# [10]	validation_0-auc:0.86233	validation_1-auc:0.82634
# [11]	validation_0-auc:0.86511	validation_1-auc:0.82451
# [12]	validation_0-auc:0.86665	validation_1-auc:0.82152
# [13]	validation_0-auc:0.86952	validation_1-auc:0.82345
# [14]	validation_0-auc:0.87191	validation_1-auc:0.82546
# [15]	validation_0-auc:0.87410	validation_1-auc:0.82754
# [16]	validation_0-auc:0.87567	validation_1-auc:0.82853
# [17]	validation_0-auc:0.87661	validation_1-auc:0.82644
# [18]	validation_0-auc:0.87757	validation_1-auc:0.82445
# [19]	validation_0-auc:0.87985	validation_1-auc:0.82537
# [20]	validation_0-auc:0.88245	validation_1-auc:0.82652
# [21]	validation_0-auc:0.88390	validation_1-auc:0.82799
# [22]	validation_0-auc:0.88431	validation_1-auc:0.82647
# [23]	validation_0-auc:0.88474	validation_1-auc:0.82532
# [24]	validation_0-auc:0.88585	validation_1-auc:0.82637
# [25]	validation_0-auc:0.88793	validation_1-auc:0.82709
# [26]	validation_0-auc:0.89045	validation_1-auc:0.82739
# [27]	validation_0-auc:0.89137	validation_1-auc:0.82714
# [28]	validation_0-auc:0.89235	validation_1-auc:0.82582
# [29]	validation_0-auc:0.89326	validation_1-auc:0.82630
# [30]	validation_0-auc:0.89386	validation_1-auc:0.82484
# [31]	validation_0-auc:0.89506	validation_1-auc:0.82609
# [32]	validation_0-auc:0.89643	validation_1-auc:0.82742
# [33]	validation_0-auc:0.89787	validation_1-auc:0.82838
# [34]	validation_0-auc:0.89768	validation_1-auc:0.82731
# [35]	validation_0-auc:0.89764	validation_1-auc:0.82610
# [36]	validation_0-auc:0.89921	validation_1-auc:0.82764
# [37]	validation_0-auc:0.90144	validation_1-auc:0.82860
# [38]	validation_0-auc:0.90117	validation_1-auc:0.82805
# [39]	validation_0-auc:0.90211	validation_1-auc:0.82713
# [40]	validation_0-auc:0.90370	validation_1-auc:0.82764
# [41]	validation_0-auc:0.90532	validation_1-auc:0.82818
# [42]	validation_0-auc:0.90573	validation_1-auc:0.82722
# [43]	validation_0-auc:0.90633	validation_1-auc:0.82630
# [44]	validation_0-auc:0.90743	validation_1-auc:0.82757
# [45]	validation_0-auc:0.90748	validation_1-auc:0.82688
# [46]	validation_0-auc:0.90869	validation_1-auc:0.82747
# [47]	validation_0-auc:0.91049	validation_1-auc:0.82781
# [48]	validation_0-auc:0.91157	validation_1-auc:0.82871
# [49]	validation_0-auc:0.91274	validation_1-auc:0.82852
# [50]	validation_0-auc:0.91309	validation_1-auc:0.82761
# [51]	validation_0-auc:0.91321	validation_1-auc:0.82754
# [52]	validation_0-auc:0.91417	validation_1-auc:0.82765
# [53]	validation_0-auc:0.91590	validation_1-auc:0.82804
# [54]	validation_0-auc:0.91704	validation_1-auc:0.82874
# [55]	validation_0-auc:0.91702	validation_1-auc:0.82847
# [56]	validation_0-auc:0.91765	validation_1-auc:0.82809
# [57]	validation_0-auc:0.91865	validation_1-auc:0.82762
# [58]	validation_0-auc:0.91923	validation_1-auc:0.82867
# [59]	validation_0-auc:0.92007	validation_1-auc:0.82864
# [60]	validation_0-auc:0.92098	validation_1-auc:0.82859
# [61]	validation_0-auc:0.92226	validation_1-auc:0.82909
# [62]	validation_0-auc:0.92310	validation_1-auc:0.83006
# [63]	validation_0-auc:0.92391	validation_1-auc:0.83013
# [64]	validation_0-auc:0.92444	validation_1-auc:0.83075
# [65]	validation_0-auc:0.92499	validation_1-auc:0.83014
# [66]	validation_0-auc:0.92560	validation_1-auc:0.82996
# [67]	validation_0-auc:0.92581	validation_1-auc:0.82918
# [68]	validation_0-auc:0.92652	validation_1-auc:0.82895
# [69]	validation_0-auc:0.92659	validation_1-auc:0.82850
# [70]	validation_0-auc:0.92702	validation_1-auc:0.82832
# [71]	validation_0-auc:0.92767	validation_1-auc:0.82868
# [72]	validation_0-auc:0.92871	validation_1-auc:0.82821
# [73]	validation_0-auc:0.92962	validation_1-auc:0.82855
# [74]	validation_0-auc:0.93000	validation_1-auc:0.82890
# [75]	validation_0-auc:0.93041	validation_1-auc:0.82894
# [76]	validation_0-auc:0.93056	validation_1-auc:0.82873
# [77]	validation_0-auc:0.93122	validation_1-auc:0.82886
# [78]	validation_0-auc:0.93173	validation_1-auc:0.82896
# [79]	validation_0-auc:0.93239	validation_1-auc:0.82914
# [80]	validation_0-auc:0.93281	validation_1-auc:0.82935
# [81]	validation_0-auc:0.93315	validation_1-auc:0.82936
# [82]	validation_0-auc:0.93340	validation_1-auc:0.82921
# [83]	validation_0-auc:0.93379	validation_1-auc:0.82929
# [84]	validation_0-auc:0.93427	validation_1-auc:0.82935
# [85]	validation_0-auc:0.93472	validation_1-auc:0.82987
# [86]	validation_0-auc:0.93507	validation_1-auc:0.83002
# [87]	validation_0-auc:0.93543	validation_1-auc:0.82991
# [88]	validation_0-auc:0.93597	validation_1-auc:0.83003
# [89]	validation_0-auc:0.93638	validation_1-auc:0.82985
# [90]	validation_0-auc:0.93684	validation_1-auc:0.82981
# [91]	validation_0-auc:0.93706	validation_1-auc:0.82991
# [92]	validation_0-auc:0.93722	validation_1-auc:0.82991
# [93]	validation_0-auc:0.93748	validation_1-auc:0.82996
# [94]	validation_0-auc:0.93765	validation_1-auc:0.82994
# [0]	validation_0-auc:0.83050	validation_1-auc:0.80729
# [1]	validation_0-auc:0.82853	validation_1-auc:0.80455
# [2]	validation_0-auc:0.83347	validation_1-auc:0.80380
# [3]	validation_0-auc:0.83142	validation_1-auc:0.79709
# [4]	validation_0-auc:0.84273	validation_1-auc:0.80877
# [5]	validation_0-auc:0.84286	validation_1-auc:0.80840
# [6]	validation_0-auc:0.84839	validation_1-auc:0.81533
# [7]	validation_0-auc:0.85353	validation_1-auc:0.81705
# [8]	validation_0-auc:0.85709	validation_1-auc:0.81907
# [9]	validation_0-auc:0.85980	validation_1-auc:0.82107
# [10]	validation_0-auc:0.86145	validation_1-auc:0.82127
# [11]	validation_0-auc:0.86250	validation_1-auc:0.81992
# [12]	validation_0-auc:0.86569	validation_1-auc:0.82029
# [13]	validation_0-auc:0.86716	validation_1-auc:0.82057
# [14]	validation_0-auc:0.87115	validation_1-auc:0.82449
# [15]	validation_0-auc:0.87313	validation_1-auc:0.82508
# [16]	validation_0-auc:0.87448	validation_1-auc:0.82645
# [17]	validation_0-auc:0.87587	validation_1-auc:0.82574
# [18]	validation_0-auc:0.87797	validation_1-auc:0.82477
# [19]	validation_0-auc:0.87950	validation_1-auc:0.82640
# [20]	validation_0-auc:0.88113	validation_1-auc:0.82764
# [21]	validation_0-auc:0.88338	validation_1-auc:0.82834
# [22]	validation_0-auc:0.88587	validation_1-auc:0.82607
# [23]	validation_0-auc:0.88549	validation_1-auc:0.82539
# [24]	validation_0-auc:0.88709	validation_1-auc:0.82667
# [25]	validation_0-auc:0.88896	validation_1-auc:0.82681
# [26]	validation_0-auc:0.89089	validation_1-auc:0.82701
# [27]	validation_0-auc:0.89099	validation_1-auc:0.82532
# [28]	validation_0-auc:0.89234	validation_1-auc:0.82418
# [29]	validation_0-auc:0.89333	validation_1-auc:0.82498
# [30]	validation_0-auc:0.89507	validation_1-auc:0.82376
# [31]	validation_0-auc:0.89658	validation_1-auc:0.82496
# [32]	validation_0-auc:0.89816	validation_1-auc:0.82619
# [33]	validation_0-auc:0.89987	validation_1-auc:0.82711
# [34]	validation_0-auc:0.90009	validation_1-auc:0.82704
# [35]	validation_0-auc:0.90063	validation_1-auc:0.82631
# [36]	validation_0-auc:0.90224	validation_1-auc:0.82748
# [37]	validation_0-auc:0.90354	validation_1-auc:0.82846
# [38]	validation_0-auc:0.90347	validation_1-auc:0.82783
# [39]	validation_0-auc:0.90496	validation_1-auc:0.82704
# [40]	validation_0-auc:0.90598	validation_1-auc:0.82825
# [41]	validation_0-auc:0.90763	validation_1-auc:0.82917
# [42]	validation_0-auc:0.90893	validation_1-auc:0.82842
# [43]	validation_0-auc:0.90968	validation_1-auc:0.82820
# [44]	validation_0-auc:0.91047	validation_1-auc:0.82859
# [45]	validation_0-auc:0.91061	validation_1-auc:0.82818
# [46]	validation_0-auc:0.91210	validation_1-auc:0.82863
# [47]	validation_0-auc:0.91334	validation_1-auc:0.82899
# [48]	validation_0-auc:0.91465	validation_1-auc:0.82980
# [49]	validation_0-auc:0.91562	validation_1-auc:0.83004
# [50]	validation_0-auc:0.91580	validation_1-auc:0.82906
# [51]	validation_0-auc:0.91610	validation_1-auc:0.82847
# [52]	validation_0-auc:0.91695	validation_1-auc:0.82937
# [53]	validation_0-auc:0.91827	validation_1-auc:0.82973
# [54]	validation_0-auc:0.91889	validation_1-auc:0.83054
# [55]	validation_0-auc:0.91906	validation_1-auc:0.83007
# [56]	validation_0-auc:0.91936	validation_1-auc:0.82988
# [57]	validation_0-auc:0.92021	validation_1-auc:0.82952
# [58]	validation_0-auc:0.92084	validation_1-auc:0.82995
# [59]	validation_0-auc:0.92138	validation_1-auc:0.82959
# [60]	validation_0-auc:0.92200	validation_1-auc:0.83071
# [61]	validation_0-auc:0.92285	validation_1-auc:0.83147
# [62]	validation_0-auc:0.92358	validation_1-auc:0.83203
# [63]	validation_0-auc:0.92440	validation_1-auc:0.83271
# [64]	validation_0-auc:0.92467	validation_1-auc:0.83276
# [65]	validation_0-auc:0.92521	validation_1-auc:0.83248
# [66]	validation_0-auc:0.92593	validation_1-auc:0.83234
# [67]	validation_0-auc:0.92629	validation_1-auc:0.83207
# [68]	validation_0-auc:0.92699	validation_1-auc:0.83176
# [69]	validation_0-auc:0.92714	validation_1-auc:0.83177
# [70]	validation_0-auc:0.92774	validation_1-auc:0.83155
# [71]	validation_0-auc:0.92860	validation_1-auc:0.83165
# [72]	validation_0-auc:0.92924	validation_1-auc:0.83098
# [73]	validation_0-auc:0.92985	validation_1-auc:0.83182
# [74]	validation_0-auc:0.93003	validation_1-auc:0.83204
# [75]	validation_0-auc:0.93085	validation_1-auc:0.83181
# [76]	validation_0-auc:0.93095	validation_1-auc:0.83186
# [77]	validation_0-auc:0.93156	validation_1-auc:0.83202
# [78]	validation_0-auc:0.93204	validation_1-auc:0.83226
# [79]	validation_0-auc:0.93262	validation_1-auc:0.83250
# [80]	validation_0-auc:0.93330	validation_1-auc:0.83294
# [81]	validation_0-auc:0.93351	validation_1-auc:0.83252
# [82]	validation_0-auc:0.93358	validation_1-auc:0.83211
# [83]	validation_0-auc:0.93393	validation_1-auc:0.83211
# [84]	validation_0-auc:0.93419	validation_1-auc:0.83176
# [85]	validation_0-auc:0.93462	validation_1-auc:0.83172
# [86]	validation_0-auc:0.93475	validation_1-auc:0.83157
# [87]	validation_0-auc:0.93502	validation_1-auc:0.83178
# [88]	validation_0-auc:0.93524	validation_1-auc:0.83197
# [89]	validation_0-auc:0.93556	validation_1-auc:0.83184
# [90]	validation_0-auc:0.93596	validation_1-auc:0.83220
# [91]	validation_0-auc:0.93616	validation_1-auc:0.83208
# [92]	validation_0-auc:0.93634	validation_1-auc:0.83263
# [93]	validation_0-auc:0.93671	validation_1-auc:0.83262
# [94]	validation_0-auc:0.93684	validation_1-auc:0.83278
# [95]	validation_0-auc:0.93695	validation_1-auc:0.83293
# [96]	validation_0-auc:0.93717	validation_1-auc:0.83302
# [97]	validation_0-auc:0.93731	validation_1-auc:0.83283
# [98]	validation_0-auc:0.93741	validation_1-auc:0.83270
# [99]	validation_0-auc:0.93748	validation_1-auc:0.83264
# [0]	validation_0-auc:0.82884	validation_1-auc:0.80096
# [1]	validation_0-auc:0.83640	validation_1-auc:0.80149
# [2]	validation_0-auc:0.84786	validation_1-auc:0.80551
# [3]	validation_0-auc:0.85606	validation_1-auc:0.80917
# [4]	validation_0-auc:0.86064	validation_1-auc:0.81169
# [5]	validation_0-auc:0.86550	validation_1-auc:0.81462
# [6]	validation_0-auc:0.86940	validation_1-auc:0.81792
# [7]	validation_0-auc:0.87128	validation_1-auc:0.81885
# [8]	validation_0-auc:0.87461	validation_1-auc:0.82013
# [9]	validation_0-auc:0.87773	validation_1-auc:0.82346
# [10]	validation_0-auc:0.88172	validation_1-auc:0.82351
# [11]	validation_0-auc:0.88404	validation_1-auc:0.82393
# [12]	validation_0-auc:0.89075	validation_1-auc:0.82461
# [13]	validation_0-auc:0.89395	validation_1-auc:0.82460
# [14]	validation_0-auc:0.89594	validation_1-auc:0.82649
# [15]	validation_0-auc:0.90310	validation_1-auc:0.82718
# [16]	validation_0-auc:0.90576	validation_1-auc:0.82720
# [17]	validation_0-auc:0.90762	validation_1-auc:0.82677
# [18]	validation_0-auc:0.91022	validation_1-auc:0.82541
# [19]	validation_0-auc:0.91244	validation_1-auc:0.82698
# [20]	validation_0-auc:0.91594	validation_1-auc:0.82707
# [21]	validation_0-auc:0.91885	validation_1-auc:0.82751
# [22]	validation_0-auc:0.92123	validation_1-auc:0.82618
# [23]	validation_0-auc:0.92308	validation_1-auc:0.82658
# [24]	validation_0-auc:0.92531	validation_1-auc:0.82697
# [25]	validation_0-auc:0.92832	validation_1-auc:0.82624
# [26]	validation_0-auc:0.93055	validation_1-auc:0.82580
# [27]	validation_0-auc:0.93212	validation_1-auc:0.82576
# [28]	validation_0-auc:0.93415	validation_1-auc:0.82497
# [29]	validation_0-auc:0.93512	validation_1-auc:0.82492
# [30]	validation_0-auc:0.93681	validation_1-auc:0.82438
# [31]	validation_0-auc:0.93802	validation_1-auc:0.82460
# [32]	validation_0-auc:0.93884	validation_1-auc:0.82524
# [33]	validation_0-auc:0.94013	validation_1-auc:0.82480
# [34]	validation_0-auc:0.94082	validation_1-auc:0.82436
# [35]	validation_0-auc:0.94190	validation_1-auc:0.82472
# [36]	validation_0-auc:0.94306	validation_1-auc:0.82501
# [37]	validation_0-auc:0.94435	validation_1-auc:0.82495
# [38]	validation_0-auc:0.94504	validation_1-auc:0.82441
# [39]	validation_0-auc:0.94553	validation_1-auc:0.82452
# [40]	validation_0-auc:0.94614	validation_1-auc:0.82478
# [41]	validation_0-auc:0.94679	validation_1-auc:0.82486
# [42]	validation_0-auc:0.94711	validation_1-auc:0.82458
# [43]	validation_0-auc:0.94778	validation_1-auc:0.82414
# [44]	validation_0-auc:0.94821	validation_1-auc:0.82475
# [45]	validation_0-auc:0.94843	validation_1-auc:0.82458
# [46]	validation_0-auc:0.94906	validation_1-auc:0.82442
# [47]	validation_0-auc:0.94939	validation_1-auc:0.82440
# [48]	validation_0-auc:0.94954	validation_1-auc:0.82420
# [49]	validation_0-auc:0.94995	validation_1-auc:0.82367
# [50]	validation_0-auc:0.95059	validation_1-auc:0.82380
# [0]	validation_0-auc:0.82248	validation_1-auc:0.80281
# [1]	validation_0-auc:0.83248	validation_1-auc:0.81246
# [2]	validation_0-auc:0.84271	validation_1-auc:0.81911
# [3]	validation_0-auc:0.85368	validation_1-auc:0.81820
# [4]	validation_0-auc:0.86054	validation_1-auc:0.82533
# [5]	validation_0-auc:0.86441	validation_1-auc:0.82782
# [6]	validation_0-auc:0.86908	validation_1-auc:0.82739
# [7]	validation_0-auc:0.87081	validation_1-auc:0.82722
# [8]	validation_0-auc:0.87441	validation_1-auc:0.82832
# [9]	validation_0-auc:0.87895	validation_1-auc:0.83091
# [10]	validation_0-auc:0.88633	validation_1-auc:0.82974
# [11]	validation_0-auc:0.89036	validation_1-auc:0.82953
# [12]	validation_0-auc:0.89565	validation_1-auc:0.82769
# [13]	validation_0-auc:0.89999	validation_1-auc:0.82805
# [14]	validation_0-auc:0.90270	validation_1-auc:0.82842
# [15]	validation_0-auc:0.90558	validation_1-auc:0.82778
# [16]	validation_0-auc:0.90954	validation_1-auc:0.82854
# [17]	validation_0-auc:0.91135	validation_1-auc:0.82774
# [18]	validation_0-auc:0.91252	validation_1-auc:0.82474
# [19]	validation_0-auc:0.91480	validation_1-auc:0.82506
# [20]	validation_0-auc:0.91844	validation_1-auc:0.82623
# [21]	validation_0-auc:0.92072	validation_1-auc:0.82751
# [22]	validation_0-auc:0.92341	validation_1-auc:0.82862
# [23]	validation_0-auc:0.92532	validation_1-auc:0.82720
# [24]	validation_0-auc:0.92794	validation_1-auc:0.82738
# [25]	validation_0-auc:0.93025	validation_1-auc:0.82723
# [26]	validation_0-auc:0.93293	validation_1-auc:0.82765
# [27]	validation_0-auc:0.93560	validation_1-auc:0.82689
# [28]	validation_0-auc:0.93759	validation_1-auc:0.82720
# [29]	validation_0-auc:0.93839	validation_1-auc:0.82751
# [30]	validation_0-auc:0.94022	validation_1-auc:0.82743
# [31]	validation_0-auc:0.94090	validation_1-auc:0.82804
# [32]	validation_0-auc:0.94183	validation_1-auc:0.82844
# [33]	validation_0-auc:0.94276	validation_1-auc:0.82940
# [34]	validation_0-auc:0.94419	validation_1-auc:0.82959
# [35]	validation_0-auc:0.94544	validation_1-auc:0.82875
# [36]	validation_0-auc:0.94653	validation_1-auc:0.82850
# [37]	validation_0-auc:0.94790	validation_1-auc:0.82873
# [38]	validation_0-auc:0.94892	validation_1-auc:0.82838
# [39]	validation_0-auc:0.95008	validation_1-auc:0.82770
# [0]	validation_0-auc:0.83348	validation_1-auc:0.80854
# [1]	validation_0-auc:0.84176	validation_1-auc:0.81264
# [2]	validation_0-auc:0.84995	validation_1-auc:0.81462
# [3]	validation_0-auc:0.85825	validation_1-auc:0.81620
# [4]	validation_0-auc:0.86336	validation_1-auc:0.82051
# [5]	validation_0-auc:0.86902	validation_1-auc:0.82121
# [6]	validation_0-auc:0.87147	validation_1-auc:0.82145
# [7]	validation_0-auc:0.87372	validation_1-auc:0.82154
# [8]	validation_0-auc:0.87882	validation_1-auc:0.82380
# [9]	validation_0-auc:0.88131	validation_1-auc:0.82509
# [10]	validation_0-auc:0.88506	validation_1-auc:0.82526
# [11]	validation_0-auc:0.88952	validation_1-auc:0.82576
# [12]	validation_0-auc:0.89526	validation_1-auc:0.82712
# [13]	validation_0-auc:0.89933	validation_1-auc:0.82969
# ...
# [80]	validation_0-auc:0.93064	validation_1-auc:0.82901
# [81]	validation_0-auc:0.93078	validation_1-auc:0.82897
# [82]	validation_0-auc:0.93090	validation_1-auc:0.82871
# [0]	validation_0-auc:0.82972	validation_1-auc:0.80005
# [1]	validation_0-auc:0.83837	validation_1-auc:0.79908
# [2]	validation_0-auc:0.85112	validation_1-auc:0.80512
# [3]	validation_0-auc:0.85518	validation_1-auc:0.80723
# [4]	validation_0-auc:0.86141	validation_1-auc:0.80980
# [5]	validation_0-auc:0.86789	validation_1-auc:0.81235
# [6]	validation_0-auc:0.87251	validation_1-auc:0.81317
# [7]	validation_0-auc:0.87809	validation_1-auc:0.81471
# [8]	validation_0-auc:0.88604	validation_1-auc:0.81782
# [9]	validation_0-auc:0.88993	validation_1-auc:0.81862
# [10]	validation_0-auc:0.89389	validation_1-auc:0.81810
# [11]	validation_0-auc:0.89704	validation_1-auc:0.81972
# [12]	validation_0-auc:0.90283	validation_1-auc:0.82111
# [13]	validation_0-auc:0.90887	validation_1-auc:0.82068
# [14]	validation_0-auc:0.91070	validation_1-auc:0.82276
# [15]	validation_0-auc:0.91611	validation_1-auc:0.82243
# [16]	validation_0-auc:0.92195	validation_1-auc:0.82145
# [17]	validation_0-auc:0.92771	validation_1-auc:0.82269
# [18]	validation_0-auc:0.93166	validation_1-auc:0.82112
# [19]	validation_0-auc:0.93402	validation_1-auc:0.82184
# [20]	validation_0-auc:0.93784	validation_1-auc:0.82103
# [21]	validation_0-auc:0.94034	validation_1-auc:0.82275
# [22]	validation_0-auc:0.94232	validation_1-auc:0.82249
# [23]	validation_0-auc:0.94394	validation_1-auc:0.82132
# [24]	validation_0-auc:0.94558	validation_1-auc:0.82241
# [25]	validation_0-auc:0.94721	validation_1-auc:0.82264
# [26]	validation_0-auc:0.94951	validation_1-auc:0.82291
# [27]	validation_0-auc:0.95043	validation_1-auc:0.82301
# [28]	validation_0-auc:0.95185	validation_1-auc:0.82332
# [29]	validation_0-auc:0.95308	validation_1-auc:0.82263
# [30]	validation_0-auc:0.95507	validation_1-auc:0.82215
# [31]	validation_0-auc:0.95566	validation_1-auc:0.82256
# [32]	validation_0-auc:0.95645	validation_1-auc:0.82229
# [33]	validation_0-auc:0.95731	validation_1-auc:0.82256
# [34]	validation_0-auc:0.95777	validation_1-auc:0.82242
# [35]	validation_0-auc:0.95813	validation_1-auc:0.82268
# [36]	validation_0-auc:0.95895	validation_1-auc:0.82283
# [37]	validation_0-auc:0.95948	validation_1-auc:0.82302
# [38]	validation_0-auc:0.95967	validation_1-auc:0.82328
# [39]	validation_0-auc:0.96001	validation_1-auc:0.82313
# [40]	validation_0-auc:0.96035	validation_1-auc:0.82337
# [41]	validation_0-auc:0.96077	validation_1-auc:0.82347
# [42]	validation_0-auc:0.96102	validation_1-auc:0.82346
# [43]	validation_0-auc:0.96196	validation_1-auc:0.82332
# [44]	validation_0-auc:0.96222	validation_1-auc:0.82316
# [45]	validation_0-auc:0.96237	validation_1-auc:0.82276
# [46]	validation_0-auc:0.96259	validation_1-auc:0.82262
# [47]	validation_0-auc:0.96294	validation_1-auc:0.82246
# [48]	validation_0-auc:0.96411	validation_1-auc:0.82176
# [49]	validation_0-auc:0.96443	validation_1-auc:0.82153
# [50]	validation_0-auc:0.96471	validation_1-auc:0.82108
# [51]	validation_0-auc:0.96487	validation_1-auc:0.82041
# [52]	validation_0-auc:0.96500	validation_1-auc:0.82017
# [53]	validation_0-auc:0.96528	validation_1-auc:0.82010
# [54]	validation_0-auc:0.96563	validation_1-auc:0.82015
# [55]	validation_0-auc:0.96609	validation_1-auc:0.81978
# [56]	validation_0-auc:0.96679	validation_1-auc:0.81968
# [57]	validation_0-auc:0.96686	validation_1-auc:0.81971
# [58]	validation_0-auc:0.96709	validation_1-auc:0.81940
# [59]	validation_0-auc:0.96720	validation_1-auc:0.81932
# [60]	validation_0-auc:0.96834	validation_1-auc:0.81906
# [61]	validation_0-auc:0.96942	validation_1-auc:0.81851
# [62]	validation_0-auc:0.97001	validation_1-auc:0.81818
# [63]	validation_0-auc:0.97005	validation_1-auc:0.81809
# [64]	validation_0-auc:0.97023	validation_1-auc:0.81770
# [65]	validation_0-auc:0.97026	validation_1-auc:0.81748
# [66]	validation_0-auc:0.97063	validation_1-auc:0.81702
# [67]	validation_0-auc:0.97131	validation_1-auc:0.81641
# [68]	validation_0-auc:0.97137	validation_1-auc:0.81618
# [69]	validation_0-auc:0.97150	validation_1-auc:0.81567
# [70]	validation_0-auc:0.97188	validation_1-auc:0.81559
# [0]	validation_0-auc:0.82351	validation_1-auc:0.80352
# [1]	validation_0-auc:0.83537	validation_1-auc:0.81496
# [2]	validation_0-auc:0.84724	validation_1-auc:0.82004
# [3]	validation_0-auc:0.85623	validation_1-auc:0.82225
# [4]	validation_0-auc:0.86296	validation_1-auc:0.82306
# [5]	validation_0-auc:0.86780	validation_1-auc:0.82424
# [6]	validation_0-auc:0.87343	validation_1-auc:0.82351
# [7]	validation_0-auc:0.88060	validation_1-auc:0.82668
# [8]	validation_0-auc:0.88550	validation_1-auc:0.82678
# [9]	validation_0-auc:0.89469	validation_1-auc:0.82886
# [10]	validation_0-auc:0.90028	validation_1-auc:0.82844
# [11]	validation_0-auc:0.90536	validation_1-auc:0.82733
# [12]	validation_0-auc:0.90862	validation_1-auc:0.82671
# [13]	validation_0-auc:0.91378	validation_1-auc:0.82757
# [14]	validation_0-auc:0.91648	validation_1-auc:0.82812
# [15]	validation_0-auc:0.92027	validation_1-auc:0.82875
# [16]	validation_0-auc:0.92452	validation_1-auc:0.82914
# [17]	validation_0-auc:0.92672	validation_1-auc:0.82802
# [18]	validation_0-auc:0.92864	validation_1-auc:0.82769
# [19]	validation_0-auc:0.93208	validation_1-auc:0.82794
# [20]	validation_0-auc:0.93486	validation_1-auc:0.82868
# [21]	validation_0-auc:0.93850	validation_1-auc:0.82712
# [22]	validation_0-auc:0.94030	validation_1-auc:0.82676
# [23]	validation_0-auc:0.94281	validation_1-auc:0.82533
# [24]	validation_0-auc:0.94482	validation_1-auc:0.82519
# [25]	validation_0-auc:0.94722	validation_1-auc:0.82522
# [26]	validation_0-auc:0.94892	validation_1-auc:0.82515
# [27]	validation_0-auc:0.95067	validation_1-auc:0.82464
# [28]	validation_0-auc:0.95179	validation_1-auc:0.82405
# [29]	validation_0-auc:0.95310	validation_1-auc:0.82468
# [30]	validation_0-auc:0.95442	validation_1-auc:0.82454
# [31]	validation_0-auc:0.95527	validation_1-auc:0.82512
# [32]	validation_0-auc:0.95628	validation_1-auc:0.82530
# [33]	validation_0-auc:0.95743	validation_1-auc:0.82530
# [34]	validation_0-auc:0.95801	validation_1-auc:0.82520
# [35]	validation_0-auc:0.95858	validation_1-auc:0.82518
# [36]	validation_0-auc:0.95966	validation_1-auc:0.82511
# [37]	validation_0-auc:0.96001	validation_1-auc:0.82556
# [38]	validation_0-auc:0.96014	validation_1-auc:0.82600
# [39]	validation_0-auc:0.96042	validation_1-auc:0.82561
# [40]	validation_0-auc:0.96089	validation_1-auc:0.82546
# [41]	validation_0-auc:0.96137	validation_1-auc:0.82513
# [42]	validation_0-auc:0.96204	validation_1-auc:0.82478
# [43]	validation_0-auc:0.96244	validation_1-auc:0.82485
# [44]	validation_0-auc:0.96334	validation_1-auc:0.82460
# [45]	validation_0-auc:0.96342	validation_1-auc:0.82453
# [46]	validation_0-auc:0.96419	validation_1-auc:0.82409
# [0]	validation_0-auc:0.83402	validation_1-auc:0.80769
# [1]	validation_0-auc:0.84391	validation_1-auc:0.81273
# [2]	validation_0-auc:0.85509	validation_1-auc:0.81493
# [3]	validation_0-auc:0.86119	validation_1-auc:0.81576
# [4]	validation_0-auc:0.86539	validation_1-auc:0.81647
# [5]	validation_0-auc:0.87220	validation_1-auc:0.82047
# [6]	validation_0-auc:0.87760	validation_1-auc:0.82123
# [7]	validation_0-auc:0.88138	validation_1-auc:0.82149
# [8]	validation_0-auc:0.88744	validation_1-auc:0.82345
# [9]	validation_0-auc:0.88999	validation_1-auc:0.82454
# [10]	validation_0-auc:0.89580	validation_1-auc:0.82495
# [11]	validation_0-auc:0.90159	validation_1-auc:0.82527
# [12]	validation_0-auc:0.90799	validation_1-auc:0.82698
# [13]	validation_0-auc:0.91085	validation_1-auc:0.82747
# [14]	validation_0-auc:0.91260	validation_1-auc:0.82782
# [15]	validation_0-auc:0.91695	validation_1-auc:0.82713
# [16]	validation_0-auc:0.92172	validation_1-auc:0.82640
# [17]	validation_0-auc:0.92823	validation_1-auc:0.82458
# [18]	validation_0-auc:0.93225	validation_1-auc:0.82406
# [19]	validation_0-auc:0.93473	validation_1-auc:0.82568
# [20]	validation_0-auc:0.93837	validation_1-auc:0.82576
# [21]	validation_0-auc:0.94177	validation_1-auc:0.82664
# [22]	validation_0-auc:0.94438	validation_1-auc:0.82738
# [23]	validation_0-auc:0.94626	validation_1-auc:0.82695
# [24]	validation_0-auc:0.94838	validation_1-auc:0.82815
# [25]	validation_0-auc:0.95045	validation_1-auc:0.82806
# [26]	validation_0-auc:0.95346	validation_1-auc:0.82846
# [27]	validation_0-auc:0.95547	validation_1-auc:0.82771
# [28]	validation_0-auc:0.95676	validation_1-auc:0.82691
# [29]	validation_0-auc:0.95797	validation_1-auc:0.82800
# [30]	validation_0-auc:0.95886	validation_1-auc:0.82775
# [31]	validation_0-auc:0.95976	validation_1-auc:0.82804
# [32]	validation_0-auc:0.96079	validation_1-auc:0.82878
# [33]	validation_0-auc:0.96111	validation_1-auc:0.82850
# [34]	validation_0-auc:0.96176	validation_1-auc:0.82827
# [35]	validation_0-auc:0.96321	validation_1-auc:0.82724
# [36]	validation_0-auc:0.96480	validation_1-auc:0.82808
# [37]	validation_0-auc:0.96505	validation_1-auc:0.82857
# [38]	validation_0-auc:0.96513	validation_1-auc:0.82865
# [39]	validation_0-auc:0.96595	validation_1-auc:0.82903
# [40]	validation_0-auc:0.96655	validation_1-auc:0.82917
# [41]	validation_0-auc:0.96714	validation_1-auc:0.82924
# [42]	validation_0-auc:0.96798	validation_1-auc:0.82911
# [43]	validation_0-auc:0.96822	validation_1-auc:0.82934
# [44]	validation_0-auc:0.96845	validation_1-auc:0.82933
# [45]	validation_0-auc:0.96849	validation_1-auc:0.82907
# [46]	validation_0-auc:0.96898	validation_1-auc:0.82868
# [47]	validation_0-auc:0.96916	validation_1-auc:0.82865
# [48]	validation_0-auc:0.97019	validation_1-auc:0.82886
# [49]	validation_0-auc:0.97053	validation_1-auc:0.82896
# [50]	validation_0-auc:0.97078	validation_1-auc:0.82860
# [51]	validation_0-auc:0.97091	validation_1-auc:0.82849
# [52]	validation_0-auc:0.97106	validation_1-auc:0.82838
# [53]	validation_0-auc:0.97136	validation_1-auc:0.82845
# [54]	validation_0-auc:0.97169	validation_1-auc:0.82842
# [55]	validation_0-auc:0.97173	validation_1-auc:0.82832
# [56]	validation_0-auc:0.97191	validation_1-auc:0.82807
# [57]	validation_0-auc:0.97217	validation_1-auc:0.82796
# [58]	validation_0-auc:0.97226	validation_1-auc:0.82777
# [59]	validation_0-auc:0.97232	validation_1-auc:0.82760
# [60]	validation_0-auc:0.97244	validation_1-auc:0.82798
# [61]	validation_0-auc:0.97252	validation_1-auc:0.82773
# [62]	validation_0-auc:0.97343	validation_1-auc:0.82743
# [63]	validation_0-auc:0.97362	validation_1-auc:0.82759
# [64]	validation_0-auc:0.97367	validation_1-auc:0.82753
# [65]	validation_0-auc:0.97373	validation_1-auc:0.82729
# [66]	validation_0-auc:0.97382	validation_1-auc:0.82714
# [67]	validation_0-auc:0.97385	validation_1-auc:0.82716
# [68]	validation_0-auc:0.97394	validation_1-auc:0.82678
# [69]	validation_0-auc:0.97399	validation_1-auc:0.82673
# [70]	validation_0-auc:0.97563	validation_1-auc:0.82602
# [71]	validation_0-auc:0.97568	validation_1-auc:0.82575
# [72]	validation_0-auc:0.97587	validation_1-auc:0.82578
# [73]	validation_0-auc:0.97640	validation_1-auc:0.82582
# 100%|██████████| 5/5 [06:34<00:00, 78.85s/trial, best loss: -0.8364421299269358]
# {'colsample_bytree': 0.753532317468581, 'learning_rate': 0.08326583869166816, 'max_depth': 6.0, 'min_chile_weight': 2.0}

# %%
best
# Out:
# {'colsample_bytree': 0.753532317468581,
#  'learning_rate': 0.08326583869166816,
#  'max_depth': 6.0,
#  'min_child_weight': 2.0}

# %%
xgb_clf = XGBClassifier(n_estimators=500, max_depth=int(5),
                           colsample_bytree=(0.5749),
                            learning_rate=(0.1514),
                       min_child_weight=int(6))
xgb_clf.fit(X_tr, y_tr, early_stopping_rounds=100, eval_metric="auc", eval_set=[(X_tr,y_tr),(X_val,y_val)], )
# Out:
# [0]	validation_0-auc:0.82138	validation_1-auc:0.80582
# [1]	validation_0-auc:0.82690	validation_1-auc:0.80718
# [2]	validation_0-auc:0.82980	validation_1-auc:0.80998
# [3]	validation_0-auc:0.83199	validation_1-auc:0.81322
# [4]	validation_0-auc:0.84005	validation_1-auc:0.82142
# [5]	validation_0-auc:0.83960	validation_1-auc:0.82025
# [6]	validation_0-auc:0.84260	validation_1-auc:0.82294
# [7]	validation_0-auc:0.84600	validation_1-auc:0.82389
# [8]	validation_0-auc:0.84796	validation_1-auc:0.82385
# [9]	validation_0-auc:0.84879	validation_1-auc:0.82395
# [10]	validation_0-auc:0.85031	validation_1-auc:0.82518
# [11]	validation_0-auc:0.85036	validation_1-auc:0.82588
# [12]	validation_0-auc:0.84961	validation_1-auc:0.82343
# [13]	validation_0-auc:0.85165	validation_1-auc:0.82348
# [14]	validation_0-auc:0.85382	validation_1-auc:0.82722
# [15]	validation_0-auc:0.85626	validation_1-auc:0.82951
# [16]	validation_0-auc:0.85694	validation_1-auc:0.83084
# [17]	validation_0-auc:0.85740	validation_1-auc:0.83121
# [18]	validation_0-auc:0.85709	validation_1-auc:0.83069
# [19]	validation_0-auc:0.85911	validation_1-auc:0.83230
# [20]	validation_0-auc:0.86086	validation_1-auc:0.83328
# [21]	validation_0-auc:0.86269	validation_1-auc:0.83359
# [22]	validation_0-auc:0.86367	validation_1-auc:0.83300
# [23]	validation_0-auc:0.86358	validation_1-auc:0.83293
# [24]	validation_0-auc:0.86454	validation_1-auc:0.83305
# [25]	validation_0-auc:0.86569	validation_1-auc:0.83288
# [26]	validation_0-auc:0.86706	validation_1-auc:0.83377
# [27]	validation_0-auc:0.86787	validation_1-auc:0.83431
# [28]	validation_0-auc:0.86892	validation_1-auc:0.83472
# [29]	validation_0-auc:0.86934	validation_1-auc:0.83497
# [30]	validation_0-auc:0.86968	validation_1-auc:0.83460
# [31]	validation_0-auc:0.87047	validation_1-auc:0.83438
# [32]	validation_0-auc:0.87115	validation_1-auc:0.83492
# [33]	validation_0-auc:0.87202	validation_1-auc:0.83545
# [34]	validation_0-auc:0.87272	validation_1-auc:0.83537
# [35]	validation_0-auc:0.87383	validation_1-auc:0.83533
# [36]	validation_0-auc:0.87446	validation_1-auc:0.83561
# [37]	validation_0-auc:0.87514	validation_1-auc:0.83626
# [38]	validation_0-auc:0.87544	validation_1-auc:0.83619
# [39]	validation_0-auc:0.87577	validation_1-auc:0.83617
# [40]	validation_0-auc:0.87615	validation_1-auc:0.83645
# [41]	validation_0-auc:0.87650	validation_1-auc:0.83673
# [42]	validation_0-auc:0.87747	validation_1-auc:0.83665
# [43]	validation_0-auc:0.87762	validation_1-auc:0.83660
# [44]	validation_0-auc:0.87811	validation_1-auc:0.83686
# [45]	validation_0-auc:0.87833	validation_1-auc:0.83686
# [46]	validation_0-auc:0.87891	validation_1-auc:0.83685
# [47]	validation_0-auc:0.87955	validation_1-auc:0.83687
# [48]	validation_0-auc:0.87979	validation_1-auc:0.83732
# [49]	validation_0-auc:0.88022	validation_1-auc:0.83723
# [50]	validation_0-auc:0.88039	validation_1-auc:0.83716
# [51]	validation_0-auc:0.88082	validation_1-auc:0.83730
# [52]	validation_0-auc:0.88119	validation_1-auc:0.83744
# [53]	validation_0-auc:0.88154	validation_1-auc:0.83796
# [54]	validation_0-auc:0.88215	validation_1-auc:0.83782
# [55]	validation_0-auc:0.88226	validation_1-auc:0.83782
# [56]	validation_0-auc:0.88238	validation_1-auc:0.83765
# [57]	validation_0-auc:0.88285	validation_1-auc:0.83775
# [58]	validation_0-auc:0.88289	validation_1-auc:0.83750
# [59]	validation_0-auc:0.88351	validation_1-auc:0.83753
# [60]	validation_0-auc:0.88373	validation_1-auc:0.83766
# [61]	validation_0-auc:0.88382	validation_1-auc:0.83779
# [62]	validation_0-auc:0.88404	validation_1-auc:0.83765
# [63]	validation_0-auc:0.88508	validation_1-auc:0.83767
# [64]	validation_0-auc:0.88533	validation_1-auc:0.83773
# [65]	validation_0-auc:0.88559	validation_1-auc:0.83777
# [66]	validation_0-auc:0.88606	validation_1-auc:0.83738
# [67]	validation_0-auc:0.88653	validation_1-auc:0.83764
# [68]	validation_0-auc:0.88723	validation_1-auc:0.83747
# [69]	validation_0-auc:0.88742	validation_1-auc:0.83743
# [70]	validation_0-auc:0.88760	validation_1-auc:0.83768
# [71]	validation_0-auc:0.88834	validation_1-auc:0.83774
# [72]	validation_0-auc:0.88857	validation_1-auc:0.83764
# [73]	validation_0-auc:0.88901	validation_1-auc:0.83777
# [74]	validation_0-auc:0.88951	validation_1-auc:0.83800
# [75]	validation_0-auc:0.88973	validation_1-auc:0.83807
# [76]	validation_0-auc:0.88978	validation_1-auc:0.83801
# [77]	validation_0-auc:0.89057	validation_1-auc:0.83798
# [78]	validation_0-auc:0.89099	validation_1-auc:0.83796
# [79]	validation_0-auc:0.89160	validation_1-auc:0.83806
# [80]	validation_0-auc:0.89233	validation_1-auc:0.83764
# [81]	validation_0-auc:0.89251	validation_1-auc:0.83754
# [82]	validation_0-auc:0.89262	validation_1-auc:0.83739
# [83]	validation_0-auc:0.89345	validation_1-auc:0.83723
# [84]	validation_0-auc:0.89351	validation_1-auc:0.83709
# [85]	validation_0-auc:0.89367	validation_1-auc:0.83717
# [86]	validation_0-auc:0.89401	validation_1-auc:0.83728
# [87]	validation_0-auc:0.89413	validation_1-auc:0.83720
# [88]	validation_0-auc:0.89431	validation_1-auc:0.83713
# [89]	validation_0-auc:0.89482	validation_1-auc:0.83709
# [90]	validation_0-auc:0.89507	validation_1-auc:0.83722
# [91]	validation_0-auc:0.89570	validation_1-auc:0.83731
# [92]	validation_0-auc:0.89643	validation_1-auc:0.83733
# [93]	validation_0-auc:0.89718	validation_1-auc:0.83736
# [94]	validation_0-auc:0.89787	validation_1-auc:0.83728
# [95]	validation_0-auc:0.89835	validation_1-auc:0.83708
# [96]	validation_0-auc:0.89844	validation_1-auc:0.83693
# [97]	validation_0-auc:0.89874	validation_1-auc:0.83671
# [98]	validation_0-auc:0.89914	validation_1-auc:0.83637
# [99]	validation_0-auc:0.89952	validation_1-auc:0.83638
# [100]	validation_0-auc:0.89962	validation_1-auc:0.83635
# [101]	validation_0-auc:0.89972	validation_1-auc:0.83657
# [102]	validation_0-auc:0.89989	validation_1-auc:0.83643
# [103]	validation_0-auc:0.89996	validation_1-auc:0.83620
# [104]	validation_0-auc:0.90051	validation_1-auc:0.83630
# [105]	validation_0-auc:0.90053	validation_1-auc:0.83633
# [106]	validation_0-auc:0.90057	validation_1-auc:0.83628
# [107]	validation_0-auc:0.90063	validation_1-auc:0.83633
# [108]	validation_0-auc:0.90102	validation_1-auc:0.83640
# [109]	validation_0-auc:0.90109	validation_1-auc:0.83632
# [110]	validation_0-auc:0.90136	validation_1-auc:0.83620
# [111]	validation_0-auc:0.90190	validation_1-auc:0.83584
# [112]	validation_0-auc:0.90218	validation_1-auc:0.83564
# [113]	validation_0-auc:0.90229	validation_1-auc:0.83545
# [114]	validation_0-auc:0.90269	validation_1-auc:0.83535
# [115]	validation_0-auc:0.90304	validation_1-auc:0.83521
# [116]	validation_0-auc:0.90344	validation_1-auc:0.83504
# [117]	validation_0-auc:0.90369	validation_1-auc:0.83491
# [118]	validation_0-auc:0.90398	validation_1-auc:0.83488
# [119]	validation_0-auc:0.90427	validation_1-auc:0.83506
# [120]	validation_0-auc:0.90434	validation_1-auc:0.83489
# [121]	validation_0-auc:0.90499	validation_1-auc:0.83474
# [122]	validation_0-auc:0.90506	validation_1-auc:0.83467
# [123]	validation_0-auc:0.90526	validation_1-auc:0.83481
# [124]	validation_0-auc:0.90534	validation_1-auc:0.83498
# [125]	validation_0-auc:0.90542	validation_1-auc:0.83500
# [126]	validation_0-auc:0.90565	validation_1-auc:0.83506
# [127]	validation_0-auc:0.90602	validation_1-auc:0.83520
# [128]	validation_0-auc:0.90661	validation_1-auc:0.83522
# [129]	validation_0-auc:0.90670	validation_1-auc:0.83515
# [130]	validation_0-auc:0.90677	validation_1-auc:0.83516
# [131]	validation_0-auc:0.90722	validation_1-auc:0.83504
# [132]	validation_0-auc:0.90727	validation_1-auc:0.83502
# [133]	validation_0-auc:0.90733	validation_1-auc:0.83505
# [134]	validation_0-auc:0.90742	validation_1-auc:0.83502
# [135]	validation_0-auc:0.90755	validation_1-auc:0.83505
# [136]	validation_0-auc:0.90773	validation_1-auc:0.83497
# [137]	validation_0-auc:0.90804	validation_1-auc:0.83497
# [138]	validation_0-auc:0.90836	validation_1-auc:0.83491
# [139]	validation_0-auc:0.90892	validation_1-auc:0.83486
# [140]	validation_0-auc:0.90899	validation_1-auc:0.83476
# [141]	validation_0-auc:0.90915	validation_1-auc:0.83444
# [142]	validation_0-auc:0.90942	validation_1-auc:0.83459
# [143]	validation_0-auc:0.90947	validation_1-auc:0.83458
# [144]	validation_0-auc:0.90952	validation_1-auc:0.83448
# [145]	validation_0-auc:0.90959	validation_1-auc:0.83440
# [146]	validation_0-auc:0.90965	validation_1-auc:0.83432
# [147]	validation_0-auc:0.90990	validation_1-auc:0.83425
# [148]	validation_0-auc:0.90998	validation_1-auc:0.83406
# [149]	validation_0-auc:0.91008	validation_1-auc:0.83396
# [150]	validation_0-auc:0.91031	validation_1-auc:0.83398
# [151]	validation_0-auc:0.91036	validation_1-auc:0.83394
# [152]	validation_0-auc:0.91044	validation_1-auc:0.83387
# [153]	validation_0-auc:0.91095	validation_1-auc:0.83384
# [154]	validation_0-auc:0.91097	validation_1-auc:0.83378
# [155]	validation_0-auc:0.91131	validation_1-auc:0.83360
# [156]	validation_0-auc:0.91134	validation_1-auc:0.83348
# [157]	validation_0-auc:0.91154	validation_1-auc:0.83333
# [158]	validation_0-auc:0.91182	validation_1-auc:0.83331
# [159]	validation_0-auc:0.91192	validation_1-auc:0.83317
# [160]	validation_0-auc:0.91228	validation_1-auc:0.83316
# [161]	validation_0-auc:0.91241	validation_1-auc:0.83311
# [162]	validation_0-auc:0.91280	validation_1-auc:0.83307
# [163]	validation_0-auc:0.91300	validation_1-auc:0.83309
# [164]	validation_0-auc:0.91305	validation_1-auc:0.83311
# [165]	validation_0-auc:0.91309	validation_1-auc:0.83315
# [166]	validation_0-auc:0.91345	validation_1-auc:0.83304
# [167]	validation_0-auc:0.91377	validation_1-auc:0.83286
# [168]	validation_0-auc:0.91396	validation_1-auc:0.83297
# [169]	validation_0-auc:0.91416	validation_1-auc:0.83288
# [170]	validation_0-auc:0.91420	validation_1-auc:0.83290
# [171]	validation_0-auc:0.91437	validation_1-auc:0.83279
# [172]	validation_0-auc:0.91442	validation_1-auc:0.83283
# [173]	validation_0-auc:0.91463	validation_1-auc:0.83308
# [174]	validation_0-auc:0.91464	validation_1-auc:0.83297
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.5749,
#               enable_categorical=False, gamma=0, gpu_id=-1,
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.1514, max_delta_step=0, max_depth=5,
#               min_child_weight=6, missing=nan, monotone_constraints='()',
#               n_estimators=500, n_jobs=8, num_parallel_tree=1, predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
score = roc_auc_score(y_test, xgb_clf.predict_proba(X_test)[:,1])
score
# Out:
# 0.8445410386927894

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(1,1,figsize=(10,8))
plot_importance(xgb_clf, ax=ax, max_num_features=20, height=0.4)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ## 1.4.3 LightGBM 모델학습과 하이퍼 파라미터 튜닝

# %%
from lightgbm import LGBMClassifier

lgbm_clf = LGBMClassifier(n_estimators=500)

eval_set=[(X_tr, y_tr), (X_val, y_val)]
lgbm_clf.fit(X_tr, y_tr, early_stopping_rounds=100, eval_metric="auc", eval_set=eval_set, verbose=0)

print("ROC AUC socre: ", roc_auc_score(y_test,lgbm_clf.predict_proba(X_test)[:, 1]))
# Out:
# ROC AUC socre:  0.8371932301150327

# %%
from hyperopt import hp
lgbm_search_space={'max_depth':hp.quniform('max_depth',100, 160, 1),
                  'num_leaves':hp.quniform('num_leaves', 32, 64, 1),
                  'min_child_samples':hp.quniform('min_child_samples', 60, 100, 1),
                  'learning_rate':hp.uniform('learning_rate', 0.01, 0.2),
                 'subsample':hp.uniform('subsample',0.7,1)}

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score

def objective_func(search_space):
    lgbm_clf = LGBMClassifier(n_estimators=100, max_depth=int(search_space['max_depth']),
                           min_child_samples=int(search_space['min_child_samples']),
                           subsample=search_space['subsample'],
                            learning_rate=search_space['learning_rate'])
    roc_auc_list= []
    skf = StratifiedKFold(n_splits=3)
    
    for tr_index, val_index in skf.split(X_train, y_train):
        X_tr, y_tr = X_train.iloc[tr_index], y_train.iloc[tr_index]
        X_val, y_val = X_train.iloc[val_index], y_train.iloc[val_index]
        
        lgbm_clf.fit(X_tr, y_tr, early_stopping_rounds=30, eval_metric='auc', eval_set=[(X_tr, y_tr),(X_val,y_val)], )
        
        score = roc_auc_score(y_val, xgb_clf.predict_proba(X_val)[:,1])
        roc_auc_list.append(score)
    return -1*np.mean(roc_auc_list)

# %%
from hyperopt import fmin, tpe, Trials

trials = Trials()

best = fmin(fn=objective_func,
           space=lgbm_search_space,
           algo=tpe.suggest,
           max_evals=5,
           trials=trials,rstate=np.random.default_rng(seed=30))
print(best)
# Out:
# [1]	training's auc: 0.826575	training's binary_logloss: 0.162639	valid_1's auc: 0.805095	valid_1's binary_logloss: 0.162899
# [2]	training's auc: 0.827079	training's binary_logloss: 0.160648	valid_1's auc: 0.805323	valid_1's binary_logloss: 0.161216
# [3]	training's auc: 0.832193	training's binary_logloss: 0.158871	valid_1's auc: 0.807771	valid_1's binary_logloss: 0.159738
# [4]	training's auc: 0.836267	training's binary_logloss: 0.157231	valid_1's auc: 0.811605	valid_1's binary_logloss: 0.158364
# [70]	training's auc: 0.902882	training's binary_logloss: 0.116551	valid_1's auc: 0.839739	valid_1's binary_logloss: 0.132844
# [71]	training's auc: 0.903571	training's binary_logloss: 0.116314	valid_1's auc: 0.839703	valid_1's binary_logloss: 0.132853
# [72]	training's auc: 0.904091	training's binary_logloss: 0.116111	valid_1's auc: 0.839729	valid_1's binary_logloss: 0.132851
# [73]	training's auc: 0.904464	training's binary_logloss: 0.115951	valid_1's auc: 0.83972	valid_1's binary_logloss: 0.132848
# [74]	training's auc: 0.904843	training's binary_logloss: 0.115795	valid_1's auc: 0.839929	valid_1's binary_logloss: 0.132791
# [75]	training's auc: 0.905344	training's binary_logloss: 0.115605	valid_1's auc: 0.839639	valid_1's binary_logloss: 0.132835
# [76]	training's auc: 0.90587	training's binary_logloss: 0.115375	valid_1's auc: 0.839737	valid_1's binary_logloss: 0.132826
# [77]	training's auc: 0.906492	training's binary_logloss: 0.115157	valid_1's auc: 0.83968	valid_1's binary_logloss: 0.132829
# [78]	training's auc: 0.906889	training's binary_logloss: 0.114973	valid_1's auc: 0.839347	valid_1's binary_logloss: 0.132898
# [79]	training's auc: 0.907416	training's binary_logloss: 0.114777	valid_1's auc: 0.839179	valid_1's binary_logloss: 0.132932
# [80]	training's auc: 0.907941	training's binary_logloss: 0.114577	valid_1's auc: 0.839164	valid_1's binary_logloss: 0.132951
# [81]	training's auc: 0.908402	training's binary_logloss: 0.114391	valid_1's auc: 0.839088	valid_1's binary_logloss: 0.132957
# [82]	training's auc: 0.909326	training's binary_logloss: 0.114202	valid_1's auc: 0.839083	valid_1's binary_logloss: 0.132953
# [83]	training's auc: 0.909627	training's binary_logloss: 0.114049	valid_1's auc: 0.839195	valid_1's binary_logloss: 0.132946
# [84]	training's auc: 0.910352	training's binary_logloss: 0.113856	valid_1's auc: 0.839214	valid_1's binary_logloss: 0.132943
# [85]	training's auc: 0.910669	training's binary_logloss: 0.113697	valid_1's auc: 0.83906	valid_1's binary_logloss: 0.132975
# [86]	training's auc: 0.911023	training's binary_logloss: 0.113542	valid_1's auc: 0.838747	valid_1's binary_logloss: 0.133028
# [87]	training's auc: 0.91143	training's binary_logloss: 0.113355	valid_1's auc: 0.83894	valid_1's binary_logloss: 0.13299
# [88]	training's auc: 0.91173	training's binary_logloss: 0.113202	valid_1's auc: 0.838857	valid_1's binary_logloss: 0.133035
# [89]	training's auc: 0.912091	training's binary_logloss: 0.113024	valid_1's auc: 0.838986	valid_1's binary_logloss: 0.133003
# [90]	training's auc: 0.912499	training's binary_logloss: 0.112857	valid_1's auc: 0.839016	valid_1's binary_logloss: 0.132996
# [91]	training's auc: 0.912957	training's binary_logloss: 0.112657	valid_1's auc: 0.838976	valid_1's binary_logloss: 0.132995
# 100%|██████████| 5/5 [00:35<00:00,  7.18s/trial, best loss: -0.8694849829237207]
# {'learning_rate': 0.02347777899863792, 'max_depth': 134.0, 'min_child_samples': 75.0, 'num_leaves': 34.0, 'subsample': 0.7754775757159653}

# %%
lgbm_clf = LGBMClassifier(n_estimators=500, num_leaves=int(best['num_leaves']),
                         max_depth=int(best['max_depth']),
                         min_child_samples=int(best['min_child_samples']),
                         subsample=round(best['subsample'], 5),
                         learning_rate=round(best['learning_rate'],5)
                         )
lgbm_clf.fit(X_tr, y_tr, early_stopping_rounds=100,
            eval_metric="auc", eval_set=[(X_tr,y_tr),(X_val,y_val)], verbose=0)

print('ROC AUC: ', roc_auc_score(y_test,xgb_clf.predict_proba(X_test)[:,1]))
# Out:
# ROC AUC:  0.8409421286122255

# %% [markdown]
# # 1.5 캐글 신용카드 사기 검출

# %% [markdown]
# # 1.5.1 데이터 살펴보기

# %%
datasets = pd.read_csv("creditcard.csv")
credit_df = pd.DataFrame(datasets)

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
credit_df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.473120e-16  8.042109e-16  5.282512e-16  4.456271e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.426896e-15  1.701640e-15 -3.662252e-16 -1.217809e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
credit_df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# 비대칭적인 데이터 셋

# %% [markdown]
# # 1.5.2 언더 샘플링과 오버 샘플링의 이해

# %% [markdown]
# 레이블이 비대칭적인 데이터를 학습할 때 모델이 잘 학습 되지 않는 경우가 있는데, 이는 레이블이 정상 데이터만 학습을 해서  제대로 학습을 못하기 때문이다. <br>이런 문제는 언더 샘플링(UnderSampling)과 오버 샘플링(OverSampling)을 이용해서 문제점을 해결할 수 있다.
# ![image.png](attachment:image.png)
# 보통 오버 샘플링의 예측 성능이 뛰어난데,
# <br>오버샘플링은 SMOTE 방법을 이용해서 사용할 수 있다.
# ### SMOTE
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 1.5.3 데이터 전처리

# %%
# 필요없는 Time 컬럼 없애기
def get_preprocessed_df(df=None):
    df_copy = df.copy()
    df_copy.drop('Time', inplace=True, axis=1)
    return df_copy

def get_train_test_dataset(df=None):
    df_copy = get_preprocessed_df(df)
    
    X_features = df_copy.iloc[:, :-1]
    y_target = df_copy.iloc[:, -1]
    
    X_train, X_test, y_train, y_test = \
    train_test_split(X_features, y_target, test_size=0.2, random_state=0, stratify = y_target)
    
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = get_train_test_dataset(credit_df)

# %%
print( '학습데이터 레이블 비율')
print(y_train.value_counts()/y_train.count()*100)
print( '\n테스트 데이터 레이블 비율')
print(y_test.value_counts()/y_test.count()*100)
# Out:
# 학습데이터 레이블 비율
# 0    99.827075
# 1     0.172925
# Name: Class, dtype: float64
#
# 테스트 데이터 레이블 비율
# 0    99.827955
# 1     0.172045
# Name: Class, dtype: float64

# %% [markdown]
# # 1.5.4 Logistic 회귀 모델 학습/평가

# %%
from sklearn.linear_model import LogisticRegression

lr_clf = LogisticRegression(max_iter=1000)
lr_clf.fit(X_train, y_train)
lr_pred = lr_clf.predict(X_test)
lr_pred_proba = lr_clf.predict_proba(X_test)[:,1]

get_clf_eval(y_test, lr_pred, lr_pred_proba)
# Out:
# 오차행렬:
# [[56853    11]
#  [   36    62]]
#
# 정확도: 0.9992, 정밀도: 0.8493, 재현율: 0.6327, f1 스코어: 0.7251, AUC: 0.9635

# %%
def get_clf_train_eval(model, ftr_train=None, ftr_test=None, tgt_train=None, tgt_test=None):
    model.fit(ftr_train, tgt_train)
    get_clf_eval(tgt_test,model.predict(ftr_test), model.predict_proba(ftr_test)[:, 1])

# %% [markdown]
# # 1.5.5 LGBM 모델 학습/평가

# %%
from lightgbm import LGBMClassifier

lgbm_clf = LGBMClassifier(n_estimators= 1000, num_leaves=64, n_jobs=1, boost_from_average=False)
get_clf_train_eval(lgbm_clf, X_train, X_test, y_train, y_test)
# Out:
# 오차행렬:
# [[56860     4]
#  [   24    74]]
#
# 정확도: 0.9995, 정밀도: 0.9487, 재현율: 0.7551, f1 스코어: 0.8409, AUC: 0.9782

# %%
from lightgbm import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10,12))
plot_importance(lgbm_clf, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# # 1.5.6 데이터 분포도 정규분포로 변환 후 모델 학습/예측/평가

# %% [markdown]
# 대부분의 선형 모델은 중요피처들이 정규 분포 형태를 유지하는 것을 선호한다. 데이터셋에서 중요한 피처를 정규분포 형태로 바꾸어 보자

# %%
import seaborn as sns

plt.figure(figsize=(8,4))
plt.xticks(range(0,30000,1000), rotation=60)
sns.histplot(credit_df['Amount'], bins=100, kde=True)
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.xticks(range(0,30000,1000), rotation=60)
sns.histplot(credit_df['V4'], bins=100, kde=True)
plt.show()

# %% [markdown]
# Amount 피처를 정규 분포 형태로 반환해보자.

# %%
from sklearn.preprocessing import StandardScaler

def get_preprocessed_df(df=None):
    df_copy = df.copy()
    scaler = StandardScaler()
    amount_n = scaler.fit_transform(df_copy['Amount'].values.reshape(-1,1))
    df_copy.insert(0, 'Amount_Scaled',amount_n)
    df_copy.drop(['Time','Amount'], inplace=True, axis=1)
    return df_copy

# %%
get_preprocessed_df(credit_df)

X_train, X_test, y_train, y_test = get_train_test_dataset(credit_df)

lr_clf = LogisticRegression(max_iter=1000)
print('로지스틱 회귀 모델 예측 성능')
get_clf_train_eval(lr_clf, X_train, X_test, y_train, y_test)
print('\nLight GBM 모델 예측 성능')
get_clf_train_eval(lgbm_clf, X_train, X_test, y_train, y_test)
# Out:
# 로지스틱 회귀 모델 예측 성능
# 오차행렬:
# [[56853    11]
#  [   36    62]]
#
# 정확도: 0.9992, 정밀도: 0.8493, 재현율: 0.6327, f1 스코어: 0.7251, AUC: 0.9634
#
#
#
# Light GBM 모델 예측 성능
# 오차행렬:
# [[56860     4]
#  [   24    74]]
#
# 정확도: 0.9995, 정밀도: 0.9487, 재현율: 0.7551, f1 스코어: 0.8409, AUC: 0.9738

# %% [markdown]
# # 1.5.7 데이터 로그 변환

# %%
from sklearn.preprocessing import StandardScaler

def get_preprocessed_df(df=None):
    df_copy = df.copy()
    scaler = StandardScaler()
    amount_n = np.log1p(df_copy['Amount'])
    df_copy.insert(0, 'Amount_Scaled',amount_n)
    df_copy.drop(['Time','Amount'], inplace=True, axis=1)
    return df_copy

get_preprocessed_df(credit_df)

X_train, X_test, y_train, y_test = get_train_test_dataset(credit_df)

lr_clf = LogisticRegression(max_iter=1000)
print('로지스틱 회귀 모델 예측 성능')
get_clf_train_eval(lr_clf, X_train, X_test, y_train, y_test)
print('\nLight GBM 모델 예측 성능')
get_clf_train_eval(lgbm_clf, X_train, X_test, y_train, y_test)
# Out:
# 로지스틱 회귀 모델 예측 성능
# 오차행렬:
# [[56854    10]
#  [   36    62]]
#
# 정확도: 0.9992, 정밀도: 0.8611, 재현율: 0.6327, f1 스코어: 0.7294, AUC: 0.9666
#
#
#
# Light GBM 모델 예측 성능
# 오차행렬:
# [[56860     4]
#  [   23    75]]
#
# 정확도: 0.9995, 정밀도: 0.9494, 재현율: 0.7653, f1 스코어: 0.8475, AUC: 0.9794

# %% [markdown]
# 로지스틱 회귀는 데이터의 label이 비대칭 적일때 불안정한 성능을 보인다.

# %% [markdown]
# # 1.5.8 이상치 데이터 제거 후 모델 학습/예측/평가

# %%
import seaborn as sns 
plt.figure(figsize=(9,9))
corr = credit_df.corr()
sns.heatmap(corr, cmap='RdBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 상관관계가 높은 피처 이상값 제거 하기

# %%
import numpy as np

def det_outlier(df=None, column=None, weight=1.5):
    # class가 1인 데이터만 선별
    fraud = df[df['Class']==1][column]
    quantile_25 = np.percentile(fraud.values, 25)
    quantile_75 = np.percentile(fraud.values, 75)
    
    iqr = quantile_75 -quantile_25
    iqr_weight = iqr*weight
    lowest = quantile_25 - iqr_weight
    highest = quantile_75 + iqr_weight
    
    outlier_index = fraud[(fraud<lowest)|(fraud>highest)].index
    return outlier_index

# %%
outliner1 = det_outlier(credit_df, 'V14', weight=1.5)
# Out:
# Int64Index([], dtype='int64')

# %%
def get_preprocessed_df(df=None):
    df_copy = df.copy()
    scaler = StandardScaler()
    amount_n = np.log1p(df_copy['Amount'])
    df_copy.insert(0, 'Amount_Scaled',amount_n)
    df_copy.drop(['Time','Amount'], inplace=True, axis=1)
    
    df_copy.drop(outliner1, inplace=True, axis=0)

    return df_copy

get_preprocessed_df(credit_df)

X_train, X_test, y_train, y_test = get_train_test_dataset(credit_df)

lr_clf = LogisticRegression(max_iter=1000)
print('로지스틱 회귀 모델 예측 성능')
get_clf_train_eval(lr_clf, X_train, X_test, y_train, y_test)
print('\nLight GBM 모델 예측 성능')
get_clf_train_eval(lgbm_clf, X_train, X_test, y_train, y_test)
# Out:
# 로지스틱 회귀 모델 예측 성능
# 오차행렬:
# [[56853    10]
#  [   34    64]]
#
# 정확도: 0.9992, 정밀도: 0.8649, 재현율: 0.6531, f1 스코어: 0.7442, AUC: 0.9643
#
#
#
# Light GBM 모델 예측 성능
# 오차행렬:
# [[56859     4]
#  [   19    79]]
#
# 정확도: 0.9996, 정밀도: 0.9518, 재현율: 0.8061, f1 스코어: 0.8729, AUC: 0.9743

# %% [markdown]
# # 1.5.9 SMOTE를 이용한 오버샘플링
# 단, train셋에만 적용해야 한다.

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=0)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)
print('SMOTE 적용 전 피처/레이블 데이터 크기: ', X_train.shape, y_train.shape)
print('SMOTE 적용 후 피처/레이블 데이터 크기: ', X_train_over.shape, y_train_over.shape)
print('SMOTE 적용 후 레이블 분포: ' )
print(y_train_over.value_counts())
# Out:
# SMOTE 적용 전 피처/레이블 데이터 크기:  (227842, 29) (227842,)
# SMOTE 적용 후 피처/레이블 데이터 크기:  (454904, 29) (454904,)
# SMOTE 적용 후 레이블 분포:
# 0    227452
# 1    227452
# Name: Class, dtype: int64

# %%
lr_clf = LogisticRegression(max_iter=1000)
get_clf_train_eval(lr_clf, X_train_over, X_test, y_train_over, y_test)
# Out:
# 오차행렬:
# [[55324  1539]
#  [   10    88]]
#
# 정확도: 0.9728, 정밀도: 0.0541, 재현율: 0.898, f1 스코어: 0.102, AUC: 0.9645

# %%
lgbm_clf = LGBMClassifier(n_estimators=1000, num_leaves=64, n_jobs=-1, boost_from_average=False)
get_clf_train_eval(lgbm_clf, X_train_over, X_test, y_train_over, y_test)
# Out:
# 오차행렬:
# [[56856     7]
#  [   17    81]]
#
# 정확도: 0.9996, 정밀도: 0.9205, 재현율: 0.8265, f1 스코어: 0.871, AUC: 0.9833

# %% [markdown]
# #### 오버샘플링을 적용하면 재현율은 높아지나 정밀도는 낮아진다.

# %% [markdown]
# # 1.6 스태킹 앙상블

# %% [markdown]
# ## 1.6.1 기본 스태킹 모델

# %% [markdown]
# 스태킹은 개별적인 여러 알고리즘을 서로 결합해 예측 셜과를 도출한다는 점에서 앞에 소개한 배깅 및 부스팅과 공통점을 가지고 있다.<br>
# 하지만 가장 큰 차이점은 개별 알고리즘으로 예측한 데이터를 기반으로 다시 예측을 수행하는 것이다. <br>
#
# 즉, 개별 알고리즘의 예측을 통해서 메타 데이터 세트로 만들어서 별도의 ML알고리즘을 최종학습을 수행하는 모델이다.
#
# 스태킹 앙상블을 위해서는 1. 개별적인 기반 모델과, 2. 기반모델의 예측값으로 만든 메타데이터를 학습하는 최종 메타 모델이 필요하다.

# %%
import numpy as np

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

cancer_data =load_breast_cancer()

X_data = cancer_data.data
y_label = cancer_data.target

X_train, X_test, y_train, y_test = train_test_split(X_data, y_label, test_size=0.2, random_state=0)

knn_clf = KNeighborsClassifier(n_neighbors=4)
rf_clf = RandomForestClassifier(n_estimators=100, random_state=0)
dt_clf = DecisionTreeClassifier()
ada_clf= AdaBoostClassifier(n_estimators=100)

lr_final = LogisticRegression()

knn_clf.fit(X_train, y_train)
rf_clf.fit(X_train, y_train)
dt_clf.fit(X_train, y_train)
ada_clf.fit(X_train, y_train)

knn_pred = knn_clf.predict(X_test)
rf_pred = rf_clf.predict(X_test)
dt_pred = dt_clf.predict(X_test)
ada_pred = ada_clf.predict(X_test)

print("KNN 정확도: ", round(accuracy_score(y_test, knn_pred),4))
print("랜덤포레스트 정확도: ", round(accuracy_score(y_test, rf_pred),4))
print("결정 트리 정확도: ", round(accuracy_score(y_test, dt_pred),4))
print("에이다 부스트 정확도: ", round(accuracy_score(y_test, ada_pred),4))
# Out:
# KNN 정확도:  0.9211
# 랜덤포레스트 정확도:  0.9649
# 결정 트리 정확도:  0.9035
# 에이다 부스트 정확도:  0.9561

# %%
pred = np.array([knn_pred, rf_pred, dt_pred, ada_pred])
print(pred.shape)

pred = np.transpose(pred)
print(pred.shape)
# Out:
# (4, 114)
# (114, 4)

# %%
lr_final.fit(pred, y_test)
print('최종 메타 모델 정확도: {0:.4f}'.format(accuracy_score(lr_final.predict(pred), y_test)))
# Out:
# 최종 메타 모델 정확도: 0.9737

# %% [markdown]
# # 1.6.2 CV 세트 기반의 스태킹
# ####방금 전에 한 기본 스태킹 모델은 최종 메타 모델을 fit 할 때 y_test를 사용해서 과적합이 발생할 수 있는 문제가 있다.
#
# 이에 대한 방안으로 CV 세트 기반의 스태킹이 있다.
# ![image-2.png](attachment:image-2.png)
# 이것을 n번 만큼 반복한다.
# ![image.png](attachment:image.png)

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error
def get_stacking_base_datasets(model, X_train_n, X_test_n, y_train_n, n_folds):
    kf = KFold(n_splits=n_folds, shuffle=False)
    
    # 추후에 메타 모델이 사용할 합습데이터 반환을 위한 넘파이 배열 초기화
    train_fold_pred = np.zeros((X_train_n.shape[0], 1))
    test_pred = np.zeros((X_test_n.shape[0], n_folds))
    print(model.__class__.__name__, 'model 시작 ')
    
    for folder_counter, (train_index, vaild_index) in enumerate(kf.split(X_train_n)):
        print("\t 폴드 세트: ", folder_counter, ' 시작 ')
        X_tr = X_train_n[train_index]
        y_tr = y_train_n[train_index]
        X_te = X_train_n[vaild_index]
        
        model.fit(X_tr, y_tr)
        
        train_fold_pred[vaild_index, :] = model.predict(X_te).reshape(-1,1)
        test_pred[:, folder_counter] = model.predict(X_test_n)
    
    test_pred_mean = np.mean(test_pred, axis=1).reshape(-1,1)
    return train_fold_pred, test_pred_mean

knn_train,knn_test = get_stacking_base_datasets(knn_clf, X_train, X_test, y_train, 7)
rf_train,rf_test = get_stacking_base_datasets(rf_clf, X_train, X_test, y_train, 7)
dt_train,dt_test = get_stacking_base_datasets(dt_clf, X_train, X_test, y_train, 7)
ada_train,ada_test = get_stacking_base_datasets(ada_clf, X_train, X_test, y_train, 7)
# Out:
# KNeighborsClassifier model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작
# RandomForestClassifier model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작
# DecisionTreeClassifier model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작
# AdaBoostClassifier model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작

# %%
stack_final_X_train = np.concatenate((knn_train,rf_train, dt_train, ada_train),axis=1)
print("스태킹 학습 피처 데이터", stack_final_X_train.shape)
stack_final_X_test =np.concatenate((knn_test,rf_test, dt_test, ada_test),axis=1)
print("스태킹 테스트 피처 데이터", stack_final_X_test.shape)
# Out:
# 스태킹 학습 피처 데이터 (455, 4)
# 스태킹 테스트 피처 데이터 (114, 4)

# %%
lr_final.fit(stack_final_X_train, y_train)
pred = lr_final.predict(stack_final_X_test)

print("최종 메타 모델 정확도: {0:.4f}".format(accuracy_score(y_test, pred)))
# Out:
# 최종 메타 모델 정확도: 0.9825
