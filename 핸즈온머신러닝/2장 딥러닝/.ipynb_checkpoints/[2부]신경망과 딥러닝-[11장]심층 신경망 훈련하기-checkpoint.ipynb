# %% [markdown]
# 10장을 끝내고 왔다. <br>
# 10장을 공부해보니, 딥러닝이 머신러닝보다 오히려 더 간결한 알고리즘을 수행하는 것 같다.<br>
# 활성화함수만 잘 선택한다면 회귀, 분류 문제를 해결할 수 있기 때문에 이렇게 생각했다.
#
# 딥러닝은 재미있는 것 같다. 아직 머신러닝의 지식이 부족하기 때문에 base가 없는 상태에서 너무 막 공부를 하는게 아닌가 싶기도 하지만... 그래도 재밌으면 그만인 것 같다.
#
# 11장도 열심히 공부하겠다.

# %% [markdown]
# -----------
# 11장 초반부의 주요내용은 그래디언트 소실/ 그래디언트 폭주와 관련된 문제와 문제에 대한 해결법(다양한 가중치 초기화 방법을 통한,다양한 활성화 함수를 통한)이 제시되어있다.
#
# 그래디언트 소실/폭주 문제는 신경망의 깊이가 아주 깊은 (내가 하고 싶은 말은 10장에서 사용된 은닉층이 해봐야 두겹인 신경망이 아닌) 신경망에서 발생하는 문제라고한다. 아직은 이런 문제를 겪어보지 못해서 뭔가 와닿지는 않는다.

# %% [markdown]
# ### 가중치 초기화를 통한 그래디언트 소실문제 해결

# %% [markdown]
# - 글로럿 초기화: 활성화함수 없음, tanh, logistic, softmax - σ^2 = 1/fan_avg
# - He 초기화: ReLU 함수와 그 변종들(Leaky ReLU) - σ^2 = 2/fan_in
# - 르쿤 : SELU  - σ^2 = 1/fan_in
#
# 위 식들은 균등분포 혹은 정규분포로 이루어져있다. <br>
# 이때 중요한 값은, fan_in/ fan_out이다. 이 값들은 각각 층의 입력과 출력연결 개수를 나타낸다.
#
# 디폴트는 균등분포의 글로럿초기화를 사용한다. r= sqrt(3/fan_avg) 일 때, -r ~ +r
#
# > keras.layers.Dense(10, activation="relu", kernel_initializer="he_nomal")
#
# > keras.layers.Dense(10, activation="relu", kernel_initializer="lecun_nomal")

# %% [markdown]
# ### 활성화 함수를 통한 그래디언트 문제 해결

# %% [markdown]
# 주요 활성화 함수:
# 1. LeakyReLU: ReLU와 비슷하지만, 죽은 ReLU문제가 일어나지 않는 장점이 있다.
# 2. RReLU: LeakyReLU alpha값을 무작위로 설정하는 활성화 함수이다. 이 함수는 규제의 역할도 수행한다.
# 3. PReLU: 역전파가 실행될 때 마다 alpha값이 훈련되서 수정되는 함수이다. 소규모 데이터셋에서는 과대적합의 위험성이 있다.
# 4. ELU: z<0 일때 지수함수로 이루어진 함수이다. 수렴속도가 빠르고 정확하지만, 계산이 느리다.
# 5. SELU: 자기정규화가 가능하다면 가장 성능이 좋은 함수이다. lecun_normal을 사용해야한다.
#
# SELU > ELU > LeakyReLU > ReLU > tanh > logistic 순으로 사용하면 된다.
# 하지만 나는 속도가 중요하기 때문에 ReLU를 사용할 것이다.

# %% [markdown]
# LeakyReLU 활성화 함수를 사용하려면 LeakyReLU층을 만들고 모델에서 적용하려는 층 뒤에 추가하면 된다.
# > model.keras.models.Sequential(\[<br>
# &nbsp; &nbsp; &nbsp; &nbsp; [...]<br>
# &nbsp; &nbsp; &nbsp; &nbsp; keras.layers.Dense(10, kernel_initializer="he_normal"),<br>
# &nbsp; &nbsp; &nbsp; &nbsp; keras.layers.LeakyReLU(alpha=0.2),<br>
# &nbsp; &nbsp; &nbsp; &nbsp; [...]<br>
# \])
#
# PReLU는 keras.layers.LeakyReLU(alpha=0.2) 대신 keras.layers.PReLU(alpha=0.2)를 사용하면 된다.
#
# ----------
# SELU 활성화 함수를 사용하려면
# > layer = keras.layers.Dense(10, activation="selu", kernel_optimizer="lecun_normal")
#
# 처럼 작성하면 된다.

# %% [markdown]
# ### 배치 정규화
# 이 기법은 각 층에서 활성화 함수를 통과하기 전이나 후에 모델에 연산을 하나 추가하는 것이다. 이 연산은 단순하게 입력을 원점에 맞추고 정규화한다음, 각 층에서 두개의 새로운 파라미터로 결괏값의 스케일을 조정하고 이동시킨다. 하나는 스케일 조정에, 다른 하나는 이동에 사용한다. 많은 경우 신경망의 첫 번째 층으로 배치 정규화를 추가하면 훈련 세트를 표준화할 필요가 없다.
#
# 라고 한다...
#
#
# 나는 잘 이해를 못해서 아래 링크를 통해서 이해해봤다<br>
# https://sacko.tistory.com/44
#
# <b>내가 생각하기에 배치 정규화는 매번 배치가 학습될 때마다, 배치의 평균과 분산을 추정해서(지수이동평균을 이용한다.)(이 때 추정된 평균과 추정된 분산 변수가 생긴다.), 매 은닉층에 들어가기전에 정규화된 상태(이 때 감마와 베타가 이용된다.) 로 들어가게하는 것이다.</b>
# ![image.png](attachment:image.png)
# ~~다른건 알겠는데 스케일 조정과, 이동에 사용되는 파라미터는 뭔지 잘 모르겠다. ~~
# <br> 파라미터 두개는 각각 정규화를 위해서 각 뉴런마다 적용되는 파라미터라고 생각하면 될 듯 하다. (역전파를 통해 학습됨)

# %% [markdown]
# ## 케라스로 배치 정규화 구현하기
# 배치정규화는 아래와 같이 사용할 수 있다.
#
# 활성화 함수의 앞이나 뒤에 배치정규화 층을 넣어주면 된다.

# %%
from tensorflow import keras

model_1 = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28,28]),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(300, activation="elu", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(10, activation="softmax")
])

# %%
model_1.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_3 (Flatten)         (None, 784)               0
#
#  batch_normalization_9 (Batc  (None, 784)              3136
#  hNormalization)
#
#  dense_9 (Dense)             (None, 300)               235500
#
#  batch_normalization_10 (Bat  (None, 300)              1200
#  chNormalization)
#
#  dense_10 (Dense)            (None, 100)               30100
#
#  batch_normalization_11 (Bat  (None, 100)              400
#  chNormalization)
#
#  dense_11 (Dense)            (None, 10)                1010
#
# ...
# Total params: 271,346
# Trainable params: 268,978
# Non-trainable params: 2,368
# _________________________________________________________________

# %%
[(var.name, var.trainable) for var in model_1.layers[1].variables]
# Out:
# [('batch_normalization_9/gamma:0', True),
#  ('batch_normalization_9/beta:0', True),
#  ('batch_normalization_9/moving_mean:0', False),
#  ('batch_normalization_9/moving_variance:0', False)]

# %% [markdown]
# 감마와 베타는 역전파를 수행할 때 학습이 되는 변수이고, 추정된 평균과 분산을 담당하는 변수는 역전파에서 학습되는 변수가 아니다.

# %%
model_2 = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28,28]),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(300, activation="elu", kernel_initializer="he_normal", use_bias=False),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal", use_bias=False),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(10, activation="softmax")
])

# %% [markdown]
# 배치정규화는 이동파라미터가 있기 때문에 편향을 사용하지 않을 수 있다. <br>
# 편향을 배제하는게 어떤 효과로 나타는지 모르겠지만, 말 그대로 학습에서의 편향을 배제해주는 것 아닐까?

# %% [markdown]
# ----
# BatchNormalization은 조정할 하이퍼파라미터가 적다.
#
# 그래도 이따금 momentum 매개변수를 변경해야할 필요가 있다. 이는 Batchnormalization에서 지수 이동 평균을 업데이트할 때 사용된다. 새로운 v값(즉, 현재 배치에서 계산한 새로운 입력 평균 벡터나 표준편차벡터)가 주어지면 다음 식을 이용해서 이동 평균 v^을 업데이트 한다.
#
# > v^ = v^ x momentum + v x (1 - momentum)
#
# 적절한 momentum 값은 일반적으로 1에 가깝다. 예를 들면 0.9, 0.99, 0.99이다.
#
# -----
# 다른 중요한 하이퍼파라미터는 axis 이다. 이 매개 변수는 정규화할 축을 결정한다. 기본값은 -1이다. 즉 마지막 축을 정규화한다. 입력 배치가 2D(즉, 배치 크기가 [샘플개수, 특성개수])이면 각 입력 특성이 배치에 있는 모든 샘플에 대해 계산한 평균과 표준표준편차를 기반으로 정규화 된다.
#
# 이전 model_1 에서 첫번째 배치 정규화 층은 784개의 입력 특성마다 독립적으로 정규화가 될 것이다. <br>
# 만약 정규화 층을 Flatten(28 x 28 행렬을 784 크기의 벡터로 바꾸어 주는 층)이전으로 옮기면 입력배치가 [샘플개수, 높이, 너비] 크기의 3D가 된다. 따라서 배치 정규화 층이 28 개의 평균과 28개의 표준편차를 계산하고, 이를 이용해서 모든 픽셀을 정규화 한다.
#
# 만약 모든 픽셀을 개별적으로 정규화 하고 싶다면 axis=[1,2]로 지정하면 된다.
#
# ~~라고 하는데.... 정규화의 효과를 아직은 잘 모르겠다.~~
#
# 이 다음에 클래스 코드를 보는 부분이 있는데 잘 모르겠다..!

# %% [markdown]
# ## 그레이디언트 클리핑
# 그레디언트 폭주 문제를 완화하기 위한 방법중 하나로, 역전파될 때 일정 임곗값을 넘어서지 못하게 그레디언트를 잘라내는 것이다.<br>
# 이는 배치정규화를 적용하기 힘든 순환신경망(RNN)에서 주로 사용된다. 다른 종류 네트워크는 배치 정규화면 충분하다.

# %% [markdown]
# > optimizer = keras.opimizers.SGD(clipvalue=1.0)
#
# > model.compile(loss="mse", optimizer = optimizer)

# %% [markdown]
# ## 사전훈련된 층 재사용하기

# %% [markdown]
# 이미 사용하는 모델을 재사용하는 방법이다. 아래나온 코드는 가져온 코드이다.

# %% [markdown]
# 패션 MNIST 훈련 세트를 두 개로 나누어 보죠:
#
# - X_train_A: 샌달과 셔츠(클래스 5와 6)을 제외한 모든 이미지
# - X_train_B: 샌달과 셔츠 이미지 중 처음 200개만 가진 작은 훈련 세트
# 검증 세트와 테스트 세트도 이렇게 나눕니다. 하지만 이미지 개수는 제한하지 않습니다.
#
# A 세트(8개의 클래스를 가진 분류 문제)에서 모델을 훈련하고 이를 재사용하여 B 세트(이진 분류)를 해결해 보겠습니다. A 작업에서 B 작업으로 약간의 지식이 전달되기를 기대합니다. 왜냐하면 A 세트의 클래스(스니커즈, 앵클 부츠, 코트, 티셔츠 등)가 B 세트에 있는 클래스(샌달과 셔츠)와 조금 비슷하기 때문입니다. 하지만 Dense 층을 사용하기 때문에 동일한 위치에 나타난 패턴만 재사용할 수 있습니다(반대로 합성곱 층은 훨씬 많은 정보를 전송합니다. 학습한 패턴을 이미지의 어느 위치에서나 감지할 수 있기 때문입니다. CNN 장에서 자세히 알아 보겠습니다).

# %%
from tensorflow import keras
import numpy as np
import pandas as pd

(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
X_train_full = X_train_full / 255.0
X_test = X_test / 255.0
X_valid, X_train = X_train_full[:5000], X_train_full[5000:]
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

def split_dataset(X, y):
    y_5_or_6 = (y == 5) | (y == 6) # sandals or shirts
    y_A = y[~y_5_or_6]
    y_A[y_A > 6] -= 2 # class indices 7, 8, 9 should be moved to 5, 6, 7
    y_B = (y[y_5_or_6] == 6).astype(np.float32) # binary classification task: is it a shirt (class 6)?
    return ((X[~y_5_or_6], y_A),
            (X[y_5_or_6], y_B))

(X_train_A, y_train_A), (X_train_B, y_train_B) = split_dataset(X_train, y_train)
(X_valid_A, y_valid_A), (X_valid_B, y_valid_B) = split_dataset(X_valid, y_valid)
(X_test_A, y_test_A), (X_test_B, y_test_B) = split_dataset(X_test, y_test)
X_train_B = X_train_B[:200]
y_train_B = y_train_B[:200]

# %%
print(X_train_A.shape)
print(X_train_B.shape)
# Out:
# (43986, 28, 28)
# (200, 28, 28)

# %%
y_test_A
# Out:
# array([7, 2, 1, ..., 1, 6, 1], dtype=uint8)

# %%
y_test_B
# Out:
# array([1., 1., 0., ..., 0., 1., 0.], dtype=float32)

# %%
model_A = keras.models.Sequential()
model_A.add(keras.layers.Flatten(input_shape=[28, 28]))
for n_hidden in (300, 100, 50, 50, 50):
    model_A.add(keras.layers.Dense(n_hidden, activation="selu"))
model_A.add(keras.layers.Dense(8, activation="softmax"))

# %%
model_A.compile(loss="sparse_categorical_crossentropy",
                optimizer=keras.optimizers.SGD(learning_rate=1e-3),
                metrics=["accuracy"])

# %%
history = model_A.fit(X_train_A, y_train_A, epochs=20,
                    validation_data=(X_valid_A, y_valid_A))
# Out:
# Epoch 1/20
# 1375/1375 [==============================] - 9s 6ms/step - loss: 0.5758 - accuracy: 0.8091 - val_loss: 0.3755 - val_accuracy: 0.8724
# Epoch 2/20
# 1375/1375 [==============================] - 7s 5ms/step - loss: 0.3535 - accuracy: 0.8761 - val_loss: 0.3255 - val_accuracy: 0.8871
# Epoch 3/20
# 1375/1375 [==============================] - 7s 5ms/step - loss: 0.3183 - accuracy: 0.8888 - val_loss: 0.3049 - val_accuracy: 0.8969
# Epoch 4/20
# 1375/1375 [==============================] - 7s 5ms/step - loss: 0.2990 - accuracy: 0.8954 - val_loss: 0.2883 - val_accuracy: 0.9018
# Epoch 5/20
# 1375/1375 [==============================] - 7s 5ms/step - loss: 0.2854 - accuracy: 0.9017 - val_loss: 0.2826 - val_accuracy: 0.9051
# Epoch 6/20
# 1375/1375 [==============================] - 7s 5ms/step - loss: 0.2752 - accuracy: 0.9073 - val_loss: 0.2768 - val_accuracy: 0.9046
# Epoch 7/20
# ...

# %%
model_A.save("my_model_A.h5")

# %%
model_B = keras.models.Sequential()
model_B.add(keras.layers.Flatten(input_shape=[28,28]))
for n_hidden in [300,100,50,50,50]:
    model_B.add(keras.layers.Dense(n_hidden, activation="selu"))
model_B.add(keras.layers.Dense(1, activation="sigmoid"))

model_B.compile(loss="binary_crossentropy",
                optimizer=keras.optimizers.SGD(learning_rate=1e-3),
                metrics=["accuracy"])

model_B.fit(X_train_B, y_train_B, epochs=20,
           validation_data = (X_valid_B, y_valid_B))

model_B.summary()
# Out:
# Epoch 1/20
# 7/7 [==============================] - 2s 81ms/step - loss: 0.5849 - accuracy: 0.7150 - val_loss: 0.5698 - val_accuracy: 0.7160
# Epoch 2/20
# 7/7 [==============================] - 0s 32ms/step - loss: 0.4579 - accuracy: 0.8150 - val_loss: 0.4720 - val_accuracy: 0.7870
# Epoch 3/20
# 7/7 [==============================] - 0s 29ms/step - loss: 0.3706 - accuracy: 0.8800 - val_loss: 0.3968 - val_accuracy: 0.8408
# Epoch 4/20
# 7/7 [==============================] - 0s 29ms/step - loss: 0.3052 - accuracy: 0.9100 - val_loss: 0.3459 - val_accuracy: 0.8732
# Epoch 5/20
# 7/7 [==============================] - 0s 29ms/step - loss: 0.2585 - accuracy: 0.9250 - val_loss: 0.2979 - val_accuracy: 0.9077
# Epoch 6/20
# 7/7 [==============================] - 0s 34ms/step - loss: 0.2190 - accuracy: 0.9400 - val_loss: 0.2686 - val_accuracy: 0.9158
# Epoch 7/20
# ...

# %%
model_A = keras.models.load_model("my_model_A.h5")
model_B_on_A = keras.models.Sequential(model_A.layers[:-1])
model_B_on_A.add(keras.layers.Dense(1, activation="sigmoid"))
# 이 방식을 사용하면 model_A의 가중치도 변한다.
# model_A_clone = keras.models.clone_model(model_A)
# model_A_clone_set_weight(model_A.get_weight)
# 클론을 만들고 가중치를 설정해주는 방식으로 하면 model_A가 영향을 받지 않는다.

# %% [markdown]
# 이제 model_B_on_A를 compile하고 fit 해야한다. 하지만 새롭게 추가된 층은 가중치가 초기화되었기 때문에 fit하는 과정에서 앞선 층들의 가중치가 어지렵혀질 수 있다. 이걸 방지하기 위해서 앞선 층들을 동결해주고(새롭게 추가된 층의 가중치를 적절한 수준으로 바꾸어 주고) 적은 에포크로 학습을 시켜준 후, 동결을 풀고 모든 층을 학습시켜준다.

# %%
for layer in model_B_on_A.layers[:-1]:
    layer.trainable = False

# 층을 동결하거나 동결을 해제한 후 반드시 모델을 컴파일해야한다.
 
model_B_on_A.compile(loss="binary_crossentropy", optimizer="sgd",
                    metrics=["accuracy"])

model_B_on_A.fit(X_train_B, y_train_B, epochs=4,
                validation_data=(X_valid_B, y_valid_B))
# Out:
# Epoch 1/4
# 7/7 [==============================] - 1s 92ms/step - loss: 1.2767 - accuracy: 0.2300 - val_loss: 0.6814 - val_accuracy: 0.5578
# Epoch 2/4
# 7/7 [==============================] - 0s 26ms/step - loss: 0.5405 - accuracy: 0.7200 - val_loss: 0.3803 - val_accuracy: 0.8621
# Epoch 3/4
# 7/7 [==============================] - 0s 26ms/step - loss: 0.3179 - accuracy: 0.8750 - val_loss: 0.2569 - val_accuracy: 0.9310
# Epoch 4/4
# 7/7 [==============================] - 0s 29ms/step - loss: 0.2189 - accuracy: 0.9400 - val_loss: 0.1955 - val_accuracy: 0.9544

# %%
for layer in model_B_on_A.layers[:-1]:
    layer.trainable = True
    
model_B_on_A.compile(loss="binary_crossentropy", optimizer=keras.optimizers.SGD(learning_rate=1e-4),
                    metrics=["accuracy"])
model_B_on_A.fit(X_train_B, y_train_B, epochs=16,
                validation_data=(X_valid_B, y_valid_B))
# Out:
# Epoch 1/16
# 7/7 [==============================] - 2s 120ms/step - loss: 0.1811 - accuracy: 0.9650 - val_loss: 0.1919 - val_accuracy: 0.9584
# Epoch 2/16
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1773 - accuracy: 0.9700 - val_loss: 0.1884 - val_accuracy: 0.9594
# Epoch 3/16
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1737 - accuracy: 0.9750 - val_loss: 0.1849 - val_accuracy: 0.9594
# Epoch 4/16
# 7/7 [==============================] - 0s 36ms/step - loss: 0.1701 - accuracy: 0.9750 - val_loss: 0.1818 - val_accuracy: 0.9594
# Epoch 5/16
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1668 - accuracy: 0.9750 - val_loss: 0.1786 - val_accuracy: 0.9635
# Epoch 6/16
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1635 - accuracy: 0.9750 - val_loss: 0.1757 - val_accuracy: 0.9675
# Epoch 7/16
# ...

# %%
model_B_on_A.evaluate(X_test_B, y_test_B)
# Out:
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1120 - accuracy: 0.9875
# [0.11201521754264832, 0.987500011920929]

# %%
model_B.evaluate(X_test_B, y_test_B)
# Out:
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1081 - accuracy: 0.9790
# [0.108088418841362, 0.9789999723434448]

# %% [markdown]
# 전이 학습은 작은 완전 열결 네트워크에서는 잘 동작하지 않는다.
#
# 전이학습은 합성곱 신경망에서 잘 동작한다고 한다.

# %% [markdown]
# ## 비지도 사전훈련
# 이거는 어려웠다. 뒷부분 공부해봐야겠다.

# %% [markdown]
# ## 고속 옵티마이저

# %% [markdown]
# ~~이거 식을 보는데 잘못되도 한참 잘못된 느낌이다. ㅋㅋㅋㅋㅋ <br>
# 선형대수를 잘 모르는..? 상태에서 공부해서 그런가? 아니다 그냥 어려운 내용같다. 악~~
#
# --------
#
# - <b>모멘텀 최적화: 이거는 지수가중평균을 이용해서 이전의 그레디언트를 고려해서 변수를 업데이트 하는 방식이다. </b><br>
# https://velog.io/@minjung-s/Optimization-Algorithm 여기 설명이 너무 잘 나와있다. <br>
# https://m.blog.naver.com/nilsine11202/221903150950 지수가중평균을 설명하는 글.
# ![image.png](attachment:image.png)
# > optimizer = keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)
#
# -----------------
#
# - <b>네스테르포 가속 경사: 모멘텀 최적화보다 좋다고 한다.</b>
# ![image-2.png](attachment:image-2.png)
# > optimizer = keras.optimizers.SGD(learning_rate=0.001, momentum=0.9, nesterov=True)
#
# -----
# 위 두개 최적화의 차이는
#
# - 모멘텀 최적화
# 1. 현재 위치에서의 gradient를 구한다
# 2. 이전 velocity를 가져온다
# 3. 이 두 가지 방향을 더한 방향으로 한 step 간다
# - 네스테르포 가속 경사
# 1. 이전 velocity를 가져온다
# 2. 이전 velocity 방향대로만 갔을 때의 지점에서 gradient를 구한다
# 3. 이 두 가지를 더한 방향으로 한 step 간다
#
# 라고한다.<br>
#
#
# https://hyunw.kim/blog/2017/11/01/Optimization.html 여기를 참고했는데 여기 설명이 굉장히 잘 나와있다.
# <br>~~이쯤오니 감이 잡힌다. 내가 멍청한게 아니라 진짜 어려운 거였어.~~
#
# ------
# - <b>AdaGrad: 가장 가파른 차원을 따라 그레디언트 벡터의 스케일을 감소시켜서 빠르게 내려가게하는 경사하강법.</b>
# ![image-3.png](attachment:image-3.png)
# <br>하지만 신경망에서는 너무 빨리 학습이 종료되서 사용하지 않는다.
#
# --------------
#
# - <b>RMSProp: AdaGrad가 너무 빨리종료되는 문제를 최근 반복에서 비롯된 그레디언트만 누적함으로써 문제를 해결한 경사하강법.</b>
# ![image-4.png](attachment:image-4.png)
# 이건 느낌이 모멘텀 최적화와 비슷하다. 지수평균가중을 사용한 것이다.
# > optimizer = keras.optimizer.RMSprop(lr=0.001, rho=0.9)
#
# -----
# - <b>Adam 최적화: RMSProp와 모멘텀 최적화를 합친 것 이다.</b>
# ![image-5.png](attachment:image-5.png)
# 1. t는 (1부터 시작하는) 반복 횟수<br>
# 2. 단계 1,2,5는 모멘텀 최적화, RMSProp과 비슷<br>
# 3. 단계 3,4에서 m,s는 0으로 초기화되기 때문에 훈련 초기에 0쪽으로 치우치게 된다.<br>
# 4. 그래서 이 두 단계가 훈련 초기에 m,s의 값을 증폭시키는 데 도움을 준다. <br>
# 5. 반복 초기에는 m,s를 증폭시켜주지만 반복이 많이 진행되면 단계 3,4의 분모는 1에 가까워져 거의 증폭되지 않는다.모멘텀 감쇠 하이퍼파라미터 β1은 보통 0.9로, 스케일 감쇠 하이퍼파라미터 β2는 0.999로 초기화<br>
# > optimizer = keras.optimizer.Adam(lr=0.001, beta_1=0.9, beta_2=0.999)
#
#
# ------
# - <b>AdaMax: Adam 최적화와 비슷하지만 다른..? 최적화 방법. 일반적으로 Adam 최적화가 더 성능이 좋다.</b>
#
# -----
# - <b>Nadam: Adam 최적화에 네스테로프 기법을 더한 것이다. 일반적으로 Nadam 이 Adam보다 성능이 좋았다.
#
# -----
#
# 적응적 최적화 방법이 좋은 솔루션은 맞지만, 특정 [데이터셋](https://homl.info/60)에서 나쁜 성능을 보인다. 이럴 때에는 네스테로프 가속 경사를 사용해보자.
#
# 위 링크를 타고 들어가서 논문을 읽어봤는데..(물론 서론과 결론 위주로) 무조건 SGD가 이득이라는 급진적인(?) 주장을 펼친다.. 그래서 내가 잘 해석한게 맞나 싶어서 검색을 해봤는데.. 맞는것 같다. 음.. 저 논문을 리뷰한 한국 블로그도 찾아봤다. https://jaejunyoo.blogspot.com/2017/06/marginal-value-of-adaptive-gradient-methods-in-ML2.html
# 나는 저 논문이 맞는지 틀린지 잘 모르겠다! 그래도 첫 옵티마이저는 SGD로 해보는게 맞는 것 같다. 안그러면 저자분한테 맞을 듯..

# %% [markdown]
# ## 학습률 스케일링
# 실행시간에 학습률을 튜닝하는 것<br>
# 여기에 스텝이라는 개념이 나와서 헷갈렸는데, 스텝이란 한개의 배치가 학습되는 과정을 말한다.
# https://bslife.tistory.com/73
# ![image.png](attachment:image.png)

# %% [markdown]
# - 거듭제곱 기반 스케줄링
# - 지수 기반 스케줄링
# - 구간별 고정 스케줄링
# - 성능 기반 스케줄링
# - 1 사이클 스케줄링
#
# 책에서는 1 사이클 스케줄링 > 지수 기반 스케줄링 > 성능기반 스케줄링 순으로 성능이 좋다고 한다.
#
#
# 1 cycle scheduling이 왜 좋은 지에 대해서 찾아봤다. <br>
# https://towardsdatascience.com/finding-good-learning-rate-and-the-one-cycle-policy-7159fe1db5d6<br>
# https://arxiv.org/pdf/1803.09820.pdf
#
# 위 링크들을 조금 읽어봤는데, 1 cycle scheduling 이 좋다고 한다. <br>
# 내 생각으로는 학습률을 점점 높혀나가면서 빠르게 지역최소점을 벗어남과 동시에 전역최소점으로 가까이 가고, 학습률이 작아지면서 잘 수렴할 수 있도록 하는 것 같다.

# %% [markdown]
# #### 거듭제곱 기반 스케줄링

# %%
# decay는 s(학습률을 나누기 위해 수행할 스텝 수)의 역수이다.
optimizer = keras.optimizers.SGD(learning_rate = 0.01, decay = 1e-4)

# %% [markdown]
# #### 지수 기반 스케줄링

# %%
def exponential_decay_fn(epoch):
    return 0.01 * 0.1**(epoch/20)

def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch/s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(lr0=0.01, s=20)

# %% [raw]
# lr_scheduler = keras.callbacks.LearningRateScheculer(exoinential_decay_fn)
# history = model.fit(X_train_scaled, y_train, [...], collbacks=[lr_scheduler])

# %% [markdown]
# #### 성능 기반 스케줄링

# %% [raw]
# lr_scheduler = keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5)
# history = model.fit(X_train_scaled, y_train, [...], callbacks=[lr_scheduler])

# %% [markdown]
# #### 1 사이클 스케줄링

# %% [markdown]
# https://github.com/rickiepark/handson-ml2/blob/master/11_training_deep_neural_networks.ipynb<br>
# https://www.kaggle.com/code/robotdreams/one-cycle-policy-with-keras/notebook<br>
# https://arxiv.org/pdf/1803.09820.pdf
#
# 위 링크에 나와있는 코드이다, 잘 모르겠다..! <br>
# 위 링크에서 아래 코드의 바로위에 어떤 그래프가 있는데, 내 생각에는 max_rate를 찾는 과정 같다.
#
# 두번째 링크는 캐글에서 one cycle policy를 코드로 만들어서 보여준 것이고, 3번째 링크는 관련된 논문이다.
#
# 내가 아직 사용자 클래스를 만들만큼 keras에 대한 이해도가 높지 않아서 이해를 잘 못하는 것 같다. <br>
# 특히 log가 저장되고 그런 것들을 잘 모르겠다..!
#
# 이해가 되면 다시 봐보자

# %%
import math 

class OneCycleScheduler(keras.callbacks.Callback):
    def __init__(self, iterations, max_rate, start_rate=None,
                 last_iterations=None, last_rate=None):
        self.iterations = iterations
        self.max_rate = max_rate
        self.start_rate = start_rate or max_rate / 10
        self.last_iterations = last_iterations or iterations // 10 + 1
        self.half_iteration = (iterations - self.last_iterations) // 2
        self.last_rate = last_rate or self.start_rate / 1000
        self.iteration = 0
    def _interpolate(self, iter1, iter2, rate1, rate2):
        return ((rate2 - rate1) * (self.iteration - iter1)
                / (iter2 - iter1) + rate1)
    def on_batch_begin(self, batch, logs):
        if self.iteration < self.half_iteration:
            rate = self._interpolate(0, self.half_iteration, self.start_rate, self.max_rate)
        elif self.iteration < 2 * self.half_iteration:
            rate = self._interpolate(self.half_iteration, 2 * self.half_iteration,
                                     self.max_rate, self.start_rate)
        else:
            rate = self._interpolate(2 * self.half_iteration, self.iterations,
                                     self.start_rate, self.last_rate)
        self.iteration += 1
        K.set_value(self.model.optimizer.lr, rate)
n_epochs = 25

onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * n_epochs, max_rate=0.05)
history = model.fit(X_train_scaled, y_train, epochs=n_epochs, batch_size=batch_size,
                    validation_data=(X_valid_scaled, y_valid),
                    callbacks=[onecycle])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2368/634175521.py in <module>
#      28
#      29 onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * n_epochs, max_rate=0.05)
# ---> 30 history = model.fit(X_train_scaled, y_train, epochs=n_epochs, batch_size=batch_size,
#      31                     validation_data=(X_valid_scaled, y_valid),
#      32                     callbacks=[onecycle])
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## 규제를 사용해서 과대적합 피하기

# %% [markdown]
# 파라미터가 많을 수록 과대적합 되기가 쉽다. 그렇기 때문에 규제를 사용해준다.

# %% [markdown]
# #### l1, l2 규제

# %%
layer = keras.layers.Dense(100, activation="elu",
                          kernel_initializer="he_normal",
                          kernel_regularizer=keras.regularizers.l2(0.01))

# %% [markdown]
# 위와 같이 사용할 수 있다.
#
# ------
# 은닉층이 많을 때 위와 같이 쓰면 코드의 가독성이 떨어진다. 그렇기 때문에 <b>functools.partial()</b>을 사용하면 좋다

# %%
from functools import partial

RegularuzedDense = partial(keras.layers.Dense,
                          activation = "elu",
                          kernel_initializer="he_normal",
                          kernel_regularizer=keras.regularizers.l2(0.01))

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28,28]),
    RegularuzedDense(300),
    RegularuzedDense(100),
    RegularuzedDense(10, activation="softmax",
                    kernel_initializer="glorot_uniform")
])

# %% [markdown]
# ## 드롭아웃
# ![image.png](attachment:image.png)

# %% [raw]
# model = keras.models.Sequential([
#     keras.layers.Flatten(input_shape=[28, 28]),
#     keras.layers.Dropout(rate=0.2),
#     keras.layers.Dense(300, activation="elu", kernel_initializer="he_normal"),
#     keras.layers.Dropout(rate=0.2),
#     keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
#     keras.layers.Dropout(rate=0.2),
#     keras.layers.Dense(10, activation="softmax")
# ])
# model.compile(loss="sparse_categorical_crossentropy", optimizer="nadam", metrics=["accuracy"])
# n_epochs = 2
# history = model.fit(X_train_scaled, y_train, epochs=n_epochs,
#                     validation_data=(X_valid_scaled, y_valid))

# %% [markdown]
# 드롭아웃을 적용해서 훈련시 훈련손실과 검증손실을 비교하면 오해를 일으킨다. 그러므로 훈련이 끝난후에 검증을 해야한다.<br>
#
# 모델이 과대적합되었다면 드롭아웃비율을 늘리고, 과소적합되었다면 드롭아웃 비율을 낮추면 된다. <br>
#
# 만약 SELU를 활성화 함수로 사용한다면(자기정규화를 진행해야함.) 알파드롭아웃(평균과 표준편차를 유지하는 드롭아웃)을 사용해야한다.

# %% [markdown]
# ## MC 드롭아웃
# 드롭아웃으로 만든 예측을 평균을 내서 예측확률을 보다 정확하게 나타내는 방법

# %% [raw]
# # model은 predict메소드와 비슷하다. training 파라미터를 True로 함으로써 드롭아웃을 활성화 할 수 있다.
#
# y_probas = np.stack([model(X_test_scaled, training=True)
#                      for sample in range(100)])
# y_proba = y_probas.mean(axis=0)
# y_std = y_probas.std(axis=0)

# %% [raw]
# MC 드롭아웃은 몯ㄹ이 훈련하는 동안 다르게 작동하는 (배치 정규화 층)층을 가지고 있다면 앞에서와 같이 훈련모드를 강제로 설정해서는 안된다.
